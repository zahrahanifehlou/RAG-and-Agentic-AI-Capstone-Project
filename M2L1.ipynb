# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Construct a Multimodal Vector Index**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Introduction
#
# Retrieval-Augmented Generation (RAG) systems depend critically on the quality of their retrieval layer to produce grounded and contextually accurate responses. In real-world applications, user queries often span heterogeneous data sources, including structured textual information and visual content. As a result, modern RAG pipelines increasingly adopt **multimodal retrieval architectures** capable of indexing and searching across multiple data modalities.
#
# To support these scenarios, multimodal systems encode different data types into dense vector representations that enable efficient similarity-based search. A well-designed retrieval layer ensures that high-quality evidence is identified before any downstream reasoning or generation occurs.
#
# In this lab, you will build the retrieval backbone of a multimodal RAG system for restaurant and food discovery. Using structured outputs from Module 1 together with raw food images, you will construct **vectorized, searchable indexes** that support cross-modal evidence retrieval.
#
# The lab emphasizes **retrieval pipeline engineering**, focusing on how heterogeneous data is transformed, embedded, and organized within scalable vector databases using ChromaDB. This modular design mirrors production RAG systems, where the retrieval layer operates as a reusable component independent of the generation model.
#
# Upon completion, you will have a functional multimodal vector index that forms the foundation for similarity search, metadata-constrained retrieval, and multimodal fusion in subsequent lessons.

# %% [markdown]
# ## Objectives
#
# After completing this lab, you will be able to:
#
# - Construct retrieval-ready documents from structured restaurant data
# - Generate dense embeddings for both text and image modalities
# - Build separate vector indexes for articles and food images using Chroma
# - Persist multimodal vector databases for downstream retrieval tasks
# - Prepare the retrieval backbone for similarity search and metadata filtering
#
# These capabilities form the foundation of a production-style multimodal RAG retrieval pipeline.

# %% [markdown]
# ## Set up the lab environment
#
# In this step, you'll install the core libraries required to build a multimodal retrieval system.
#
# The environment supports both text and image processing and prepares the runtime for vector database construction. These components will be used throughout the module.
#
# The environment includes:
#
# - **PyTorch (CPU)** for model inference and tensor operations
# - **LangChain + Chroma** for vector database construction and persistence
# - **Sentence-Transformers** for generating text embeddings
# - **Transformers (CLIP)** for image embedding support
# - **Pillow and NumPy** for image loading and numerical processing
#
# After installation completes, the environment will be ready for multimodal vector index construction.

# %%
# # ================================
# # Install dependencies
# # ================================
# !pip install -q torch torchvision --index-url https://download.pytorch.org/whl/cpu
# !pip install -q langchain==0.3.27 langchain-community==0.3.31 langchain-chroma==0.2.6
# !pip install -q sentence-transformers==2.7.0 transformers pillow numpy

# %% [markdown]
# ## Import core libraries
#
# Next, import the core Python libraries used throughout this lab.
#
# These libraries enable:
#
# - structured data loading and preprocessing
# - embedding model initialization
# - multimodal document construction
# - vector database creation and management
#
# Successful import confirms that the runtime environment is correctly configured and ready for the retrieval pipeline.

# %%
# ================================
# Import libraries
# ================================

# Standard library
import glob
import json
import os
import shutil
from pathlib import Path

# Third-party library
import numpy as np
import torch
from PIL import Image
from langchain_chroma import Chroma
from langchain_core.documents import Document
from sentence_transformers import SentenceTransformer
from transformers import CLIPModel, CLIPProcessor

print("✅ Environment ready")
# Out:
# ✅ Environment ready

# %% [markdown]
# ## Prepare the image dataset
#
# Multimodal retrieval systems require both textual and visual evidence.
#
# In this step, you'll perform the following operations:
#
# 1. Download the synthetic recipe image dataset
# 2. Extract the image archive
# 3. Collect image file paths for embedding
#
# These images will later form the **Restaurant & Food Images database**, which complements the restaurant text database built from structured data.

# %%
# ================================
# Download and prepare image data
# ================================
ZIP_URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/5_Rr6ohviItzucyWk6nkrw/synthetic-recipe-images.zip"
ZIP_PATH = "data/synthetic-recipe-images.zip"
IMG_DIR  = "data/recipe_images"

# !wget -P ./data/ -q -O {ZIP_PATH} {ZIP_URL}
# !unzip -oq {ZIP_PATH} -d {IMG_DIR}

image_paths = sorted(glob.glob(f"{IMG_DIR}/**/*.png", recursive=True))
print(f"✅ Images found: {len(image_paths)}")
# Out:
# ✅ Images found: 109

# %% [markdown]
# ## Load the structured data
#
# This module builds directly on the structured outputs produced earlier. Before constructing the multimodal index, load the processed JSON files generated earlier.
#
# You'll load:
#
# - **Structured restaurant data**, which provides the textual retrieval corpus
# - **Augmented recipe data**, which supplies additional metadata for food items
#
# These structured records will be transformed into retrieval-ready documents in the next step. Maintaining this pipeline connection ensures the multimodal RAG system remains modular and extensible.

# %%
# ================================
# Load structured data from Module 1
# ================================

# NOTE: Ensure the JSON files are in your current working directory.

with open("data/structured_restaurant_data.json", "r") as f:
    restaurants = json.load(f)

with open("data/augmented_food_recipe.json", "r") as f:
    recipes = json.load(f)

with open("data/augmented_user_review.json", "r") as f:
    user_reviews = json.load(f)
print(f"✅ Loaded restaurants: {len(restaurants)}")
print(f"✅ Loaded recipes:     {len(recipes)}")
print(f"✅ Loaded user reviews: {len(user_reviews)}")
# Out:
# ✅ Loaded restaurants: 95
# ✅ Loaded recipes:     109
# ✅ Loaded user reviews: 10

# %%
restaurants[0].keys()
# Out:
# dict_keys(['name', 'location', 'type', 'food_style', 'rating', 'price_range', 'signatures', 'vibe', 'environment', 'shortcomings', 'itemId'])

# %%
recipes[0].keys()
# Out:
# dict_keys(['id', 'name', 'cuisine', 'servings', 'prep_time', 'cook_time', 'total_time', 'ingredients', 'directions', 'image_description'])

# %%
user_reviews[0].keys()
# Out:
# dict_keys(['reviewId', 'userId', 'itemId', 'title', 'text', 'date', 'rating', 'language', 'images', 'image_captions'])

# %% [markdown]
# ## Initialize embedding models
#
# To support multimodal retrieval, you need to initialize two specialized embedding models.
#
# The system uses:
#
# - **Sentence-Transformers (384-dimensional)** for restaurant text encoding
# - **CLIP image encoder (512-dimensional)** for food image encoding
#
# Both embedding outputs are L2-normalized to support cosine similarity search in later retrieval stages. Using modality-appropriate encoders ensures that semantic similarity is preserved within each vector space.

# %%
! ollama list
# Out:
# ]11;?\NAME                        ID              SIZE      MODIFIED
# llava:latest                8dd30f6b0cb1    4.7 GB    13 days ago
# llama3.2:latest             a80c4f17acd5    2.0 GB    13 days ago
# llama3.2:3b                 a80c4f17acd5    2.0 GB    13 days ago
# gemma4:latest               c6eb396dbd59    9.6 GB    4 months ago
# qwen3.5:27b                 7653528ba5cb    17 GB     5 months ago
# qwen35-uncensored:latest    443fb05972d8    6.7 GB    5 months ago
# deepseek-r1:latest          6995872bfe4c    5.2 GB    5 months ago
# deepseek-r1:8b              6995872bfe4c    5.2 GB    5 months ago
# codestral:latest            0898a8b286d5    12 GB     5 months ago
# devstral-2:latest           524a6607f0f5    74 GB     5 months ago
# qwen3-coder-next:latest     ca06e9e4087c    51 GB     6 months ago
# deepseek-coder:33b          acec7c0b0fd9    18 GB     6 months ago
# qwen3-coder:latest          06c1097efce0    18 GB     6 months ago

# %%
# ================================
# Initialize embedding models
# ================================

# ---- Text embedding model (384-d) ----
text_model = SentenceTransformer("all-MiniLM-L6-v2")

def embed_texts(texts, batch_size=64):
    return text_model.encode(
        texts,
        batch_size=batch_size,
        show_progress_bar=False,
        normalize_embeddings=True,  # cosine-ready
    ).astype(np.float32)

print("✅ Text embedder ready")
# Out:
# /home/zahra/.pyenv/versions/3.10.8/lib/python3.10/site-packages/torch/cuda/__init__.py:188: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12080). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /__w/pytorch/pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ✅ Text embedder ready

# %%
# ---- Image embedding model: SigLIP ----
from transformers import AutoProcessor, AutoModel
device = "cuda" if torch.cuda.is_available() else "cpu"

siglip_name = "google/siglip-base-patch16-224"

siglip_processor = AutoProcessor.from_pretrained(siglip_name)
siglip_model = AutoModel.from_pretrained(siglip_name).to(device)

siglip_model.eval()


@torch.no_grad()
def embed_images(paths, batch_size=16):
    vecs = []

    for i in range(0, len(paths), batch_size):
        batch = paths[i:i + batch_size]

        imgs = [
            Image.open(p).convert("RGB")
            for p in batch
        ]

        inputs = siglip_processor(
            images=imgs,
            return_tensors="pt"
        )

        inputs = {
            k: v.to(device)
            for k, v in inputs.items()
        }

        # Get SigLIP image representations
        outputs = siglip_model.get_image_features(**inputs)

        # Depending on Transformers version, outputs may be
        # a tensor OR BaseModelOutputWithPooling
        if isinstance(outputs, torch.Tensor):
            feats = outputs
        elif hasattr(outputs, "pooler_output"):
            feats = outputs.pooler_output
        elif hasattr(outputs, "last_hidden_state"):
            feats = outputs.last_hidden_state[:, 0]
        else:
            raise TypeError(
                f"Unexpected SigLIP output type: {type(outputs)}"
            )

        # Normalize for cosine similarity
        feats = torch.nn.functional.normalize(
            feats,
            p=2,
            dim=-1
        )

        vecs.append(
            feats.cpu().numpy().astype(np.float32)
        )

    return np.vstack(vecs)


print("✅ SigLIP image embedder ready")
# Out:
# Loading weights:   0%|          | 0/408 [00:00<?, ?it/s]
# ✅ SigLIP image embedder ready

# %% [markdown]
# ## Construct multimodal documents
#
# Vector databases operate on structured documents rather than raw files.
#
# In this step, you'll construct two document sets:
#
# 1. **Article documents** derived from structured restaurant data
# 2. **Image documents** derived from recipe image files
#
# Each document includes:
#
# - Retrieval text (`page_content`)
# - A unique document identifier
# - Metadata fields that enable filtering and constrained search
#
# These multimodal documents form the foundation of the retrieval index and will be embedded in the next stage.

# %%
# ================================
# Build article and image documents
# ================================

# -------- articles --------
article_docs = []

for i, r in enumerate(restaurants):
    name = str(r.get("name", "")).strip()
    if not name:
        continue

    text = (
    f"Restaurant: {name}\n"
    f"Cuisine: {r.get('food_style','')}\n"
    f"Location: {r.get('location','')}"
    )

    # GUARANTEED UNIQUE
    doc_id = f"rest_{i}"

    article_docs.append(
        Document(
            page_content=text.strip(),
            metadata={
                "doc_id": doc_id,
                "cuisine": r.get("food_style"),
                "location": r.get("location"),
                "source": "restaurant",
            },
        )
    )

print("✅ article docs:", len(article_docs))


# -------- images --------
image_docs = []

for i, (p, rec) in enumerate(zip(image_paths, recipes)):
    doc_id = f"img_{i}"

    image_docs.append(
        Document(
            # keeps retrieval results readable
            page_content=rec.get("name", f"recipe image {i}"),
            metadata={
                "doc_id": doc_id,
                "image_path": p,
                "source": "recipe_image",
                "recipe_id": rec.get("id"),
                "cuisine": rec.get("cuisine"),
            },
        )
    )

print("✅ image docs:", len(image_docs))
# Out:
# ✅ article docs: 95
# ✅ image docs: 109

# %% [markdown]
# ## Construct the vector index
#
# You'll now construct the retrieval backbone of the multimodal RAG system.
#
# This step performs the following operations:
#
# 1. Generate embeddings for both text and image documents
# 2. Create separate Chroma collections for each modality
# 3. Store vectors together with their metadata
# 4. Persist the multimodal index to disk for reuse
#
# After this step completes, the system is fully prepared for similarity retrieval and metadata filtering in Lesson 2.

# %%
image_docs
# Out:
# [Document(metadata={'doc_id': 'img_0', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe1.png', 'source': 'recipe_image', 'recipe_id': 1, 'cuisine': 'Italian'}, page_content='Classic Margherita Pizza'),
#  Document(metadata={'doc_id': 'img_1', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe10.png', 'source': 'recipe_image', 'recipe_id': 2, 'cuisine': 'Indian'}, page_content='Chicken Tikka Masala'),
#  Document(metadata={'doc_id': 'img_2', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe100.png', 'source': 'recipe_image', 'recipe_id': 3, 'cuisine': 'Chinese'}, page_content='Vegetable Stir-Fry with Tofu'),
#  Document(metadata={'doc_id': 'img_3', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe101.png', 'source': 'recipe_image', 'recipe_id': 4, 'cuisine': 'Greek'}, page_content='Greek Giouvertsa Salad with Lemon-Oregano Dressing'),
#  Document(metadata={'doc_id': 'img_4', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe102.png', 'source': 'recipe_image', 'recipe_id': 5, 'cuisine': 'Italian'}, page_content='Spaghetti Aglio e Olio'),
#  Document(metadata={'doc_id': 'img_5', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe103.png', 'source': 'recipe_image', 'recipe_id': 6, 'cuisine': 'American'}, page_content='Distance-Glazed Salmon with Dill'),
#  Document(metadata={'doc_id': 'img_6', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe104.png', 'source': 'recipe_image', 'recipe_id': 7, 'cuisine': 'American'}, page_content='Tomato Basil Soup'),
#  Document(metadata={'doc_id': 'img_7', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe105.png', 'source': 'recipe_image', 'recipe_id': 8, 'cuisine': 'Thai'}, page_content='Pad Thai'),
#  Document(metadata={'doc_id': 'img_8', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe106.png', 'source': 'recipe_image', 'recipe_id': 9, 'cuisine': 'Middle Eastern'}, page_content='Chickpea Falafel with Tahini'),
#  Document(metadata={'doc_id': 'img_9', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe107.png', 'source': 'recipe_image', 'recipe_id': 10, 'cuisine': 'Mexican'}, page_content='Beef Tacos with Salsa Verde'),
#  Document(metadata={'doc_id': 'img_10', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe108.png', 'source': 'recipe_image', 'recipe_id': 11, 'cuisine': 'American'}, page_content='Pan-Seared Ribeye Steak'),
#  Document(metadata={'doc_id': 'img_11', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe109.png', 'source': 'recipe_image', 'recipe_id': 12, 'cuisine': 'Indian'}, page_content='Lentil Dal with Cumin and Turmeric'),
#  Document(metadata={'doc_id': 'img_12', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe11.png', 'source': 'recipe_image', 'recipe_id': 13, 'cuisine': 'Japanese'}, page_content='Miso-Glazed Cod with Sesame Rice'),
#  Document(metadata={'doc_id': 'img_13', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe12.png', 'source': 'recipe_image', 'recipe_id': 14, 'cuisine': 'Caribbean'}, page_content='Caribbean Jerk Chicken'),
#  Document(metadata={'doc_id': 'img_14', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe13.png', 'source': 'recipe_image', 'recipe_id': 15, 'cuisine': 'Italian'}, page_content='Roasted Tomato and Basil Pasta'),
#  Document(metadata={'doc_id': 'img_15', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe14.png', 'source': 'recipe_image', 'recipe_id': 16, 'cuisine': 'Indian'}, page_content='Paneer Butter Masala'),
#  Document(metadata={'doc_id': 'img_16', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe15.png', 'source': 'recipe_image', 'recipe_id': 17, 'cuisine': 'Indian'}, page_content='Falooda (Dessert Drink)'),
#  Document(metadata={'doc_id': 'img_17', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe16.png', 'source': 'recipe_image', 'recipe_id': 18, 'cuisine': 'Mediterranean'}, page_content='Shakshuka'),
#  Document(metadata={'doc_id': 'img_18', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe17.png', 'source': 'recipe_image', 'recipe_id': 19, 'cuisine': 'Cuban'}, page_content='Cuban Black Beans and Rice'),
#  Document(metadata={'doc_id': 'img_19', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe18.png', 'source': 'recipe_image', 'recipe_id': 20, 'cuisine': 'Korean'}, page_content='Beef Bulgogi'),
#  Document(metadata={'doc_id': 'img_20', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe19.png', 'source': 'recipe_image', 'recipe_id': 21, 'cuisine': 'Spanish'}, page_content='Spanish Paella Valenciana'),
#  Document(metadata={'doc_id': 'img_21', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe2.png', 'source': 'recipe_image', 'recipe_id': 22, 'cuisine': 'Thai'}, page_content='Tom Yum Goong'),
#  Document(metadata={'doc_id': 'img_22', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe20.png', 'source': 'recipe_image', 'recipe_id': 23, 'cuisine': 'American'}, page_content='Chicken Caesar Salad'),
#  Document(metadata={'doc_id': 'img_23', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe21.png', 'source': 'recipe_image', 'recipe_id': 24, 'cuisine': 'Greek'}, page_content='Moussaka'),
#  Document(metadata={'doc_id': 'img_24', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe22.png', 'source': 'recipe_image', 'recipe_id': 25, 'cuisine': 'Japanese'}, page_content='Shoyu Ramen (Quick)'),
#  Document(metadata={'doc_id': 'img_25', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe23.png', 'source': 'recipe_image', 'recipe_id': 26, 'cuisine': 'Italian'}, page_content='Lemon Garlic Shrimp Pasta'),
#  Document(metadata={'doc_id': 'img_26', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe24.png', 'source': 'recipe_image', 'recipe_id': 27, 'cuisine': 'French'}, page_content='Ratatouille'),
#  Document(metadata={'doc_id': 'img_27', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe25.png', 'source': 'recipe_image', 'recipe_id': 28, 'cuisine': 'Scandinavian'}, page_content='Crispy Skin Salmon with Dill Yogurt'),
#  Document(metadata={'doc_id': 'img_28', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe26.png', 'source': 'recipe_image', 'recipe_id': 29, 'cuisine': 'Thai'}, page_content='Thai Green Curry with Vegetables'),
#  Document(metadata={'doc_id': 'img_29', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe27.png', 'source': 'recipe_image', 'recipe_id': 30, 'cuisine': 'Thai'}, page_content='Mango Sticky Rice'),
#  Document(metadata={'doc_id': 'img_30', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe28.png', 'source': 'recipe_image', 'recipe_id': 31, 'cuisine': 'American'}, page_content='Herbed Quinoa Salad'),
#  Document(metadata={'doc_id': 'img_31', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe29.png', 'source': 'recipe_image', 'recipe_id': 32, 'cuisine': 'Middle Eastern'}, page_content='Beef Shawarma Wrap'),
#  Document(metadata={'doc_id': 'img_32', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe3.png', 'source': 'recipe_image', 'recipe_id': 33, 'cuisine': 'Italian'}, page_content='Pesto Chicken Bake'),
#  Document(metadata={'doc_id': 'img_33', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe30.png', 'source': 'recipe_image', 'recipe_id': 34, 'cuisine': 'Italian'}, page_content='Baked Eggplant Parmesan'),
#  Document(metadata={'doc_id': 'img_34', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe31.png', 'source': 'recipe_image', 'recipe_id': 35, 'cuisine': 'Moroccan'}, page_content='Moroccan Chickpea Stew'),
#  Document(metadata={'doc_id': 'img_35', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe32.png', 'source': 'recipe_image', 'recipe_id': 36, 'cuisine': 'American'}, page_content='Crunchy Cabbage Slaw'),
#  Document(metadata={'doc_id': 'img_36', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe33.png', 'source': 'recipe_image', 'recipe_id': 37, 'cuisine': 'Peruvian'}, page_content='Ceviche de Pescado'),
#  Document(metadata={'doc_id': 'img_37', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe34.png', 'source': 'recipe_image', 'recipe_id': 38, 'cuisine': 'Thai'}, page_content='Thai Basil Chicken (Pad Krapow Gai)'),
#  Document(metadata={'doc_id': 'img_38', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe35.png', 'source': 'recipe_image', 'recipe_id': 39, 'cuisine': 'Italian'}, page_content='Caprese Salad'),
#  Document(metadata={'doc_id': 'img_39', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe36.png', 'source': 'recipe_image', 'recipe_id': 40, 'cuisine': 'Italian'}, page_content='Pumpkin Risotto'),
#  Document(metadata={'doc_id': 'img_40', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe37.png', 'source': 'recipe_image', 'recipe_id': 41, 'cuisine': 'American'}, page_content='Garlic Butter Shrimp'),
#  Document(metadata={'doc_id': 'img_41', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe38.png', 'source': 'recipe_image', 'recipe_id': 42, 'cuisine': 'Middle Eastern'}, page_content='Roasted Red Pepper Hummus'),
#  Document(metadata={'doc_id': 'img_42', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe39.png', 'source': 'recipe_image', 'recipe_id': 43, 'cuisine': 'Indian'}, page_content='Garlic Naan'),
#  Document(metadata={'doc_id': 'img_43', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe4.png', 'source': 'recipe_image', 'recipe_id': 44, 'cuisine': 'Indian'}, page_content='Butter Chicken'),
#  Document(metadata={'doc_id': 'img_44', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe40.png', 'source': 'recipe_image', 'recipe_id': 45, 'cuisine': 'Indian'}, page_content='Coconut Curry Lentil Soup'),
#  Document(metadata={'doc_id': 'img_45', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe41.png', 'source': 'recipe_image', 'recipe_id': 46, 'cuisine': 'Greek'}, page_content='Gyro Wrap'),
#  Document(metadata={'doc_id': 'img_46', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe42.png', 'source': 'recipe_image', 'recipe_id': 47, 'cuisine': 'Peruvian'}, page_content='Pollo a la Brasa (Peruvian Roast Chicken)'),
#  Document(metadata={'doc_id': 'img_47', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe43.png', 'source': 'recipe_image', 'recipe_id': 48, 'cuisine': 'American'}, page_content='Mango Salsa Chicken'),
#  Document(metadata={'doc_id': 'img_48', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe44.png', 'source': 'recipe_image', 'recipe_id': 49, 'cuisine': 'Vietnamese'}, page_content='Rice Paper Rolls with Peanut Dip'),
#  Document(metadata={'doc_id': 'img_49', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe45.png', 'source': 'recipe_image', 'recipe_id': 50, 'cuisine': 'Mexican'}, page_content='Beef Nachos'),
#  Document(metadata={'doc_id': 'img_50', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe46.png', 'source': 'recipe_image', 'recipe_id': 51, 'cuisine': 'Mediterranean'}, page_content='Herbed Chicken Skewers'),
#  Document(metadata={'doc_id': 'img_51', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe47.png', 'source': 'recipe_image', 'recipe_id': 52, 'cuisine': 'Caribbean'}, page_content='Coconut Shrimp Curry'),
#  Document(metadata={'doc_id': 'img_52', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe48.png', 'source': 'recipe_image', 'recipe_id': 53, 'cuisine': 'Italian'}, page_content='Herbed Mushroom Risotto'),
#  Document(metadata={'doc_id': 'img_53', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe49.png', 'source': 'recipe_image', 'recipe_id': 54, 'cuisine': 'American'}, page_content='Lemon Ricotta Pancakes'),
#  Document(metadata={'doc_id': 'img_54', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe5.png', 'source': 'recipe_image', 'recipe_id': 55, 'cuisine': 'Chinese'}, page_content='Egg Fried Rice'),
#  Document(metadata={'doc_id': 'img_55', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe50.png', 'source': 'recipe_image', 'recipe_id': 56, 'cuisine': 'Japanese'}, page_content='Okonomiyaki (Japanese Pancake)'),
#  Document(metadata={'doc_id': 'img_56', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe51.png', 'source': 'recipe_image', 'recipe_id': 57, 'cuisine': 'Italian'}, page_content='Herb-Ceta Pasta with Lemon'),
#  Document(metadata={'doc_id': 'img_57', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe52.png', 'source': 'recipe_image', 'recipe_id': 58, 'cuisine': 'Caribbean'}, page_content='Coconut Rice with Beans'),
#  Document(metadata={'doc_id': 'img_58', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe53.png', 'source': 'recipe_image', 'recipe_id': 59, 'cuisine': 'Mediterranean'}, page_content='Baked Cod with Tomato and Olive'),
#  Document(metadata={'doc_id': 'img_59', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe54.png', 'source': 'recipe_image', 'recipe_id': 60, 'cuisine': 'French'}, page_content='Seared Tuna Niçoise'),
#  Document(metadata={'doc_id': 'img_60', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe55.png', 'source': 'recipe_image', 'recipe_id': 61, 'cuisine': 'Moroccan'}, page_content='Harissa Chickpea Bowl'),
#  Document(metadata={'doc_id': 'img_61', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe56.png', 'source': 'recipe_image', 'recipe_id': 62, 'cuisine': 'Nordic'}, page_content='Salmon with Dill and Mustard Glaze'),
#  Document(metadata={'doc_id': 'img_62', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe57.png', 'source': 'recipe_image', 'recipe_id': 63, 'cuisine': 'American'}, page_content='Butter Lettuce Salad with Avocado'),
#  Document(metadata={'doc_id': 'img_63', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe58.png', 'source': 'recipe_image', 'recipe_id': 64, 'cuisine': 'Italian'}, page_content='Eggplant Caponata'),
#  Document(metadata={'doc_id': 'img_64', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe59.png', 'source': 'recipe_image', 'recipe_id': 65, 'cuisine': 'American'}, page_content='Avocado Toast with Poached Egg'),
#  Document(metadata={'doc_id': 'img_65', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe6.png', 'source': 'recipe_image', 'recipe_id': 66, 'cuisine': 'American'}, page_content='Herbed Tomato Soup'),
#  Document(metadata={'doc_id': 'img_66', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe60.png', 'source': 'recipe_image', 'recipe_id': 67, 'cuisine': 'Italian'}, page_content='Pesto Gnocchi with Cherry Tomatoes'),
#  Document(metadata={'doc_id': 'img_67', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe61.png', 'source': 'recipe_image', 'recipe_id': 68, 'cuisine': 'Indian'}, page_content='Paneer Butter Fry'),
#  Document(metadata={'doc_id': 'img_68', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe62.png', 'source': 'recipe_image', 'recipe_id': 69, 'cuisine': 'American'}, page_content='Lemon Garlic Roasted Brussels Sprouts'),
#  Document(metadata={'doc_id': 'img_69', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe63.png', 'source': 'recipe_image', 'recipe_id': 70, 'cuisine': 'Indian'}, page_content='Paneer Tarsi with Spinach'),
#  Document(metadata={'doc_id': 'img_70', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe64.png', 'source': 'recipe_image', 'recipe_id': 71, 'cuisine': 'Indonesian'}, page_content='Rendang Beef'),
#  Document(metadata={'doc_id': 'img_71', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe65.png', 'source': 'recipe_image', 'recipe_id': 72, 'cuisine': 'American'}, page_content='Chili Con Carne'),
#  Document(metadata={'doc_id': 'img_72', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe66.png', 'source': 'recipe_image', 'recipe_id': 73, 'cuisine': 'Persian'}, page_content='Persian Jeweled Rice'),
#  Document(metadata={'doc_id': 'img_73', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe67.png', 'source': 'recipe_image', 'recipe_id': 74, 'cuisine': 'Moroccan'}, page_content='Moroccan Lentil Soup (Harira)'),
#  Document(metadata={'doc_id': 'img_74', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe68.png', 'source': 'recipe_image', 'recipe_id': 75, 'cuisine': 'Thai'}, page_content='Thai Red Curry with Chicken'),
#  Document(metadata={'doc_id': 'img_75', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe69.png', 'source': 'recipe_image', 'recipe_id': 76, 'cuisine': 'Italian'}, page_content='Pasta Arrabbiata'),
#  Document(metadata={'doc_id': 'img_76', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe7.png', 'source': 'recipe_image', 'recipe_id': 77, 'cuisine': 'American'}, page_content='Cranberry Walnut Salad'),
#  Document(metadata={'doc_id': 'img_77', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe70.png', 'source': 'recipe_image', 'recipe_id': 78, 'cuisine': 'American'}, page_content='Corn Chowder'),
#  Document(metadata={'doc_id': 'img_78', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe71.png', 'source': 'recipe_image', 'recipe_id': 79, 'cuisine': 'Japanese'}, page_content='Eggplant Yakitori Skewers'),
#  Document(metadata={'doc_id': 'img_79', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe72.png', 'source': 'recipe_image', 'recipe_id': 80, 'cuisine': 'Indian'}, page_content='Chana Masala'),
#  Document(metadata={'doc_id': 'img_80', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe73.png', 'source': 'recipe_image', 'recipe_id': 81, 'cuisine': 'American'}, page_content='Buttermilk Pancakes'),
#  Document(metadata={'doc_id': 'img_81', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe74.png', 'source': 'recipe_image', 'recipe_id': 82, 'cuisine': 'Indian'}, page_content='Mango Lassi'),
#  Document(metadata={'doc_id': 'img_82', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe75.png', 'source': 'recipe_image', 'recipe_id': 83, 'cuisine': 'Italian'}, page_content='Pesto Pasta with Sun-Dried Tomatoes'),
#  Document(metadata={'doc_id': 'img_83', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe76.png', 'source': 'recipe_image', 'recipe_id': 84, 'cuisine': 'American'}, page_content='Salisbury Steak with Mushroom Gravy'),
#  Document(metadata={'doc_id': 'img_84', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe77.png', 'source': 'recipe_image', 'recipe_id': 85, 'cuisine': 'American'}, page_content='Simple Garlic Herb Salmon'),
#  Document(metadata={'doc_id': 'img_85', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe78.png', 'source': 'recipe_image', 'recipe_id': 86, 'cuisine': 'Italian'}, page_content='Gnocchi with Sage Butter'),
#  Document(metadata={'doc_id': 'img_86', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe79.png', 'source': 'recipe_image', 'recipe_id': 87, 'cuisine': 'Mexican'}, page_content='Shredded Beef Tostadas'),
#  Document(metadata={'doc_id': 'img_87', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe8.png', 'source': 'recipe_image', 'recipe_id': 88, 'cuisine': 'Mexican'}, page_content='Chili Lime Grilled Corn'),
#  Document(metadata={'doc_id': 'img_88', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe80.png', 'source': 'recipe_image', 'recipe_id': 89, 'cuisine': 'Indian/Global'}, page_content='Herbed Rice with Peas'),
#  Document(metadata={'doc_id': 'img_89', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe81.png', 'source': 'recipe_image', 'recipe_id': 90, 'cuisine': 'Indonesian'}, page_content='Gulai Ayam (Indonesian Curry Chicken)'),
#  Document(metadata={'doc_id': 'img_90', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe82.png', 'source': 'recipe_image', 'recipe_id': 91, 'cuisine': 'Thai/Chinese Fusion'}, page_content='Spicy Peanut Noodles'),
#  Document(metadata={'doc_id': 'img_91', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe83.png', 'source': 'recipe_image', 'recipe_id': 92, 'cuisine': 'French'}, page_content='Herbed Quiche'),
#  Document(metadata={'doc_id': 'img_92', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe84.png', 'source': 'recipe_image', 'recipe_id': 93, 'cuisine': 'Italian'}, page_content='Baked Ziti'),
#  Document(metadata={'doc_id': 'img_93', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe85.png', 'source': 'recipe_image', 'recipe_id': 94, 'cuisine': 'American'}, page_content='Herbed Shrimp and Grits'),
#  Document(metadata={'doc_id': 'img_94', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe86.png', 'source': 'recipe_image', 'recipe_id': 95, 'cuisine': 'French'}, page_content='Duck Confit (Simple Version)'),
#  Document(metadata={'doc_id': 'img_95', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe87.png', 'source': 'recipe_image', 'recipe_id': 96, 'cuisine': 'Mediterranean'}, page_content='Lemon Olive Oil Cake'),
#  Document(metadata={'doc_id': 'img_96', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe88.png', 'source': 'recipe_image', 'recipe_id': 97, 'cuisine': 'Moroccan'}, page_content='Salsa Verde Chicken Tajine'),
#  Document(metadata={'doc_id': 'img_97', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe89.png', 'source': 'recipe_image', 'recipe_id': 98, 'cuisine': 'Thai/Caribbean Fusion'}, page_content='Coconut Lime Chicken'),
#  Document(metadata={'doc_id': 'img_98', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe9.png', 'source': 'recipe_image', 'recipe_id': 99, 'cuisine': 'Mediterranean'}, page_content='Spinach and Feta Stuffed Peppers'),
#  Document(metadata={'doc_id': 'img_99', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe90.png', 'source': 'recipe_image', 'recipe_id': 100, 'cuisine': 'Indonesian'}, page_content='Gado-Gado (Indonesian Peanut Salad)'),
#  Document(metadata={'doc_id': 'img_100', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe91.png', 'source': 'recipe_image', 'recipe_id': 101, 'cuisine': 'Chinese (Szechuan)'}, page_content='Kung Pao Chicken'),
#  Document(metadata={'doc_id': 'img_101', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe92.png', 'source': 'recipe_image', 'recipe_id': 102, 'cuisine': 'Chinese (Szechuan)'}, page_content='Mapo Tofu'),
#  Document(metadata={'doc_id': 'img_102', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe93.png', 'source': 'recipe_image', 'recipe_id': 103, 'cuisine': 'Chinese (Cantonese)'}, page_content='Beef and Broccoli'),
#  Document(metadata={'doc_id': 'img_103', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe94.png', 'source': 'recipe_image', 'recipe_id': 104, 'cuisine': 'Chinese-American'}, page_content="General Tso's Chicken"),
#  Document(metadata={'doc_id': 'img_104', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe95.png', 'source': 'recipe_image', 'recipe_id': 105, 'cuisine': 'Chinese'}, page_content='Pork Potstickers (Dumplings)'),
#  Document(metadata={'doc_id': 'img_105', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe96.png', 'source': 'recipe_image', 'recipe_id': 106, 'cuisine': 'Chinese'}, page_content='Hot and Sour Soup'),
#  Document(metadata={'doc_id': 'img_106', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe97.png', 'source': 'recipe_image', 'recipe_id': 107, 'cuisine': 'Chinese'}, page_content='Chow Mein'),
#  Document(metadata={'doc_id': 'img_107', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe98.png', 'source': 'recipe_image', 'recipe_id': 108, 'cuisine': 'Chinese (Cantonese)'}, page_content='Wonton Soup'),
#  Document(metadata={'doc_id': 'img_108', 'image_path': 'data/recipe_images/synthetic_recipe_images/recipe99.png', 'source': 'recipe_image', 'recipe_id': 109, 'cuisine': 'Chinese (Hong Kong Style)'}, page_content='Honey Walnut Shrimp')]

# %%
# ================================
# Construct and Persist Multimodal Vector Indexes
# ================================

DB_DIR = str((Path.home() / "chroma_multimodal").resolve())

if os.path.isdir(DB_DIR):
    shutil.rmtree(DB_DIR)  # Reset vector DB (important for reruns)

# ----- article DB -----
A = embed_texts([d.page_content for d in article_docs])

article_db = Chroma(
    collection_name="restaurant_articles",
    persist_directory=DB_DIR,
)

article_db._collection.upsert(
    ids=[d.metadata["doc_id"] for d in article_docs],
    embeddings=A.tolist(),
    documents=[d.page_content for d in article_docs],
    metadatas=[d.metadata for d in article_docs],
)

print("✅ Article DB ready")
# Out:
# ✅ Article DB ready

# %%
# ----- image DB -----

V = embed_images(
    [d.metadata["image_path"] for d in image_docs]
)

print("Image embedding shape:", V.shape)
print("Image embedding dtype:", V.dtype)

image_db = Chroma(
    collection_name="food_images",
    persist_directory=DB_DIR,
)

image_db._collection.upsert(
    ids=[d.metadata["doc_id"] for d in image_docs],
    embeddings=V.tolist(),
    documents=[d.page_content for d in image_docs],
    metadatas=[d.metadata for d in image_docs],
)

print("✅ Image DB ready")
print("🎉 Multimodal Vector Index Construction COMPLETE")
# Out:
# Image embedding shape: (109, 768)
# Image embedding dtype: float32
# ✅ Image DB ready
# 🎉 Multimodal Vector Index Construction COMPLETE

# %% [markdown]
# ### 📸 Screenshot Submission Requirement
#
# At the end of this lab, take a screenshot of the final code cell and its output, and name it **M2L1_multimodal_vector_index.jpg**.
#
# Your screenshot must clearly show:
# - Successful creation of both Chroma collections:
#   - `restaurant_articles`
#   - `food_images`
# - The final completion message:
#   **"Multimodal Vector Index Construction COMPLETE"**
#
# This screenshot will later serve as a component for the assessment.

# %% [markdown]
# ## Conclusion
#
# In this lab, you built the multimodal retrieval foundation for the restaurant RAG system. You converted structured restaurant data and food images into retrieval-ready documents, generated embeddings, and constructed persistent vector indexes using Chroma.
#
# The multimodal index is now prepared for similarity search and metadata filtering.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Zikai Dou](https://author.skills.network/instructors/zikai_dou)

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
