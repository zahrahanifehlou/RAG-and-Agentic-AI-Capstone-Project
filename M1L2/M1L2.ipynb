# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Lab: Process Multimodal Data with LLMs**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## **Scenario**

# %% [markdown]
# ### **Background**
#
# You transformed unstructured restaurant descriptions into a structured JSON knowledge base using LLMs. This allowed the app to reason over textual attributes such as cuisine type, pricing, and signature dishes in a consistent, machine-readable format.
#
# However, the app’s data is not limited to text. It also includes **food recipes** and **user visit histories** that reference **images**, capturing visual information that text alone cannot fully describe, such as presentation style, ingredients, and portion details. To unlock this information and integrate it with the original databases, you will use multimodal GenAI capabilities to convert images into descriptive text and enrich the structured knowledge you have.
#
#
# ### **The challenge**
#
# Images are inherently unstructured and cannot be directly stored or queried in a text-based knowledge system. To make them usable, you must first **generate high-quality textual descriptions** that summarize the visual content of each image.
#
# Your challenge in this lab is to:
#
# * Apply image captioning to generate descriptive text for food images
# * Align and merge image captions with the corresponding recipe and restaurant JSON records
# * Extend the existing structured knowledge base with multimodal context while preserving a consistent schema
#
# By the end of this lab, you will have enriched your restaurant knowledge base with visual insights. You will bridge text and images into a unified, machine-accessible representation, setting the stage for more intelligent multimodal reasoning in later assignments.

# %% [markdown]
# ## **Objectives**
#
# In this lab, you will write a Python program that will:
#
# * Load food recipe and user visit data containing image references
# * Use a multimodal foundation model to generate textual captions for food images
# * Integrate the generated image captions into the existing structured JSON data
# * Produce an enriched multimodal JSON knowledge file for downstream applications

# %% [markdown]
# ## **Important: About the lab environment**

# %% [markdown]
# Please be aware that sessions for this lab environment are not persisted. Every time you connect to this lab, a new environment is created for you. Any data you may have saved in the earlier session would get lost. Plan to complete these labs in a single session, to avoid losing your data.

# %% [markdown]
# ## **Screenshot requirement for this lab**

# %% [markdown]
# You will be prompted to take a screenshot and save it on your own device. You will need this screenshot either to answer graded quiz questions or to upload as your submission for the Final Project at the end of this course. You can use various free screen-grabbing tools or your operating system's shortcut keys to do this (for example, `Alt+PrintScreen` on Windows and `Command+shift+4` on Mac).
# **Note**: The screenshot can be saved with either the **.jpg** or **.png** extension.

# %% [markdown]
# ----

# %% [markdown]
# ## **Set up the lab environment**

# %% [markdown]
# For this lab, you will still be using the following libraries:
#
# * [`numpy`](https://numpy.org/) for numerical operations and handling array-based data during preprocessing and analysis
#
# * [`matplotlib`](https://matplotlib.org/) for basic data visualization and plotting, useful for inspecting distributions or intermediate results
#
# * [`json`](https://docs.python.org/3/library/json.html) for parsing, constructing, and serializing structured JSON representations extracted from unstructured text
#
# * **IBM watsonx AI SDK** (`ibm-watsonx-ai`) for interacting with foundation models hosted on IBM watsonx.ai:
#
#   * `Credentials` to securely authenticate with the watsonx.ai service
#   * `ModelInference` to invoke foundation models for text understanding and information extraction
#   * `GenTextParamsMetaNames` to configure text generation and extraction parameters
#   * `ModelTypes` and `DecodingMethods` to select the appropriate model and control inference behavior
#
# These libraries together enable you to transform images into text-based data using GenAI-powered workflows.

# %% [markdown]
# ### Installing required libraries
#
# Run the following code block to install all required libraries:

# %%
# %%capture
# %pip install numpy==2.3.4
# %pip install matplotlib==3.10.7
# %pip install ibm-watsonx-ai==1.4.7

# %% [markdown]
# ### Importing required libraries
#
# It is recommended to import all required libraries in one place (here):

# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import os
from PIL import Image

# # IBM WatsonX imports
# from ibm_watsonx_ai import Credentials
# from ibm_watsonx_ai.foundation_models import ModelInference
# from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
# from ibm_watsonx_ai.foundation_models.utils.enums import (
#     ModelTypes,
#     DecodingMethods,
# )

# Libraries and codes to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Fetch the data file
#
# Run the following code to fetch the food recipe, user visit history, and recipe images.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/hpTjb6liKBLVHQK0UgMi5A/Recipes.json
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/fQUs9wQ6aB6ts6fmkD2V2w/Synthetic-User-Reviews.json
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/5_Rr6ohviItzucyWk6nkrw/synthetic-recipe-images.zip

# %% [markdown]
# Run the following code to unzip the image folder:

# %%
import zipfile

with zipfile.ZipFile("../data/synthetic-recipe-images.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %% [markdown]
# ----

# %% [markdown]
# ## **Exercise 1: Preprocess the food reciepe data**

# %% [markdown]
# ### Step 1: Explore the food recipe JSON File and its images
#
# Before applying any multimodal processing, it is important to understand the structure and contents of the data you will be working with. In this step, you will load the food recipe JSON file and examine its fields, including textual metadata and image references.
#
# You will also inspect a sample of the associated food images to understand the visual information they contain, such as ingredients, presentation style, and portion size. This exploration step helps you identify how the image data aligns with recipe metadata and prepares you for integrating image captions into the existing JSON structure in later steps.
#
# By the end of this step, you should have a clear understanding of how the recipe data and images are organized, and how they relate to the structured restaurant knowledge built in the previous lesson.

# %%
### Your Code Here
### Step 1.1: Load the json file. Define the loaded data as recipe_data.
with open("../data/Recipes.json") as f:
    recipe_data=json.load(f)

### Step 1.2: Print each key-value pair of the first recipe. In this format: key (type of value): value
print(recipe_data[0].keys())

### Step 1.3: Show the image of the first recipe (recipe1)
from IPython.display import Image, display

display(Image(filename="../data/synthetic_recipe_images/recipe1.png"))
# Out:
# dict_keys(['id', 'name', 'cuisine', 'servings', 'prep_time', 'cook_time', 'total_time', 'ingredients', 'directions'])

# %%
recipe_data
# Out:
# [{'id': 1,
#   'name': 'Classic Margherita Pizza',
#   'cuisine': 'Italian',
#   'servings': 2,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['1 pizza dough ball (about 260g)',
#    '2 tablespoons tomato sauce',
#    '1 cup shredded mozzarella cheese',
#    '6-8 fresh basil leaves',
#    '1 tablespoon olive oil',
#    'pinch of salt',
#    'optional: grated parmesan'],
#   'directions': ['Preheat oven to 250°C (482°F) with a baking stone if available.',
#    'Roll out dough to a 12-inch circle on a floured surface.',
#    'Spread tomato sauce evenly over dough, leaving a 1/2-inch border.',
#    'Scatter mozzarella cheese over sauce.',
#    'Bake on the stone for 10-12 minutes until crust is crisp and cheese melts.',
#    'Finish with basil leaves, drizzle with olive oil, and season with salt and optional parmesan.',
#    'Slice and serve immediately.']},
#  {'id': 2,
#   'name': 'Chicken Tikka Masala',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '25 mins',
#   'cook_time': '40 mins',
#   'total_time': '1 hour 5 mins',
#   'ingredients': ['500g boneless chicken thighs, cubed',
#    '1 cup yogurt',
#    '2 tablespoons lemon juice',
#    '2 teaspoons garam masala',
#    '1 teaspoon ground cumin',
#    '1 teaspoon ground coriander',
#    '1 onion, minced',
#    '2 cloves garlic, minced',
#    '1 tablespoon grated ginger',
#    '1 can (400g) crushed tomatoes',
#    '1 cup heavy cream or coconut cream',
#    '2 tablespoons oil',
#    'Salt to taste',
#    'Fresh cilantro for garnish'],
#   'directions': ['Marinate chicken in yogurt, lemon juice, garam masala, cumin, coriander, and a pinch of salt for at least 30 minutes.',
#    'In a large pan, heat oil and sauté onion until translucent.',
#    'Add garlic and ginger; cook 1 minute until fragrant.',
#    'Add marinated chicken; cook until browned on all sides.',
#    'Stir in crushed tomatoes and simmer 15 minutes.',
#    'Reduce heat and add cream; simmer 5-10 minutes until sauce thickens.',
#    'Garnish with cilantro and serve with rice or naan.']},
#  {'id': 3,
#   'name': 'Vegetable Stir-Fry with Tofu',
#   'cuisine': 'Chinese',
#   'servings': 3,
#   'prep_time': '15 mins',
#   'cook_time': '12 mins',
#   'total_time': '27 mins',
#   'ingredients': ['200g firm tofu, cubed',
#    '1 tablespoon soy sauce',
#    '1 tablespoon cornstarch',
#    '2 tablespoons vegetable oil',
#    '1 cup broccoli florets',
#    '1 red bell pepper, sliced',
#    '1 carrot, julienned',
#    '1 cup snap peas',
#    '2 cloves garlic, minced',
#    '1 tablespoon rice vinegar',
#    '1 tablespoon hoisin sauce',
#    '1 teaspoon sesame oil'],
#   'directions': ['Toss tofu with soy sauce and cornstarch.',
#    'Heat oil in a wok or large skillet over high heat.',
#    'Fry tofu until golden; remove and set aside.',
#    'Add garlic and vegetables; stir-fry 3-4 minutes until crisp-tender.',
#    'Return tofu to pan; add rice vinegar, hoisin sauce, and sesame oil.',
#    'Cook 1-2 minutes until coated; serve with steamed rice.']},
#  {'id': 4,
#   'name': 'Greek Giouvertsa Salad with Lemon-Oregano Dressing',
#   'cuisine': 'Greek',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '0 mins',
#   'total_time': '15 mins',
#   'ingredients': ['2 cups chopped romaine',
#    '1 cucumber, diced',
#    '1 cup cherry tomatoes, halved',
#    '1/2 red onion, thinly sliced',
#    '1/2 cup Kalamata olives',
#    '1/2 cup feta cheese, crumbled',
#    '2 tablespoons olive oil',
#    '1 tablespoon lemon juice',
#    '1 teaspoon dried oregano',
#    'Salt and pepper to taste'],
#   'directions': ['Toss romaine, cucumber, tomatoes, onion, olives, and feta in a bowl.',
#    'Whisk olive oil, lemon juice, oregano, salt, and pepper to make dressing.',
#    'Pour dressing over the salad and toss to combine.',
#    'Serve immediately.']},
#  {'id': 5,
#   'name': 'Spaghetti Aglio e Olio',
#   'cuisine': 'Italian',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['200g spaghetti',
#    '4 cloves garlic, thinly sliced',
#    '1/2 teaspoon red pepper flakes',
#    '1/4 cup olive oil',
#    'Fresh parsley, chopped',
#    'Salt to taste',
#    'Grated parmesan to serve'],
#   'directions': ['Cook spaghetti in salted water until al dente; reserve 1/2 cup pasta water.',
#    'Heat olive oil in a pan; add garlic and red pepper flakes, cook until fragrant and lightly golden.',
#    'Toss pasta with garlic oil, adding reserve water as needed.',
#    'Season, mix in parsley, and serve with parmesan.']},
#  {'id': 6,
#   'name': 'Distance-Glazed Salmon with Dill',
#   'cuisine': 'American',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '12 mins',
#   'total_time': '22 mins',
#   'ingredients': ['2 salmon fillets',
#    '2 tablespoons honey',
#    '1 tablespoon soy sauce',
#    '1 tablespoon Dijon mustard',
#    '1 tablespoon fresh dill, chopped',
#    'Salt and pepper to taste'],
#   'directions': ['Preheat oven to 200°C (400°F).',
#    'Mix honey, soy sauce, mustard, and dill.',
#    'Season salmon with salt and pepper; brush with glaze.',
#    'Bake 10-12 minutes until flaky; drizzle remaining glaze over and serve.']},
#  {'id': 7,
#   'name': 'Tomato Basil Soup',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '25 mins',
#   'total_time': '35 mins',
#   'ingredients': ['1 tablespoon olive oil',
#    '1 onion, chopped',
#    '2 cloves garlic, minced',
#    '2 cans (400g each) crushed tomatoes',
#    '1 cup vegetable broth',
#    '1/2 cup cream or coconut milk',
#    'Fresh basil, torn',
#    'Salt and pepper to taste'],
#   'directions': ['Sauté onion and garlic in olive oil until translucent.',
#    'Add crushed tomatoes and broth; simmer 15 minutes.',
#    'Blend until smooth or leave chunky based on preference.',
#    'Stir in cream and basil; season to taste and serve.']},
#  {'id': 8,
#   'name': 'Pad Thai',
#   'cuisine': 'Thai',
#   'servings': 2,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['150g rice noodles',
#    '2 tablespoons tamarind paste',
#    '2 tablespoons fish sauce',
#    '1 tablespoon palm sugar or brown sugar',
#    '2 eggs',
#    '200g shrimp or chicken',
#    '1 cup bean sprouts',
#    '2 cloves garlic, minced',
#    '1 lime, cut into wedges',
#    '1/4 cup roasted peanuts, chopped',
#    '1 tablespoon oil',
#    'Chili flakes (optional)'],
#   'directions': ['Prepare noodles according to package; drain and set aside.',
#    'Mix tamarind paste, fish sauce, and sugar to make sauce.',
#    'Sauté garlic in oil; add shrimp or chicken and cook through.',
#    'Push meat aside, scramble eggs in the pan, then mix with noodles.',
#    'Add sauce and bean sprouts; toss quickly.',
#    'Garnish with peanuts, lime wedges, and chili flakes if desired.']},
#  {'id': 9,
#   'name': 'Chickpea Falafel with Tahini',
#   'cuisine': 'Middle Eastern',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['2 cups cooked chickpeas',
#    '1 small onion, chopped',
#    '2 cloves garlic',
#    '1/4 cup fresh parsley',
#    '2 tablespoons flour',
#    '1 teaspoon cumin',
#    '1/2 teaspoon coriander',
#    'Salt and pepper',
#    'Oil for frying',
#    'Tahini sauce: 1/4 cup tahini, lemon juice, water'],
#   'directions': ['Pulse chickpeas, onion, garlic, parsley, flour, and spices until coarse.',
#    'Form into small patties or balls.',
#    'Fry in hot oil until golden and crisp.',
#    'Whisk tahini with lemon juice and water to desired consistency.',
#    'Serve falafel with tahini sauce.']},
#  {'id': 10,
#   'name': 'Beef Tacos with Salsa Verde',
#   'cuisine': 'Mexican',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['400g ground beef',
#    '1 packet taco seasoning',
#    '8 corn tortillas',
#    '1 cup salsa verde',
#    'Shredded lettuce',
#    'Chopped tomatoes',
#    'Grated cheddar or Mexican cheese',
#    'Sour cream (optional)'],
#   'directions': ['Cook beef with taco seasoning until browned.',
#    'Warm tortillas in a dry skillet.',
#    'Fill tortillas with beef, lettuce, tomatoes, and cheese.',
#    'Top with salsa verde and sour cream if desired.']},
#  {'id': 11,
#   'name': 'Pan-Seared Ribeye Steak',
#   'cuisine': 'American',
#   'servings': 2,
#   'prep_time': '5 mins',
#   'cook_time': '10 mins',
#   'total_time': '15 mins',
#   'ingredients': ['2 ribeye steaks (1 inch thick)',
#    'Salt and pepper',
#    '2 tablespoons butter',
#    '2 cloves garlic, smashed',
#    'Fresh thyme sprigs'],
#   'directions': ['Season steaks with salt and pepper.',
#    'Sear in a hot pan with butter until desired doneness (about 4-5 minutes per side for medium-rare).',
#    'Add garlic and thyme during the last minute, spooning butter over steaks.',
#    'Rest 5 minutes before serving.']},
#  {'id': 12,
#   'name': 'Lentil Dal with Cumin and Turmeric',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '25 mins',
#   'total_time': '35 mins',
#   'ingredients': ['1 cup red lentils',
#    '1 small onion, chopped',
#    '2 cloves garlic, minced',
#    '1 teaspoon ground cumin',
#    '1/2 teaspoon turmeric',
#    '1 teaspoon salt',
#    '2 cups water',
#    '1 tablespoon oil',
#    'Fresh cilantro for garnish'],
#   'directions': ['Rinse lentils until water runs clear.',
#    'Sauté onion and garlic in oil until soft.',
#    'Add cumin and turmeric, cook 1 minute.',
#    'Add lentils and water; simmer 20-25 minutes until soft.',
#    'Season and garnish with cilantro.']},
#  {'id': 13,
#   'name': 'Miso-Glazed Cod with Sesame Rice',
#   'cuisine': 'Japanese',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '15 mins',
#   'total_time': '30 mins',
#   'ingredients': ['2 cod fillets',
#    '2 tablespoons miso paste',
#    '1 tablespoon mirin',
#    '1 tablespoon soy sauce',
#    '1 teaspoon sugar',
#    '1 cup cooked rice',
#    'Sesame seeds and green onions for garnish',
#    '1 teaspoon sesame oil'],
#   'directions': ['Whisk miso, mirin, soy sauce, and sugar to make glaze.',
#    'Brush cod with glaze and let sit 5 minutes.',
#    'Pan-sear or bake cod until flaky.',
#    'Fluff rice with sesame oil, top with cod, sesame seeds, and green onions.']},
#  {'id': 14,
#   'name': 'Caribbean Jerk Chicken',
#   'cuisine': 'Caribbean',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '25 mins',
#   'total_time': '45 mins',
#   'ingredients': ['4 chicken thighs',
#    '2 tablespoons jerk seasoning',
#    '1 tablespoon lime juice',
#    '1 tablespoon olive oil',
#    'Salt to taste'],
#   'directions': ['Marinate chicken with jerk seasoning, lime juice, olive oil, and salt for 20 minutes.',
#    'Grill or bake until cooked through, about 20-25 minutes.',
#    'Rest briefly and serve with sides like rice and beans.']},
#  {'id': 15,
#   'name': 'Roasted Tomato and Basil Pasta',
#   'cuisine': 'Italian',
#   'servings': 3,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['300g pasta',
#    '3 cups cherry tomatoes, halved',
#    '3 cloves garlic, sliced',
#    '2 tablespoons olive oil',
#    'Fresh basil leaves',
#    'Salt and pepper',
#    'Grated parmesan'],
#   'directions': ['Roast tomatoes and garlic with olive oil for 15-20 minutes.',
#    'Cook pasta until al dente, reserve 1/2 cup pasta water.',
#    'Toss pasta with roasted tomatoes, add water to loosen if needed.',
#    'Stir in torn basil and parmesan; season to taste.']},
#  {'id': 16,
#   'name': 'Paneer Butter Masala',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['250g paneer, cubed',
#    '2 tablespoons butter',
#    '1 onion, finely chopped',
#    '1 teaspoon ginger-garlic paste',
#    '2 tomatoes, pureed',
#    '1/2 cup cream',
#    '1 teaspoon garam masala',
#    'Salt to taste'],
#   'directions': ['Fry paneer lightly until golden; set aside.',
#    'Sauté onion with butter, add ginger-garlic paste.',
#    'Add tomato puree and simmer 10 minutes.',
#    'Stir in cream, garam masala, and paneer; simmer 5 minutes.',
#    'Season to taste and serve with rice or naan.']},
#  {'id': 17,
#   'name': 'Falooda (Dessert Drink)',
#   'cuisine': 'Indian',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '0 mins',
#   'total_time': '15 mins',
#   'ingredients': ['2 cups milk',
#    '2 tablespoons rose syrup',
#    '1 tablespoon vermicelli noodles (soaked)',
#    '1 scoop basil seeds (sabja), soaked',
#    'Ice',
#    'Cherries or shredded coconut for garnish'],
#   'directions': ['In tall glasses, layer milk, rose syrup, soaked vermicelli, and sabja.',
#    'Add ice and garnish with cherries or coconut.',
#    'Serve with a spoon and straw.']},
#  {'id': 18,
#   'name': 'Shakshuka',
#   'cuisine': 'Mediterranean',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '20 mins',
#   'total_time': '30 mins',
#   'ingredients': ['1 tablespoon olive oil',
#    '1 onion, chopped',
#    '1 bell pepper, sliced',
#    '2 cloves garlic, minced',
#    '1 can (400g) chopped tomatoes',
#    '1 teaspoon paprika',
#    '1/2 teaspoon cumin',
#    '4 eggs',
#    'Fresh parsley for garnish',
#    'Salt and pepper to taste'],
#   'directions': ['Sauté onion and pepper in olive oil until soft.',
#    'Add garlic, tomatoes, paprika, and cumin; simmer 10 minutes.',
#    'Make four wells in sauce and crack in eggs.',
#    'Cover and cook until eggs set; garnish with parsley.']},
#  {'id': 19,
#   'name': 'Cuban Black Beans and Rice',
#   'cuisine': 'Cuban',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '40 mins',
#   'total_time': '55 mins',
#   'ingredients': ['1 cup dried black beans (or 2 cans, drained)',
#    '1 onion, chopped',
#    '2 cloves garlic, minced',
#    '1 bay leaf',
#    '1 teaspoon cumin',
#    '1 tablespoon olive oil',
#    'Rice to serve'],
#   'directions': ['Soak beans if using dried (overnight recommended).',
#    'Sauté onion and garlic in oil; add beans, bay leaf, cumin, and water.',
#    'Simmer until beans are tender (about 45 minutes for dried).',
#    'Serve over rice.']},
#  {'id': 20,
#   'name': 'Beef Bulgogi',
#   'cuisine': 'Korean',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '10 mins',
#   'total_time': '30 mins',
#   'ingredients': ['500g sirloin or flank steak, thinly sliced',
#    '2 tablespoons soy sauce',
#    '1 tablespoon sugar',
#    '1 tablespoon sesame oil',
#    '2 cloves garlic, minced',
#    '1 teaspoon grated ginger',
#    '1 green onion, chopped',
#    'Sesame seeds for garnish'],
#   'directions': ['Marinate beef with soy sauce, sugar, sesame oil, garlic, and ginger for 15-20 minutes.',
#    'Stir-fry in a hot pan 2-3 minutes until cooked.',
#    'Garnish with green onion and sesame seeds; serve with rice.']},
#  {'id': 21,
#   'name': 'Spanish Paella Valenciana',
#   'cuisine': 'Spanish',
#   'servings': 4,
#   'prep_time': '25 mins',
#   'cook_time': '40 mins',
#   'total_time': '1 hour 5 mins',
#   'ingredients': ['1 cup bomba rice or arborio',
#    '200g chicken pieces',
#    '150g chorizo, sliced',
#    '1 onion, chopped',
#    '1 red bell pepper, chopped',
#    '2 tomatoes, chopped',
#    '2 cups chicken broth',
#    'Saffron threads',
#    'Olive oil',
#    'Salt'],
#   'directions': ['Brown chicken and chorizo in olive oil; set aside.',
#    'Sauté onion and pepper; add tomatoes and cook until soft.',
#    'Add rice, saffron, and broth; bring to boil.',
#    'Return meat, cover, simmer until rice is cooked and liquid absorbed.',
#    'Rest 5 minutes before serving.']},
#  {'id': 22,
#   'name': 'Tom Yum Goong',
#   'cuisine': 'Thai',
#   'servings': 3,
#   'prep_time': '15 mins',
#   'cook_time': '15 mins',
#   'total_time': '30 mins',
#   'ingredients': ['4 cups stock',
#    '2 stalks lemongrass, smashed',
#    '3 kaffir lime leaves',
#    '3-4 slices galangal',
#    '200g shrimp, peeled',
#    '1 cup mushrooms',
#    '2 tablespoons fish sauce',
#    'Lime juice to taste',
#    'Chili paste (optional)'],
#   'directions': ['Boil stock with lemongrass, lime leaves, and galangal for 10 minutes.',
#    'Add mushrooms and shrimp; cook until shrimp turn pink.',
#    'Season with fish sauce and lime juice; add chili paste if desired.']},
#  {'id': 23,
#   'name': 'Chicken Caesar Salad',
#   'cuisine': 'American',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '10 mins',
#   'total_time': '25 mins',
#   'ingredients': ['2 chicken breasts',
#    'Romaine lettuce',
#    'Croutons',
#    'Parmesan cheese',
#    'Caesar dressing'],
#   'directions': ['Grill or pan-sear chicken; slice.',
#    'Toss lettuce with dressing and croutons.',
#    'Top with chicken slices and parmesan.']},
#  {'id': 24,
#   'name': 'Moussaka',
#   'cuisine': 'Greek',
#   'servings': 4,
#   'prep_time': '30 mins',
#   'cook_time': '60 mins',
#   'total_time': '1 hour 30 mins',
#   'ingredients': ['2 eggplants, sliced',
#    '500g ground lamb',
#    '1 onion, chopped',
#    '2 cloves garlic, minced',
#    '1 can tomatoes',
#    'Bechamel sauce: butter, flour, milk, nutmeg',
#    'Olive oil, salt, pepper'],
#   'directions': ['Roast eggplant slices until tender.',
#    'Cook lamb with onion and garlic; add tomatoes and season.',
#    'Layer eggplant and meat mixture in dish; top with bechamel.',
#    'Bake until golden and set.']},
#  {'id': 25,
#   'name': 'Shoyu Ramen (Quick)',
#   'cuisine': 'Japanese',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '20 mins',
#   'total_time': '35 mins',
#   'ingredients': ['2 servings ramen noodles',
#    '4 cups chicken broth',
#    '2 tablespoons soy sauce',
#    '1 teaspoon miso paste',
#    'Soft-boiled eggs',
#    'Slices of pork or chicken',
#    'Green onions'],
#   'directions': ['Simmer broth with soy sauce and miso.',
#    'Cook noodles separately.',
#    'Assemble bowls with broth, noodles, meat, egg, and green onions.']},
#  {'id': 26,
#   'name': 'Lemon Garlic Shrimp Pasta',
#   'cuisine': 'Italian',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['200g linguine',
#    '200g shrimp, peeled',
#    '2 cloves garlic, minced',
#    '1 lemon (zest and juice)',
#    '2 tablespoons olive oil',
#    'Parsley, chopped',
#    'Salt and pepper'],
#   'directions': ['Cook pasta until al dente.',
#    'Sauté garlic in olive oil; add shrimp until pink.',
#    'Toss with pasta, lemon zest/juice, and parsley.',
#    'Season and serve.']},
#  {'id': 27,
#   'name': 'Ratatouille',
#   'cuisine': 'French',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '45 mins',
#   'total_time': '1 hour 5 mins',
#   'ingredients': ['1 eggplant, cubed',
#    '2 zucchinis, sliced',
#    '1 bell pepper, chopped',
#    '1 onion, chopped',
#    '2 tomatoes, chopped',
#    '2 cloves garlic, minced',
#    'Herbs de Provence',
#    'Olive oil'],
#   'directions': ['Sauté onion and garlic in olive oil.',
#    'Add vegetables; cook slowly with herbs until tender.',
#    'Season and serve warm or room temp.']},
#  {'id': 28,
#   'name': 'Crispy Skin Salmon with Dill Yogurt',
#   'cuisine': 'Scandinavian',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '12 mins',
#   'total_time': '22 mins',
#   'ingredients': ['2 salmon fillets',
#    'Salt and pepper',
#    '1 tablespoon butter',
#    '1/2 cup yogurt',
#    'Fresh dill, chopped',
#    'Lemon wedges'],
#   'directions': ['Season salmon; sear skin-side down in butter until crisp.',
#    'Flip and cook to desired doneness.',
#    'Mix yogurt with dill and a squeeze of lemon; serve with salmon.']},
#  {'id': 29,
#   'name': 'Thai Green Curry with Vegetables',
#   'cuisine': 'Thai',
#   'servings': 3,
#   'prep_time': '15 mins',
#   'cook_time': '20 mins',
#   'total_time': '35 mins',
#   'ingredients': ['2 tablespoons green curry paste',
#    '1 can coconut milk',
#    'Assorted vegetables (bell peppers, zucchini, snow peas)',
#    'Tofu or chicken',
#    'Fish sauce to taste',
#    'Basil or cilantro',
#    'Rice to serve'],
#   'directions': ['Sauté curry paste briefly in oil.',
#    'Add coconut milk and simmer 5 minutes.',
#    'Add protein and vegetables; cook until tender.',
#    'Season with fish sauce and garnish with herbs; serve over rice.']},
#  {'id': 30,
#   'name': 'Mango Sticky Rice',
#   'cuisine': 'Thai',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '20 mins',
#   'total_time': '35 mins',
#   'ingredients': ['1 cup glutinous rice',
#    '1 1/2 cups water',
#    '1/2 cup coconut milk',
#    '2 tablespoons sugar',
#    '1 ripe mango, sliced',
#    'Pinch salt'],
#   'directions': ['Cook rice in water until tender.',
#    'Warm coconut milk with sugar and salt.',
#    'Pour coconut sauce over cooked rice and let absorb.',
#    'Serve with mango slices.']},
#  {'id': 31,
#   'name': 'Herbed Quinoa Salad',
#   'cuisine': 'American',
#   'servings': 3,
#   'prep_time': '15 mins',
#   'cook_time': '15 mins',
#   'total_time': '30 mins',
#   'ingredients': ['1 cup quinoa, rinsed',
#    '2 cups water',
#    'Cherry tomatoes, halved',
#    'Cucumber, diced',
#    'Parsley and mint, chopped',
#    'Lemon vinaigrette: lemon juice, olive oil, salt, pepper'],
#   'directions': ['Cook quinoa in water until fluffy; cool.',
#    'Toss with vegetables, herbs, and vinaigrette.',
#    'Chill 10 minutes before serving if desired.']},
#  {'id': 32,
#   'name': 'Beef Shawarma Wrap',
#   'cuisine': 'Middle Eastern',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['400g beef strips',
#    'Shawarma spice blend',
#    'Pita breads',
#    'Tomato, cucumber, onion slices',
#    'Tahini sauce or yogurt sauce'],
#   'directions': ['Marinate beef with shawarma spices.',
#    'Cook beef in a hot pan until done.',
#    'Fill pitas with beef and vegetables; drizzle with sauce.']},
#  {'id': 33,
#   'name': 'Pesto Chicken Bake',
#   'cuisine': 'Italian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['4 chicken breasts',
#    '3 tablespoons pesto',
#    '1 cup mozzarella, shredded',
#    'Cherry tomatoes',
#    'Salt and pepper'],
#   'directions': ['Season chicken and place in baking dish.',
#    'Top each with pesto, mozzarella, and tomatoes.',
#    'Bake at 200°C (400°F) for 22-25 minutes until chicken is cooked.']},
#  {'id': 34,
#   'name': 'Baked Eggplant Parmesan',
#   'cuisine': 'Italian',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '40 mins',
#   'total_time': '1 hour',
#   'ingredients': ['2 eggplants, sliced',
#    '1 cup marinara sauce',
#    '1 cup mozzarella, shredded',
#    '1/2 cup parmesan, grated',
#    'Breadcrumbs',
#    'Eggs'],
#   'directions': ['Dip eggplant slices in egg then breadcrumbs; bake until tender.',
#    'Layer with marinara and cheese; bake until golden.']},
#  {'id': 35,
#   'name': 'Moroccan Chickpea Stew',
#   'cuisine': 'Moroccan',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['1 onion, chopped',
#    '2 garlic cloves, minced',
#    '1 can chickpeas',
#    '1 can diced tomatoes',
#    '1 teaspoon cumin',
#    '1 teaspoon coriander',
#    '1/2 teaspoon cinnamon',
#    'Olive oil',
#    'Fresh cilantro'],
#   'directions': ['Sauté onion and garlic; add spices.',
#    'Add chickpeas and tomatoes; simmer 15-20 minutes.',
#    'Garnish with cilantro and serve.']},
#  {'id': 36,
#   'name': 'Crunchy Cabbage Slaw',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '0 mins',
#   'total_time': '15 mins',
#   'ingredients': ['1/2 head cabbage, shredded',
#    '1 carrot, shredded',
#    '1/4 cup mayonnaise',
#    '2 tablespoons rice vinegar',
#    '1 teaspoon sugar',
#    'Salt and pepper'],
#   'directions': ['Mix dressing ingredients.',
#    'Toss with shredded cabbage and carrot.',
#    'Chill slightly before serving.']},
#  {'id': 37,
#   'name': 'Ceviche de Pescado',
#   'cuisine': 'Peruvian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '0 mins',
#   'total_time': '15 mins',
#   'ingredients': ['400g white fish (like sea bass), diced',
#    'Juice of 2 limes',
#    '1/2 red onion, thinly sliced',
#    'Chili peppers, finely chopped',
#    'Cilantro',
#    'Salt to taste'],
#   'directions': ['Cure fish in lime juice for about 10-15 minutes until opaque.',
#    'Mix with onion, chili, and cilantro; season and serve.']},
#  {'id': 38,
#   'name': 'Thai Basil Chicken (Pad Krapow Gai)',
#   'cuisine': 'Thai',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '8 mins',
#   'total_time': '18 mins',
#   'ingredients': ['200g minced chicken',
#    '2 cloves garlic, minced',
#    '1 chili, chopped',
#    '1 tablespoon soy sauce',
#    '1 tablespoon fish sauce',
#    'Basil leaves',
#    'Rice to serve'],
#   'directions': ['Sauté garlic and chili in oil until fragrant.',
#    'Add chicken and cook through.',
#    'Stir in soy and fish sauces; toss with basil until wilted.',
#    'Serve over steamed rice.']},
#  {'id': 39,
#   'name': 'Caprese Salad',
#   'cuisine': 'Italian',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '0 mins',
#   'total_time': '10 mins',
#   'ingredients': ['Tomatoes, sliced',
#    'Fresh mozzarella, sliced',
#    'Fresh basil leaves',
#    'Olive oil',
#    'Balsamic glaze',
#    'Salt and pepper'],
#   'directions': ['Alternate tomato and mozzarella slices on a plate.',
#    'Top with basil; drizzle olive oil and balsamic glaze.',
#    'Season with salt and pepper.']},
#  {'id': 40,
#   'name': 'Pumpkin Risotto',
#   'cuisine': 'Italian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '40 mins',
#   'total_time': '55 mins',
#   'ingredients': ['1 cup arborio rice',
#    '1 cup pumpkin puree',
#    '1/2 onion, finely chopped',
#    '3 cups vegetable broth',
#    '1/4 cup parmesan',
#    '2 tablespoons butter',
#    'Olive oil'],
#   'directions': ['Sauté onion in olive oil until translucent.',
#    'Add rice and toast 1-2 minutes.',
#    'Add warm broth gradually, stirring until absorbed.',
#    'Stir in pumpkin puree, butter, and parmesan; season to taste.']},
#  {'id': 41,
#   'name': 'Garlic Butter Shrimp',
#   'cuisine': 'American',
#   'servings': 2,
#   'prep_time': '5 mins',
#   'cook_time': '6 mins',
#   'total_time': '11 mins',
#   'ingredients': ['200g shrimp, peeled',
#    '2 tablespoons butter',
#    '2 cloves garlic, minced',
#    'Lemon juice',
#    'Parsley'],
#   'directions': ['Melt butter; add garlic and cook 1 minute.',
#    'Add shrimp; cook until pink.',
#    'Squeeze lemon juice; garnish with parsley and serve.']},
#  {'id': 42,
#   'name': 'Roasted Red Pepper Hummus',
#   'cuisine': 'Middle Eastern',
#   'servings': 6,
#   'prep_time': '15 mins',
#   'cook_time': '0 mins',
#   'total_time': '15 mins',
#   'ingredients': ['1 can chickpeas',
#    '1 roasted red pepper',
#    '2 tablespoons tahini',
#    '1 clove garlic',
#    'Juice of 1 lemon',
#    'Salt and olive oil'],
#   'directions': ['Blend all ingredients until smooth.',
#    'Drizzle with olive oil and serve with pita or veggies.']},
#  {'id': 43,
#   'name': 'Garlic Naan',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '8 mins',
#   'total_time': '28 mins',
#   'ingredients': ['2 cups all-purpose flour',
#    '1/2 cup yogurt',
#    '1/2 cup warm water',
#    '2 tablespoons oil',
#    '1 teaspoon yeast',
#    'Garlic, minced',
#    'Salt'],
#   'directions': ['Mix ingredients to form dough; knead until smooth.',
#    'Let rise 1 hour; divide and roll into rounds.',
#    'Cook on hot skillet 2-3 minutes per side.',
#    'Brush with garlic butter and serve.']},
#  {'id': 44,
#   'name': 'Butter Chicken',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['500g chicken, cubed',
#    '2 tablespoons butter',
#    '1 onion, chopped',
#    '2 cloves garlic, minced',
#    '1 teaspoon garam masala',
#    '1 can tomato sauce',
#    '1/2 cup cream',
#    'Salt to taste'],
#   'directions': ['Sauté onion and garlic in butter.',
#    'Add chicken and cook until sealed.',
#    'Stir in tomato sauce and garam masala; simmer 15 minutes.',
#    'Stir in cream; season and serve with rice or naan.']},
#  {'id': 45,
#   'name': 'Coconut Curry Lentil Soup',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['1 cup red lentils',
#    '1 onion, chopped',
#    '2 cloves garlic, minced',
#    '1 tablespoon curry powder',
#    '1 can coconut milk',
#    '2 cups vegetable broth',
#    'Salt to taste'],
#   'directions': ['Sauté onion and garlic; add curry powder.',
#    'Add lentils, coconut milk, and broth; simmer 25 minutes.',
#    'Season and serve hot.']},
#  {'id': 46,
#   'name': 'Gyro Wrap',
#   'cuisine': 'Greek',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['Gyro meat (lamb or chicken) or substitute with sliced chicken',
#    'Pita breads',
#    'Tomato, onion, cucumber slices',
#    'Tzatziki sauce'],
#   'directions': ['Cook gyro meat until browned.',
#    'Warm pita; fill with meat and vegetables.',
#    'Top with tzatziki.']},
#  {'id': 47,
#   'name': 'Pollo a la Brasa (Peruvian Roast Chicken)',
#   'cuisine': 'Peruvian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '45 mins',
#   'total_time': '1 hour',
#   'ingredients': ['4 chicken thighs',
#    '2 cloves garlic, minced',
#    '1 teaspoon cumin',
#    '1 teaspoon paprika',
#    'Salt and pepper',
#    'Lime wedges'],
#   'directions': ['Marinate chicken with garlic, cumin, paprika, salt, and pepper.',
#    'Roast at 200°C (400°F) for 40-45 minutes until cooked.',
#    'Serve with lime wedges.']},
#  {'id': 48,
#   'name': 'Mango Salsa Chicken',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '20 mins',
#   'total_time': '35 mins',
#   'ingredients': ['4 chicken breasts',
#    '1 mango, diced',
#    '1 red onion, diced',
#    'Cilantro, chopped',
#    'Lime juice',
#    'Salt'],
#   'directions': ['Season chicken and sear in a pan.',
#    'Top with mango salsa (mango, onion, cilantro, lime juice).',
#    'Bake 10 minutes to finish cooking.']},
#  {'id': 49,
#   'name': 'Rice Paper Rolls with Peanut Dip',
#   'cuisine': 'Vietnamese',
#   'servings': 4,
#   'prep_time': '25 mins',
#   'cook_time': '0 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Rice paper sheets',
#    'Rice noodles',
#    'Shrimp or tofu',
#    'Fresh herbs (mint, basil)',
#    'Carrots, cucumber, lettuce',
#    'Peanut dipping sauce'],
#   'directions': ['Soak rice papers; fill with noodles, greens, and protein.',
#    'Roll tightly; serve with peanut dip.']},
#  {'id': 50,
#   'name': 'Beef Nachos',
#   'cuisine': 'Mexican',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '10 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Tortilla chips',
#    'Ground beef',
#    'Cheddar cheese',
#    'Refried beans (optional)',
#    'Salsa, sour cream, jalapenos'],
#   'directions': ['Cook beef with seasoning.',
#    'Layer chips, beef, and cheese; bake until cheese melts.',
#    'Top with beans, salsa, sour cream, and jalapenos.']},
#  {'id': 51,
#   'name': 'Herbed Chicken Skewers',
#   'cuisine': 'Mediterranean',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '12 mins',
#   'total_time': '32 mins',
#   'ingredients': ['4 chicken thighs, cubed',
#    'Olive oil',
#    'Herbs (rosemary, thyme)',
#    'Lemon wedges',
#    'Salt and pepper'],
#   'directions': ['Thread chicken onto skewers after marinating briefly.',
#    'Grill until cooked through, basting with oil and herbs.',
#    'Serve with lemon wedges.']},
#  {'id': 52,
#   'name': 'Coconut Shrimp Curry',
#   'cuisine': 'Caribbean',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '20 mins',
#   'total_time': '35 mins',
#   'ingredients': ['Shrimp',
#    'Coconut milk',
#    'Curry powder',
#    'Onion, garlic',
#    'Bell pepper',
#    'Salt'],
#   'directions': ['Sauté onion and garlic; add curry powder.',
#    'Add coconut milk and vegetables; simmer 10 minutes.',
#    'Add shrimp; cook until pink and serve.']},
#  {'id': 53,
#   'name': 'Herbed Mushroom Risotto',
#   'cuisine': 'Italian',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '25 mins',
#   'total_time': '35 mins',
#   'ingredients': ['1 cup arborio rice',
#    'Mushrooms, sliced',
#    '1 small onion, chopped',
#    '1/2 cup white wine',
#    '1/2 cup parmesan',
#    'Broth'],
#   'directions': ['Sauté onion and mushrooms; add rice and toast.',
#    'Deglaze with wine; add broth gradually until creamy.']},
#  {'id': 54,
#   'name': 'Lemon Ricotta Pancakes',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['1 cup flour',
#    '1/2 cup ricotta',
#    '1 egg',
#    '1/2 cup milk',
#    'Zest of lemon',
#    'Butter for cooking'],
#   'directions': ['Mix all ingredients into a smooth batter.',
#    'Cook on a hot skillet until bubbles form; flip and cook through.']},
#  {'id': 55,
#   'name': 'Egg Fried Rice',
#   'cuisine': 'Chinese',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '8 mins',
#   'total_time': '18 mins',
#   'ingredients': ['Cooked rice',
#    'Eggs',
#    'Green onions',
#    'Soy sauce',
#    'Peas and carrots'],
#   'directions': ['Scramble eggs in a wok; set aside.',
#    'Stir-fry vegetables, add rice, then eggs.',
#    'Season with soy sauce and scallions.']},
#  {'id': 56,
#   'name': 'Okonomiyaki (Japanese Pancake)',
#   'cuisine': 'Japanese',
#   'servings': 2,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['Cabbage, shredded',
#    'Flour, water, egg batter',
#    'Thinly sliced pork or shrimp',
#    'Okonomiyaki sauce',
#    'Mayonnaise'],
#   'directions': ['Mix batter with cabbage.',
#    'Cook on a griddle; top with meat and flip.',
#    'Brush with sauce and drizzle with mayo.']},
#  {'id': 57,
#   'name': 'Herb-Ceta Pasta with Lemon',
#   'cuisine': 'Italian',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '12 mins',
#   'total_time': '22 mins',
#   'ingredients': ['Pasta of choice',
#    'Lemon zest and juice',
#    'Fresh herbs (parsley, basil)',
#    'Olive oil',
#    'Parmesan'],
#   'directions': ['Cook pasta; reserve some pasta water.',
#    'Toss with lemon zest, juice, herbs, and olive oil.',
#    'Add a splash of pasta water; finish with parmesan.']},
#  {'id': 58,
#   'name': 'Coconut Rice with Beans',
#   'cuisine': 'Caribbean',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '20 mins',
#   'total_time': '30 mins',
#   'ingredients': ['Cooked rice',
#    'Coconut milk',
#    'Black beans',
#    'Garlic powder',
#    'Cilantro'],
#   'directions': ['Simmer coconut milk with garlic powder; stir in beans and cilantro.',
#    'Serve over rice.']},
#  {'id': 59,
#   'name': 'Baked Cod with Tomato and Olive',
#   'cuisine': 'Mediterranean',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Cod fillets',
#    'Tomatoes, chopped',
#    'Olives, sliced',
#    'Garlic, minced',
#    'Olive oil',
#    'Parsley'],
#   'directions': ['Place cod in baking dish; top with tomatoes, olives, and garlic.',
#    'Drizzle with olive oil; bake at 200°C (400°F) for 12-15 minutes.',
#    'Garnish with parsley.']},
#  {'id': 60,
#   'name': 'Seared Tuna Niçoise',
#   'cuisine': 'French',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '10 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Tuna steak',
#    'Olives',
#    'Green beans',
#    'Potatoes, boiled',
#    'Eggs, hard-boiled',
#    'Lemon vinaigrette'],
#   'directions': ['Sear tuna to desired doneness.',
#    'Boil beans and potatoes; assemble with eggs and olives.',
#    'Dress with lemon vinaigrette.']},
#  {'id': 61,
#   'name': 'Harissa Chickpea Bowl',
#   'cuisine': 'Moroccan',
#   'servings': 3,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Chickpeas',
#    'Quinoa or rice',
#    'Harissa paste',
#    'Lemon yogurt sauce',
#    'Cucumber, tomato, herbs'],
#   'directions': ['Roast chickpeas with harissa 15-20 minutes.',
#    'Serve over quinoa with fresh vegetables and lemon yogurt sauce.']},
#  {'id': 62,
#   'name': 'Salmon with Dill and Mustard Glaze',
#   'cuisine': 'Nordic',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '12 mins',
#   'total_time': '22 mins',
#   'ingredients': ['Salmon fillets',
#    'Dijon mustard',
#    'Dill, chopped',
#    'Honey',
#    'Salt and pepper'],
#   'directions': ['Mix glaze with mustard, dill, and honey.',
#    'Brush on salmon; bake or pan-sear until flaky.']},
#  {'id': 63,
#   'name': 'Butter Lettuce Salad with Avocado',
#   'cuisine': 'American',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '0 mins',
#   'total_time': '10 mins',
#   'ingredients': ['Butter lettuce',
#    'Avocado slices',
#    'Cherry tomatoes',
#    'Lemon vinaigrette'],
#   'directions': ['Toss greens with avocado and tomatoes.',
#    'Drizzle with vinaigrette and serve.']},
#  {'id': 64,
#   'name': 'Eggplant Caponata',
#   'cuisine': 'Italian',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '25 mins',
#   'total_time': '45 mins',
#   'ingredients': ['Eggplant, diced',
#    'Celery, chopped',
#    'Tomatoes, chopped',
#    'Olives, chopped',
#    'Capers',
#    'Vinegar and sugar'],
#   'directions': ['Sauté eggplant until soft.',
#    'Add vegetables and simmer with vinegar and sugar until thick.',
#    'Serve warm or at room temperature.']},
#  {'id': 65,
#   'name': 'Avocado Toast with Poached Egg',
#   'cuisine': 'American',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '5 mins',
#   'total_time': '15 mins',
#   'ingredients': ['Bread slices',
#    'Ripe avocado',
#    'Eggs',
#    'Lemon juice',
#    'Salt and pepper'],
#   'directions': ['Toast bread; mash avocado with lemon, salt, and pepper.',
#    'Poach eggs; place on toast and serve.']},
#  {'id': 66,
#   'name': 'Herbed Tomato Soup',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '25 mins',
#   'total_time': '35 mins',
#   'ingredients': ['Tomatoes, chopped',
#    'Onion',
#    'Garlic',
#    'Herbs (basil, thyme)',
#    'Vegetable broth',
#    'Cream or milk'],
#   'directions': ['Sauté onion and garlic; add tomatoes and broth.',
#    'Simmer 20 minutes; blend until smooth.',
#    'Stir in cream and herbs; season and serve.']},
#  {'id': 67,
#   'name': 'Pesto Gnocchi with Cherry Tomatoes',
#   'cuisine': 'Italian',
#   'servings': 3,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Gnocchi', 'Pesto', 'Cherry tomatoes', 'Parmesan'],
#   'directions': ['Boil gnocchi until floating; drain.',
#    'Toss with pesto and halved tomatoes; top with parmesan.']},
#  {'id': 68,
#   'name': 'Paneer Butter Fry',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Paneer cubes',
#    'Butter',
#    'Onion',
#    'Tomato paste',
#    'Cream',
#    'Spices'],
#   'directions': ['Sauté onion in butter; add paneer and brown.',
#    'Add tomato paste and spices; simmer with a splash of cream.']},
#  {'id': 69,
#   'name': 'Lemon Garlic Roasted Brussels Sprouts',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '25 mins',
#   'total_time': '35 mins',
#   'ingredients': ['Brussels sprouts',
#    'Olive oil',
#    'Garlic',
#    'Lemon zest',
#    'Salt and pepper'],
#   'directions': ['Toss sprouts with oil, garlic, salt, and pepper.',
#    'Roast at 200°C (400°F) for 20-25 minutes; finish with lemon zest.']},
#  {'id': 70,
#   'name': 'Paneer Tarsi with Spinach',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '15 mins',
#   'total_time': '30 mins',
#   'ingredients': ['Paneer cubes',
#    'Spinach',
#    'Onion',
#    'Tomato',
#    'Garam masala'],
#   'directions': ['Sauté onion and tomato; add spices.',
#    'Stir in spinach until wilted; add paneer and simmer briefly.']},
#  {'id': 71,
#   'name': 'Rendang Beef',
#   'cuisine': 'Indonesian',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '2 hours',
#   'total_time': '2 hours 20 mins',
#   'ingredients': ['Beef chunks',
#    'Coconut milk',
#    'Rendang paste',
#    'Lemongrass',
#    'Galangal',
#    'Bay leaf'],
#   'directions': ['Simmer beef with coconut milk and rendang paste with aromatics until tender and thickened.']},
#  {'id': 72,
#   'name': 'Chili Con Carne',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '40 mins',
#   'total_time': '55 mins',
#   'ingredients': ['Ground beef',
#    'Chili powder',
#    'Tomato sauce',
#    'Kidney beans',
#    'Onion, garlic',
#    'Cumin'],
#   'directions': ['Sauté onion and garlic; add beef and brown.',
#    'Add spices, tomato sauce, and beans; simmer 25-30 minutes.']},
#  {'id': 73,
#   'name': 'Persian Jeweled Rice',
#   'cuisine': 'Persian',
#   'servings': 4,
#   'prep_time': '30 mins',
#   'cook_time': '25 mins',
#   'total_time': '55 mins',
#   'ingredients': ['Basmati rice',
#    'Saffron',
#    'Barberries',
#    'Almonds',
#    'Raisins',
#    'Butter'],
#   'directions': ['Cook rice; mix with saffron and jeweled mix of nuts and dried fruits.',
#    'Fluff and serve.']},
#  {'id': 74,
#   'name': 'Moroccan Lentil Soup (Harira)',
#   'cuisine': 'Moroccan',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '30 mins',
#   'total_time': '45 mins',
#   'ingredients': ['Lentils',
#    'Tomato paste',
#    'Chickpeas',
#    'Coriander',
#    'Cumin',
#    'Lemon juice'],
#   'directions': ['Sauté onions, garlic; add tomato paste and spices.',
#    'Add lentils and chickpeas with water; simmer until tender.',
#    'Finish with lemon juice and herbs.']},
#  {'id': 75,
#   'name': 'Thai Red Curry with Chicken',
#   'cuisine': 'Thai',
#   'servings': 3,
#   'prep_time': '15 mins',
#   'cook_time': '20 mins',
#   'total_time': '35 mins',
#   'ingredients': ['Red curry paste',
#    'Coconut milk',
#    'Chicken pieces',
#    'Bell peppers',
#    'Basil',
#    'Fish sauce'],
#   'directions': ['Sauté curry paste in oil; add chicken to sear.',
#    'Pour in coconut milk; add vegetables and simmer until cooked.',
#    'Finish with basil and fish sauce.']},
#  {'id': 76,
#   'name': 'Pasta Arrabbiata',
#   'cuisine': 'Italian',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Pasta',
#    'Tomato sauce',
#    'Garlic, chili flakes',
#    'Olive oil',
#    'Parsley'],
#   'directions': ['Cook pasta until al dente.',
#    'Sauté garlic and chili in olive oil; add tomato sauce.',
#    'Toss with pasta and garnish with parsley.']},
#  {'id': 77,
#   'name': 'Cranberry Walnut Salad',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '0 mins',
#   'total_time': '15 mins',
#   'ingredients': ['Mixed greens',
#    'Cranberries',
#    'Walnuts',
#    'Feta or goat cheese',
#    'Balsamic vinaigrette'],
#   'directions': ['Toss greens with cranberries, walnuts, and cheese.',
#    'Drizzle with vinaigrette.']},
#  {'id': 78,
#   'name': 'Corn Chowder',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Corn kernels',
#    'Potatoes',
#    'Onion',
#    'Milk or cream',
#    'Butter',
#    'Salt and pepper'],
#   'directions': ['Sauté onion in butter; add potatoes and corn.',
#    'Add milk and simmer until thickened; season.']},
#  {'id': 79,
#   'name': 'Eggplant Yakitori Skewers',
#   'cuisine': 'Japanese',
#   'servings': 4,
#   'prep_time': '25 mins',
#   'cook_time': '12 mins',
#   'total_time': '37 mins',
#   'ingredients': ['Eggplant sticks',
#    'Soy glaze: soy sauce, sugar, mirin',
#    'Sesame seeds'],
#   'directions': ['Skewer eggplant chunks; brush with glaze.',
#    'Grill until tender; garnish with sesame seeds.']},
#  {'id': 80,
#   'name': 'Chana Masala',
#   'cuisine': 'Indian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Chickpeas',
#    'Onion',
#    'Tomatoes',
#    'Garlic',
#    'Garam masala',
#    'Cumin',
#    'Coriander'],
#   'directions': ['Sauté onion and garlic; add spices.',
#    'Add tomatoes and chickpeas; simmer 15-20 minutes.']},
#  {'id': 81,
#   'name': 'Buttermilk Pancakes',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Flour', 'Buttermilk', 'Egg', 'Baking powder', 'Sugar'],
#   'directions': ['Mix dry ingredients; whisk in wet ingredients until smooth.',
#    'Cook on a hot skillet until bubbles form; flip and cook through.']},
#  {'id': 82,
#   'name': 'Mango Lassi',
#   'cuisine': 'Indian',
#   'servings': 2,
#   'prep_time': '5 mins',
#   'cook_time': '0 mins',
#   'total_time': '5 mins',
#   'ingredients': ['Mango pulp',
#    'Plain yogurt',
#    'Sugar',
#    'Cardamom (optional)'],
#   'directions': ['Blend all ingredients until smooth.', 'Chill and serve.']},
#  {'id': 83,
#   'name': 'Pesto Pasta with Sun-Dried Tomatoes',
#   'cuisine': 'Italian',
#   'servings': 3,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Pasta', 'Pesto', 'Sun-dried tomatoes', 'Parmesan'],
#   'directions': ['Cook pasta; drain.',
#    'Toss with pesto and sun-dried tomatoes; top with parmesan.']},
#  {'id': 84,
#   'name': 'Salisbury Steak with Mushroom Gravy',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Ground beef',
#    'Mushrooms',
#    'Onion',
#    'Beef broth',
#    'Flour',
#    'Butter'],
#   'directions': ['Form patties and brown in a pan; set aside.',
#    'Make gravy with mushrooms, onion, flour, and broth; return patties to pan and simmer.']},
#  {'id': 85,
#   'name': 'Simple Garlic Herb Salmon',
#   'cuisine': 'American',
#   'servings': 2,
#   'prep_time': '5 mins',
#   'cook_time': '10 mins',
#   'total_time': '15 mins',
#   'ingredients': ['Salmon fillets',
#    'Garlic, minced',
#    'Herbs (dill or parsley)',
#    'Lemon juice',
#    'Olive oil'],
#   'directions': ['Season salmon; sear in a pan with garlic and herbs.',
#    'Finish with lemon juice and serve.']},
#  {'id': 86,
#   'name': 'Gnocchi with Sage Butter',
#   'cuisine': 'Italian',
#   'servings': 2,
#   'prep_time': '10 mins',
#   'cook_time': '10 mins',
#   'total_time': '20 mins',
#   'ingredients': ['Store-bought gnocchi',
#    'Butter',
#    'Fresh sage leaves',
#    'Parmesan'],
#   'directions': ['Cook gnocchi until floating.',
#    'Brown butter with sage; toss with gnocchi and parmesan.']},
#  {'id': 87,
#   'name': 'Shredded Beef Tostadas',
#   'cuisine': 'Mexican',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '2 hours',
#   'total_time': '2 hours 20 mins',
#   'ingredients': ['Beef chuck, slow-cooked and shredded',
#    'Tostada shells',
#    'Lettuce, tomato, cheese',
#    'Sour cream',
#    'Salsa'],
#   'directions': ['Slow-cook beef with spices until tender; shred.',
#    'Top tostadas with beef and toppings.']},
#  {'id': 88,
#   'name': 'Chili Lime Grilled Corn',
#   'cuisine': 'Mexican',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Corn on the cob',
#    'Butter',
#    'Chili powder',
#    'Lime juice',
#    'Salt'],
#   'directions': ['Grill corn until charred; brush with butter.',
#    'Sprinkle chili powder and drizzle lime juice; season.']},
#  {'id': 89,
#   'name': 'Herbed Rice with Peas',
#   'cuisine': 'Indian/Global',
#   'servings': 4,
#   'prep_time': '10 mins',
#   'cook_time': '15 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Basmati rice',
#    'Frozen peas',
#    'Spinach or cilantro',
#    'Butter or ghee'],
#   'directions': ['Cook rice with peas; stir in greens and butter.']},
#  {'id': 90,
#   'name': 'Gulai Ayam (Indonesian Curry Chicken)',
#   'cuisine': 'Indonesian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Chicken pieces',
#    'Gulai curry paste',
#    'Coconut milk',
#    'Vegetables (potatoes, carrots)'],
#   'directions': ['Sauté curry paste; add chicken and coconut milk.',
#    'Simmer with vegetables until cooked.']},
#  {'id': 91,
#   'name': 'Spicy Peanut Noodles',
#   'cuisine': 'Thai/Chinese Fusion',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '10 mins',
#   'total_time': '25 mins',
#   'ingredients': ['Rice noodles',
#    'Peanut butter',
#    'Soy sauce',
#    'Rice vinegar',
#    'Chili sauce',
#    'Garlic'],
#   'directions': ['Cook noodles; whisk sauce with peanut butter.',
#    'Toss noodles with sauce and sesame seeds.']},
#  {'id': 92,
#   'name': 'Herbed Quiche',
#   'cuisine': 'French',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '40 mins',
#   'total_time': '55 mins',
#   'ingredients': ['Pie crust',
#    'Eggs',
#    'Cream',
#    'Cheese',
#    'Herbs',
#    'Vegetables (optional)'],
#   'directions': ['Whisk eggs with cream and herbs.',
#    'Fill crust with cheese and vegetables; pour mixture and bake until set.']},
#  {'id': 93,
#   'name': 'Baked Ziti',
#   'cuisine': 'Italian',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Pasta',
#    'Tomato sauce',
#    'Ground beef or sausage',
#    'Mozzarella cheese',
#    'Parmesan'],
#   'directions': ['Cook pasta; mix with sauce and meat.',
#    'Top with cheese and bake until bubbly.']},
#  {'id': 94,
#   'name': 'Herbed Shrimp and Grits',
#   'cuisine': 'American',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Shrimp', 'Grits', 'Butter', 'Garlic', 'Lemon', 'Parsley'],
#   'directions': ['Prepare grits as per package instructions with butter.',
#    'Sauté shrimp with garlic; stir in lemon and parsley.',
#    'Serve shrimp over grits.']},
#  {'id': 95,
#   'name': 'Duck Confit (Simple Version)',
#   'cuisine': 'French',
#   'servings': 2,
#   'prep_time': '20 mins',
#   'cook_time': '1 hour',
#   'total_time': '1 hour 20 mins',
#   'ingredients': ['Duck legs confit (or duck legs and fat)',
#    'Garlic, thyme',
#    'Salt and pepper'],
#   'directions': ['Crisp duck skin in a hot skillet; finish in oven until skin is golden and meat is tender.']},
#  {'id': 96,
#   'name': 'Lemon Olive Oil Cake',
#   'cuisine': 'Mediterranean',
#   'servings': 8,
#   'prep_time': '15 mins',
#   'cook_time': '40 mins',
#   'total_time': '55 mins',
#   'ingredients': ['Flour',
#    'Sugar',
#    'Lemon zest',
#    'Olive oil',
#    'Eggs',
#    'Baking powder',
#    'Milk'],
#   'directions': ['Mix ingredients; bake in loaf pan until a toothpick comes out clean.']},
#  {'id': 97,
#   'name': 'Salsa Verde Chicken Tajine',
#   'cuisine': 'Moroccan',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '45 mins',
#   'total_time': '1 hour',
#   'ingredients': ['Chicken pieces',
#    'Salsa verde',
#    'Chickpeas',
#    'Potatoes',
#    'Olives'],
#   'directions': ['Combine ingredients in a tajine or pot; simmer until chicken is cooked and flavors meld.']},
#  {'id': 98,
#   'name': 'Coconut Lime Chicken',
#   'cuisine': 'Thai/Caribbean Fusion',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '20 mins',
#   'total_time': '35 mins',
#   'ingredients': ['Chicken thighs',
#    'Coconut milk',
#    'Lime juice',
#    'Garlic',
#    'Thai curry paste'],
#   'directions': ['Sauté garlic and curry paste; add chicken and coconut milk.',
#    'Simmer until chicken is cooked; finish with lime juice.']},
#  {'id': 99,
#   'name': 'Spinach and Feta Stuffed Peppers',
#   'cuisine': 'Mediterranean',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '25 mins',
#   'total_time': '40 mins',
#   'ingredients': ['Bell peppers',
#    'Spinach',
#    'Feta cheese',
#    'Rice or quinoa',
#    'Tomato sauce'],
#   'directions': ['Cook filling with spinach and feta; stuff peppers.',
#    'Bake in sauce until peppers tender.']},
#  {'id': 100,
#   'name': 'Gado-Gado (Indonesian Peanut Salad)',
#   'cuisine': 'Indonesian',
#   'servings': 4,
#   'prep_time': '20 mins',
#   'cook_time': '10 mins',
#   'total_time': '30 mins',
#   'ingredients': ['Boiled vegetables (beans, cabbage, potato)',
#    'Hard-boiled eggs',
#    'Tofu or tempeh',
#    'Peanut sauce: peanuts, palm sugar, tamarind, lime'],
#   'directions': ['Arrange vegetables, eggs, and tofu on a plate.',
#    'Drizzle with warm peanut sauce and serve.']},
#  {'id': 101,
#   'name': 'Kung Pao Chicken',
#   'cuisine': 'Chinese (Szechuan)',
#   'servings': 3,
#   'prep_time': '20 mins',
#   'cook_time': '10 mins',
#   'total_time': '30 mins',
#   'ingredients': ['500g chicken breast, cubed',
#    '1/2 cup roasted peanuts',
#    '3-4 dried red chilies',
#    '2 cloves garlic, minced',
#    '1 tablespoon ginger, minced',
#    '2 tablespoons soy sauce',
#    '1 tablespoon rice vinegar',
#    '1 teaspoon sugar',
#    '1 tablespoon cornstarch mixed with 1 tablespoon water',
#    '2 tablespoons vegetable oil'],
#   'directions': ['In a small bowl, mix soy sauce, vinegar, and sugar to make the sauce.',
#    'Heat oil in a wok and stir-fry the chicken until cooked through; remove and set aside.',
#    'In the same wok, sauté garlic, ginger, and dried chilies until fragrant.',
#    'Return chicken to the wok, add the peanuts and the sauce mixture.',
#    'Stir in the cornstarch slurry and cook until the sauce thickens and coats the chicken.',
#    'Serve hot with steamed rice.']},
#  {'id': 102,
#   'name': 'Mapo Tofu',
#   'cuisine': 'Chinese (Szechuan)',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '15 mins',
#   'total_time': '30 mins',
#   'ingredients': ['400g soft tofu, cubed',
#    '100g ground pork or beef',
#    '2 tablespoons Doubanjiang (spicy bean paste)',
#    '1 tablespoon soy sauce',
#    '1 teaspoon Szechuan peppercorns, crushed',
#    '2 green onions, chopped',
#    '1 cup chicken broth',
#    '1 tablespoon cornstarch slurry'],
#   'directions': ['Brown the ground meat in a wok over medium-high heat.',
#    'Add the spicy bean paste and peppercorns, stirring until fragrant and the oil turns red.',
#    'Pour in the chicken broth and soy sauce; bring to a simmer.',
#    'Gently add the tofu cubes and simmer for 5 minutes.',
#    'Stir in the cornstarch slurry to thicken the sauce.',
#    'Garnish with green onions and serve.']},
#  {'id': 103,
#   'name': 'Beef and Broccoli',
#   'cuisine': 'Chinese (Cantonese)',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '10 mins',
#   'total_time': '25 mins',
#   'ingredients': ['300g flank steak, thinly sliced against the grain',
#    '2 cups broccoli florets',
#    '2 tablespoons oyster sauce',
#    '1 tablespoon soy sauce',
#    '1 tablespoon ginger, minced',
#    '1 tablespoon cornstarch',
#    '2 tablespoons vegetable oil'],
#   'directions': ['Toss beef slices with cornstarch and a splash of soy sauce; let sit for 10 minutes.',
#    'Blanch broccoli in boiling water for 2 minutes, then drain.',
#    'Heat oil in a wok and sear beef at high heat until browned; remove.',
#    'Stir-fry ginger for 30 seconds, then add broccoli, oyster sauce, and soy sauce.',
#    'Return beef to the wok and toss everything together for 1 minute.',
#    'Serve immediately.']},
#  {'id': 104,
#   'name': "General Tso's Chicken",
#   'cuisine': 'Chinese-American',
#   'servings': 3,
#   'prep_time': '25 mins',
#   'cook_time': '15 mins',
#   'total_time': '40 mins',
#   'ingredients': ['500g chicken thighs, cut into bite-sized pieces',
#    '1/2 cup cornstarch (for coating)',
#    '1/4 cup soy sauce',
#    '2 tablespoons rice vinegar',
#    '2 tablespoons sugar',
#    '1 tablespoon ginger-garlic paste',
#    'Oil for deep frying',
#    'Dried red chilies to taste'],
#   'directions': ['Coat chicken pieces thoroughly in cornstarch.',
#    'Deep fry chicken in hot oil until crispy and golden; drain on paper towels.',
#    'In a separate pan, sauté ginger, garlic, and chilies.',
#    'Add soy sauce, vinegar, and sugar; simmer until the sugar dissolves.',
#    'Toss the crispy chicken into the sauce until fully coated.',
#    'Serve over white rice.']},
#  {'id': 105,
#   'name': 'Pork Potstickers (Dumplings)',
#   'cuisine': 'Chinese',
#   'servings': 4,
#   'prep_time': '40 mins',
#   'cook_time': '15 mins',
#   'total_time': '55 mins',
#   'ingredients': ['20-25 dumpling wrappers',
#    '300g ground pork',
#    '1 cup cabbage, finely shredded',
#    '1 tablespoon soy sauce',
#    '1 teaspoon sesame oil',
#    '1 teaspoon ginger, grated',
#    '2 tablespoons vegetable oil',
#    '1/4 cup water'],
#   'directions': ['Mix pork, cabbage, soy sauce, sesame oil, and ginger in a bowl.',
#    'Place a teaspoon of filling in the center of a wrapper, moisten edges, and fold/pleat to seal.',
#    'Heat oil in a flat skillet and arrange dumplings in a single layer.',
#    'Fry for 2 minutes until bottoms are golden.',
#    'Pour in water and immediately cover with a lid to steam for 5-7 minutes.',
#    'Remove lid and cook until water evaporates and bottoms are crispy again.']},
#  {'id': 106,
#   'name': 'Hot and Sour Soup',
#   'cuisine': 'Chinese',
#   'servings': 4,
#   'prep_time': '15 mins',
#   'cook_time': '15 mins',
#   'total_time': '30 mins',
#   'ingredients': ['4 cups chicken or vegetable broth',
#    '1/2 cup tofu, cut into matchsticks',
#    '1/4 cup bamboo shoots, sliced',
#    '2 tablespoons soy sauce',
#    '1/4 cup rice vinegar',
#    '1 teaspoon white pepper',
#    '1 egg, beaten',
#    '2 tablespoons cornstarch slurry'],
#   'directions': ['Bring broth to a boil in a large pot.',
#    'Add tofu, bamboo shoots, soy sauce, and white pepper.',
#    'Stir in the cornstarch slurry and simmer until thickened.',
#    'Slowly drizzle in the beaten egg while stirring gently to create ribbons.',
#    "Stir in the rice vinegar at the very end to preserve the 'sour' punch.",
#    'Garnish with green onions.']},
#  {'id': 107,
#   'name': 'Chow Mein',
#   'cuisine': 'Chinese',
#   'servings': 2,
#   'prep_time': '15 mins',
#   'cook_time': '10 mins',
#   'total_time': '25 mins',
#   'ingredients': ['200g chow mein noodles',
#    '1 cup cabbage, sliced',
#    '1 carrot, julienned',
#    '2 tablespoons soy sauce',
#    '1 tablespoon oyster sauce',
#    '1 teaspoon sugar',
#    '2 tablespoons vegetable oil'],
#   'directions': ['Boil noodles according to package instructions, drain, and set aside.',
#    'Heat oil in a wok and stir-fry cabbage and carrots for 3 minutes.',
#    'Add the noodles to the wok.',
#    'Mix soy sauce, oyster sauce, and sugar, then pour over the noodles.',
#    'Toss at high heat for 2-3 minutes until noodles are slightly charred and well coated.',
#    'Serve hot.']},
#  {'id': 108,
#   'name': 'Wonton Soup',
#   'cuisine': 'Chinese (Cantonese)',
#   'servings': 3,
#   'prep_time': '30 mins',
#   'cook_time': '10 mins',
#   'total_time': '40 mins',
#   'ingredients': ['12-15 frozen or fresh wontons',
#    '4 cups chicken broth',
#    '1 tablespoon soy sauce',
#    '1/2 teaspoon sesame oil',
#    '1/2 cup bok choy leaves',
#    'Green onions for garnish'],
#   'directions': ['Bring chicken broth and soy sauce to a boil in a pot.',
#    'Add the wontons and simmer for 5 minutes (or until they float).',
#    'Add bok choy and cook for 1 minute until wilted.',
#    'Turn off heat and stir in sesame oil.',
#    'Ladle into bowls and garnish with green onions.']},
#  {'id': 109,
#   'name': 'Honey Walnut Shrimp',
#   'cuisine': 'Chinese (Hong Kong Style)',
#   'servings': 3,
#   'prep_time': '20 mins',
#   'cook_time': '15 mins',
#   'total_time': '35 mins',
#   'ingredients': ['500g large shrimp, peeled and deveined',
#    '1/2 cup cornstarch',
#    '2 eggs, beaten',
#    '1/4 cup mayonnaise',
#    '1 tablespoon honey',
#    '1 tablespoon condensed milk',
#    '1/2 cup candied walnuts',
#    'Oil for frying'],
#   'directions': ['Dip shrimp in egg, then coat with cornstarch.',
#    'Fry shrimp in hot oil until golden and crispy; drain.',
#    'In a large bowl, whisk together mayonnaise, honey, and condensed milk.',
#    'Toss the warm shrimp and candied walnuts into the sauce until evenly coated.',
#    'Serve immediately, usually garnished with steamed broccoli.']}]

# %% [markdown]
# ### Step 2: Define the vision LLM with LLaMA
#
# To generate meaningful textual descriptions from food images, you will use a vision-capable large language model (LLM). In this step, you will define and configure a **LLaMA-based vision model** that can process both images and text prompts.
#
# You will initialize the model with the appropriate credentials and inference parameters, and verify that it accepts image inputs and produces descriptive captions. This model will serve as the core component for converting visual information into natural language that can be integrated with your existing JSON-based knowledge structure.
#
# By completing this step, you will have a vision-enabled LLM ready to perform image captioning reliably and repeatably.

# %%
! ollama list
# Out:
# ]11;?\NAME                        ID              SIZE      MODIFIED
# llava:latest                8dd30f6b0cb1    4.7 GB    12 days ago
# llama3.2:latest             a80c4f17acd5    2.0 GB    13 days ago
# llama3.2:3b                 a80c4f17acd5    2.0 GB    13 days ago
# gemma4:latest               c6eb396dbd59    9.6 GB    4 months ago
# qwen3.5:27b                 7653528ba5cb    17 GB     5 months ago
# qwen35-uncensored:latest    443fb05972d8    6.7 GB    5 months ago
# deepseek-r1:latest          6995872bfe4c    5.2 GB    5 months ago
# deepseek-r1:8b              6995872bfe4c    5.2 GB    5 months ago
# codestral:latest            0898a8b286d5    12 GB     5 months ago
# devstral-2:latest           524a6607f0f5    74 GB     5 months ago
# qwen3-coder-next:latest     ca06e9e4087c    51 GB     6 months ago
# deepseek-coder:33b          acec7c0b0fd9    18 GB     6 months ago
# qwen3-coder:latest          06c1097efce0    18 GB     6 months ago

# %%
from langchain_ollama import ChatOllama
import base64

def vision_llm(system_msg, prompt_txt, image_path):
    model_id = 'llava:latest'

    # Define the model
    model = ChatOllama(
        model=model_id,
        temperature=0
    )

    ### Step 2.2: Encode the input image to a base64 string
    with open(image_path, "rb") as image_file:
        image_base64 = base64.b64encode(
            image_file.read()
        ).decode("utf-8")
    
    

    ### Step 2.3: Define the messages for the model
    messages = [
        (
            "system",
            system_msg
        ),
        (
            "user",
            [
                {
                    "type": "text",
                    "text": prompt_txt
                },
                {
                    "type": "image_url",
                    "image_url": f"data:image/png;base64,{image_base64}"
                }
            ]
        )
    ]
    

    ### Step 2.4: Get the response for the messages 

    response = model.invoke(messages)

    return response.content

# %% [markdown]
# ### Step 3: Design and validate prompts for the vision LLM
#
# To ensure the vision LLM generates useful and consistent image captions, careful prompt design is essential. In this step, you will create a prompt that instructs the model to focus on relevant visual details, such as ingredients, cooking style, and presentation, while avoiding unnecessary or speculative information.
#
# Once the prompt is defined, you will perform a simple unit test by running the model on a small sample of food images. This allows you to verify that the generated captions are accurate, concise, and suitable for integration into the existing JSON data structure.
#
# By the end of this step, you will have a validated prompt that reliably converts food images into high-quality textual descriptions.

# %%
### Your Code Here

### Define the food image caption prompts given a food name.
### The food name, as you have noticed, comes from the corresponding recipe data.
### You want to include the food name to ensure the model focuses on it while giving captions.
def image_caption_prompt_template(food_name):
    # food_name: the food name of the recipe

    ### Step 3.1: Design the prompts
    image_caption_system_msg = """
You are a food image analysis assistant.
Your task is to generate accurate, concise captions for food images.
Focus only on information that can be visually observed.
Do not invent ingredients, cooking methods, or details that cannot be determined from the image.
"""

    image_caption_prompt_txt = f"""
Analyze this image of {food_name}.

Provide a concise description of the dish, focusing on:
- The visible ingredients or food components
- The cooking style or texture, only when visually apparent
- The presentation and appearance

Do not speculate about ingredients or preparation methods that are not visible.
Return only a short, factual description suitable for a recipe dataset.
"""

    return image_caption_system_msg, image_caption_prompt_txt


### Test the prompts on the first recipe
### Step 3.2: Get the prompts with the food name of the first recipe
food_name=recipe_data[0]["name"]
image_caption_system_msg, image_caption_prompt_txt=image_caption_prompt_template(food_name)
### Step 3.3: Get the test response and print it
### Step 3.3: Get the test response and print it
image_path = "../data/synthetic_recipe_images/recipe1.png"

response = vision_llm(
    image_caption_system_msg,
    image_caption_prompt_txt,
    image_path
)

print(response)
# Out:
#  The image shows a classic Margherita pizza with a golden-brown crust, topped with tomato sauce, mozzarella cheese, and fresh basil leaves. The pizza is cut into eight slices and is garnished with a sprig of basil in the center. The pizza is presented on a wooden cutting board, and there is a small bowl of red sauce on the side. The background is neutral, emphasizing the pizza.

# %%
response
# Out:
# ' The image shows a classic Margherita pizza with a golden-brown crust, topped with tomato sauce, mozzarella cheese, and fresh basil leaves. The pizza is cut into eight slices and is garnished with a sprig of basil in the center. The pizza is presented on a wooden cutting board, and there is a small bowl of red sauce on the side. The background is neutral, emphasizing the pizza. '

# %% [markdown]
# ### Step 4: Caption all images and augment the data
#
# With a validated prompt and a working vision LLM, you will now scale the image captioning process across the entire dataset. In this step, you will iterate through all food images, generate captions for each one, and associate the results with their corresponding recipe or restaurant records.
#
# You will then augment the existing JSON data by adding the generated image captions as new fields, ensuring the final structure remains consistent and machine-readable. This enriched dataset combines textual and visual insights into a unified representation, extending the structured knowledge base created in the previous lessons.
#
# By the end of this step, you will have a multimodal JSON file that integrates image-derived descriptions with existing structured data, ready for downstream GenAI applications.

# %%
### Your Code Here:

### Get captions for each image in the dataset and add to the JSON file (up tp 15 minutes)
### recipe_data is the recipe you loaded in Step 1
for i in range(len(recipe_data)):
    if (i+1)%10 == 0:
        print(f'{i+1} out of {len(recipe_data)} is done')

    ### Step 4.1: Get the caption prompts
    food_name=recipe_data[i]["name"]
    image_path = f"../data/synthetic_recipe_images/recipe{i + 1}.png"
    image_caption_system_msg, image_caption_prompt_txt=image_caption_prompt_template(food_name)

    ### Step 4.2: Get the response with the prompts
    response = vision_llm(
    image_caption_system_msg,
    image_caption_prompt_txt,
    image_path
)

    ### Save the response as another item in the recipe data
    recipe_data[i]['image_description'] = response
print('ALL DONE!')
# Out:
# 10 out of 109 is done
# 20 out of 109 is done
# 30 out of 109 is done
# 40 out of 109 is done
# 50 out of 109 is done
# 60 out of 109 is done
# 70 out of 109 is done
# 80 out of 109 is done
# 90 out of 109 is done
# 100 out of 109 is done
# ALL DONE!

# %%
recipe_data[0]
# Out:
# {'id': 1,
#  'name': 'Classic Margherita Pizza',
#  'cuisine': 'Italian',
#  'servings': 2,
#  'prep_time': '20 mins',
#  'cook_time': '15 mins',
#  'total_time': '35 mins',
#  'ingredients': ['1 pizza dough ball (about 260g)',
#   '2 tablespoons tomato sauce',
#   '1 cup shredded mozzarella cheese',
#   '6-8 fresh basil leaves',
#   '1 tablespoon olive oil',
#   'pinch of salt',
#   'optional: grated parmesan'],
#  'directions': ['Preheat oven to 250°C (482°F) with a baking stone if available.',
#   'Roll out dough to a 12-inch circle on a floured surface.',
#   'Spread tomato sauce evenly over dough, leaving a 1/2-inch border.',
#   'Scatter mozzarella cheese over sauce.',
#   'Bake on the stone for 10-12 minutes until crust is crisp and cheese melts.',
#   'Finish with basil leaves, drizzle with olive oil, and season with salt and optional parmesan.',
#   'Slice and serve immediately.'],
#  'image_description': ' The image shows a classic Margherita pizza with a golden-brown crust, topped with tomato sauce, mozzarella cheese, and fresh basil leaves. The pizza is cut into eight slices and is presented on a wooden cutting board. The background is blurred, but it appears to be a kitchen or dining area with a wooden table and a bottle of sauce. '}

# %% [markdown]
# Take a screenshot of the Python code, clearly showing your implementation and the output from Step 2. Name the screenshot ```M1L2_caption_all_recipes.jpg```.

# %% [markdown]
# ### Step 5: Save the image-caption-augmented recipe data
#
# Save your data by running the following code.

# %%
filename = 'augmented_food_recipe.json'
with open(filename, 'w', encoding='utf-8') as f:
    json.dump(recipe_data, f, indent=4)

# %% [markdown]
# You can download the saved JSON file to your local folder. Be sure to store it in a safe location, as you will need it for future assignments.

# %% [markdown]
# ----

# %% [markdown]
# ## **Exercise 2: Preprocess the user visit history**
#
# In this exercise, you will largely replicate the workflow from **Exercise 1**. The core steps, data exploration, prompt design, model inference, and JSON augmentation, remain the same.
#
# The key difference lies in **prompt design**. Instead of focusing on food images, you will tailor your prompt to generate concise, informative descriptions from user visit history data, such as contextual cues from URLs or associated images combined with their written reviews. These prompts should emphasize elements that help explain user preferences and behavior while maintaining consistency with the existing JSON schema.
#
# By the end of this exercise, you will have enriched the user visit history data with structured, machine-readable descriptions, further expanding the multimodal knowledge base built throughout this lab.

# %% [markdown]
# ### Step 1: Load the user review data
#
# Similar to Step 1 of Exercise 1, complete the following code block to load and explore the user review data.

# %%
### Part 1
### Your Code Here

### Step 1.1: Load the review dataset with variable name user_review_data
with open("../data/Synthetic-User-Reviews.json", "r") as f:
    user_review_data = json.load(f)

### Step 1.2: Print the first review by key-value pairs
print(user_review_data[0].keys())
# Out:
# dict_keys(['reviewId', 'userId', 'itemId', 'title', 'text', 'date', 'rating', 'language', 'images'])

# %%
print(user_review_data[0]['images'])
# Out:
# ['https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/L0HyLOGuAlxwKZaCC8sJdg/Gemini-Generated-Image-523rkg523rkg523r.png','https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/YLCD9AYY985XxvP-K8CRbA/Gemini-Generated-Image-hy4y8why4y8why4y.png']

# %% [markdown]
# Let's look at the 'images' item. Although it looks like a list, it is actually a list in string type. Therefore, you need to be careful and convert the string to the actual Python list. Complete the code block below to display the first review image of the first restaurant visit.

# %%
### Part 2
### Your Code Here

### Get the image by requesting from the URL
import ast # needed to convert string representation of list to actual python list
import requests

### Convert the list of images of the first user into the actual python list
### Step 1.3: Use ast.literal_eval to convert
image_list=ast.literal_eval(user_review_data[0]['images'])
print(len(image_list))


### Step 1.4: Use the requests.get() method to get the image content
image=requests.get(image_list[0])


### Step 1.5: Write the image content in Step 1.4 to a temporary file 'review_image_placeholder.jpg'
with open('review_image_placeholder.jpg', 'wb') as f:
    f.write(image.content)


### Step 1.6: Open the 'review_image_placeholder.jpg', and show th image
from PIL import Image
image = Image.open('review_image_placeholder.jpg')
image
# Out:
# 2
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x1024>

# %% [markdown]
# ### Step 2: Define the prompt and the validation
#
# Again, you will design a prompt template for the vision task and perform a unit test to validate the model’s behavior. However, unlike the previous exercise, this prompt must **incorporate textual context from user reviews** to guide the image captioning process.
#
# In this step, you will define a prompt template function that takes user review text as input and uses it as contextual information when describing a food image. The system message assigns the model the role of a culinary expert, while the prompt instructs the model to generate a concise image description that aligns with the sentiment and details expressed in the reviews.
#
# After defining the prompt template, you will perform a unit test by running the vision LLM on a single image and its associated reviews. This test allows you to verify that the generated caption effectively combines visual information from the image with contextual cues from the reviews before applying the prompt at scale in later steps.

# %%
### Your Code Here:
### Prompt template: caption the images with the context of the reviews
def review_context_image_caption_prompt_template(reviews):
    # reviews: the written review content


        ### Step 2.1: Design your prompts
    review_context_image_caption_system_msg = """
You are a culinary expert and food image analysis assistant.
Your task is to describe food images accurately and concisely.
Use the provided user reviews as contextual information, but rely on
the image for visual details. Do not invent or assume details that
cannot be supported by the image or reviews.
"""

    review_context_image_caption_prompt_txt = f"""
Analyze the food image and generate a concise description of the dish.

Use the following user reviews as contextual information:
{reviews}

Combine the visual information from the image with relevant details
and sentiment expressed in the reviews. Focus on the dish's appearance,
visible ingredients, texture, presentation, and notable characteristics.

Do not make unsupported claims or add information that is not present
in either the image or the reviews.
Return only a short, factual description suitable for a recipe dataset.
"""

    return review_context_image_caption_system_msg, review_context_image_caption_prompt_txt 

### Step 2.2: Get the prompts

### Step 2.3: Get the response by the vision_llm you defined previously
image='review_image_placeholder.jpg'
review_context_image_caption_system_msg, review_context_image_caption_prompt_txt = review_context_image_caption_prompt_template(user_review_data[0]['text'])
response =vision_llm(review_context_image_caption_system_msg, review_context_image_caption_prompt_txt, image)

print(response)
# Out:
#  The image depicts a restaurant interior with a focus on a dish served in a large, open dining area. The dish appears to be a lavender-rubbed chicken, which is presented on a wooden table surrounded by potted plants and a rustic wooden bench. The chicken is garnished with herbs and is accompanied by a side of what seems to be a green salad. The overall presentation is elegant and inviting, with a warm, natural ambiance. The dish is likely a specialty of the restaurant, given the unique flavor profile suggested by the review.

# %%
user_review_data[0].keys()
# Out:
# dict_keys(['reviewId', 'userId', 'itemId', 'title', 'text', 'date', 'rating', 'language', 'images'])

# %% [markdown]
# ### Step 3: Caption all images and augment the data
#
# Now, you are ready to get all captions with a for loop! Complete and run the following code block to caption all the review images.

# %%
### Your Code Here

from tenacity import retry, stop_after_attempt, wait_exponential

### URL Request function with Retry
# Retries up to 10 times, starting at 1s and doubling (1s, 2s, 4s...)
@retry(stop=stop_after_attempt(10), wait=wait_exponential(multiplier=1, min=1, max=10))
def get_data_with_retry(url):
    response = requests.get(url, timeout=5)
    response.raise_for_status() # Must raise error for retry to trigger
    return response

### Start the for loop
for i in range(len(user_review_data)):
    ### Step 3.1: Convert the string to the Python list of image urls
    review_images = ast.literal_eval(user_review_data[i]['images'])
    review_text = user_review_data[i]['text']
    image_path='review_image_placeholder.jpg'

    review_image_captions = []
    if len(review_images) > 0:
        for img_url in review_images:
            try:
                ### Step 3.2: Use get_data_with_retry to get the image_data
                image_data = requests.get(img_url)
                print("Success!")
            except Exception as e:
                print(f"All retries failed at url {img_url}:", e)
                continue
            image = image_data.content
            with open('review_image_placeholder.jpg', 'wb') as img_file:
                img_file.write(image)

            ### Step 3.3: Get the prompts, get the response, and finally append the response to review_image_captions
            
            review_context_image_caption_system_msg, review_context_image_caption_prompt_txt = review_context_image_caption_prompt_template(review_text)

            response =vision_llm(review_context_image_caption_system_msg, review_context_image_caption_prompt_txt, image_path)
            # delete review_image_placeholder.jpg
            os.remove('review_image_placeholder.jpg')
            review_image_captions.append(response)
    print(f"Processed review {i}")
            
    ### Append the review_image_captions to the review data
    user_review_data[i]['image_captions'] = review_image_captions
print('ALL DONE!')
# Out:
# Success!
# Success!
# Processed review 0
# Success!
# Processed review 1
# Processed review 2
# Success!
# Processed review 3
# Success!
# Success!
# Processed review 4
# Processed review 5
# Success!
# Processed review 6
# Success!
# Processed review 7
# Processed review 8
# Success!
# Processed review 9
# ALL DONE!

# %%
len(user_review_data)
# Out:
# 10

# %% [markdown]
# ### Step 4: Save the image-caption-augmented user review data

# %% [markdown]
# Run the following code block to save the augmented review data:

# %%
filename = 'augmented_user_review.json'
with open(filename, 'w', encoding='utf-8') as f:
    json.dump(user_review_data, f, indent=4)

# %% [markdown]
# You can download the saved JSON file to your local folder. Be sure to store it in a safe location, as you will need it for future assignments.

# %% [markdown]
# ----

# %% [markdown]
# ## **Conclusion**
#
# You have successfully applied GenAI tools to transform the unstructured text data into a well-structured JSON file!
#
# ----

# %% [markdown]
# ## Authors

# %% [markdown]
# [Jianping (Mike) Ye](https://www.linkedin.com/in/jianping-ye/)

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2026-02-03|1|Jianping Ye|Create lab|
# |2026-02-10|2|Jojy John|ID Reviewed|-->

# %% [markdown]
# ©IBM Corporation. All rights reserved.
