# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Implement and Test a Multi-Agent Recommendation System

# %% [markdown]
# ## Introduction
# Earlier, you defined six specialized agents with distinct roles, goals, and backstories. In this lab, you will integrate these agents into a coordinated multi-agent workflow that generates restaurant and recipe recommendations from a single user input.
#
# You will design the workflow logic, implement the orchestration layer that coordinates agent execution, and test the system with various user inputs to ensure it produces high-quality recommendations.
#
#
# ## From individual agents to coordinated systems
# Individual agents are like expert consultants—each has specialized knowledge, but they need orchestration to work together effectively. A multi-agent system requires:
#
# 1. Workflow design: Defining the order in which agents execute
# 2. Data flow: Specifying how information passes between agents
# 3. Orchestration logic: Coordinating execution, handling dependencies, and managing state
# 4. Error handling: Ensuring that the system degrades gracefully if an agent fails
# 5. Output synthesis: Combining agent outputs into a cohesive final result
#
# ## Workflow patterns
# Multi-agent systems can follow different workflow patterns depending on the task requirements:
#
# #### 1. Sequential workflow
# Agents execute one after another in a predefined order. Each agent's output becomes the input for the next agent.
#
# Example:
# ```
# User Input → User Profile Generator → RAG Retriever → Food Trend Analyst →
# Food Style Expert → Nutrition Expert → Recommendation Expert → Final Output
# ```
#
# Advantages:
# - Simple to implement and debug
# - Clear data dependencies
# - Predictable execution flow
#
# Disadvantages:
# - Slower execution (no parallelism)
# - Bottlenecks if one agent is slow
# - Rigid structure
#
# #### 2. Parallel workflow
# Multiple agents execute simultaneously when they don't depend on each other's outputs. Results are aggregated once all agents complete.
#
# Example:
# ```
# User Profile → [RAG Retriever, Food Trend Analyst, Food Style Expert] → Recommendation Expert
# ```
# Advantages:
# - Faster execution through parallelism
# - Efficient use of resources
# - Scales well with multiple agents
#
# Disadvantages:
# - More complex coordination logic
# - Requires handling asynchronous results
# - Harder to debug
#
# ### 3. Hybrid workflow
# This workflow combines sequential and parallel patterns. Some agents run in parallel, while others depend on previous outputs.
#
# Example:
# ```
# User Profile → RAG Retriever → [Food Trend Analyst, Food Style Expert, Nutrition Expert] → Recommendation Expert
# ```
# Advantages:
# - Balances simplicity and efficiency
# - Optimizes for dependencies
# - Flexible design
#
# Disadvantages:
# - Requires careful dependency analysis
# - More complex than pure sequential
# - Needs robust orchestration logic

# %% [markdown]
# ## Workflow design for the recommendation system
# For your recommendation system, you will implement a hybrid workflow:
#
# Phase 1: User analysis (Sequential)
# - Agent: User Profile Generator
# - Input: User's restaurant visit history and social media posts
# - Output: Comprehensive user profile with preferences, dietary restrictions, and dining patterns
# - Rationale: This must happen first because all other agents need the user profile to function effectively.
#
# Phase 2: Data retrieval (Sequential)
# - Agent: RAG Retriever
# - Input: User profile from Phase 1
# - Output: Top 20 candidate restaurants and recipes from the vector database
# - Rationale: Retrieval depends on the user profile and must be completed before analysis agents can evaluate the candidates.
#
# Phase 3: Analysis (Parallel)
# - Agents: Food Trend Analyst, Food Style Expert, and Nutrition Expert
# - Input: User profile (from Phase 1) and retrieved candidates (from Phase 2)
# - Output: Three separate analyses focusing on trends, food styles, and nutrition
# - Rationale: These three agents perform independent analyses and can run simultaneously to save time. Each provides a different perspective on the retrieved candidates.
#
# Phase 4: Synthesis (Sequential)
# - Agent: Recommendation Expert
# - Input: User profile, retrieved candidates, and all three analyses from Phase 3
# - Output: Final list of top 5 restaurants and top 5 recipe recommendations with detailed explanations
# - Rationale: This agent must wait for all previous agents to complete, as it synthesizes their collective insights into final recommendations.

# %% [markdown]
# ## Orchestration with LangGraph
# You will use LangGraph, a framework built on LangChain for building stateful, multi-agent workflows. LangGraph provides:
# - State management: Shared state that all agents can read from and write to
# - Graph structure: Nodes (agents) and edges (transitions) that define the workflow
# - Conditional routing: Logic to determine which agent executes next
# - Checkpointing: Ability to save and resume workflow state
#
# ### Key LangGraph concepts
# 1. State: A shared dictionary that holds all information as it flows through the workflow. Agents read from the state, perform their tasks, and update the state with their outputs.
#
# 2. Nodes: Functions that represent agent tasks. Each node receives the current state, performs an action, and returns the updated state.
#
# 3. Edges: Connections between nodes that define the execution order. Edges can be:
#    - Normal edges: Always transition from node A to node B
#    - Conditional edges: Chooses the next node based on the current state
#
# 4. Graph: The complete workflow structure that connects all nodes and edges.

# %% [markdown]
# ## Testing the multi-agent system
# Once your workflow is implemented, you will test it with different user inputs to ensure that it handles various scenarios:
#
# <b> Test Case 1: The health-conscious user </b>
# - A user who prefers plant-based meals, avoids gluten, and enjoys Mediterranean cuisine.
# - Expected behavior: The system should retrieve vegan/vegetarian options, filter out gluten-containing items, and recommend Mediterranean restaurants and recipes.
#
# <b> Test Case 2: The adventurous foodie</b>
# - A user who loves trying new cuisines, has no dietary restrictions, and enjoys fine dining.
# - Expected behavior: The system should recommend diverse, high-end restaurants with unique offerings and complex recipes from various cuisines.
#
# <b> Test Case 3: The budget-conscious student</b>
# - A user who prefers quick, affordable meals, frequently orders delivery, and likes comfort food.
# - Expected behavior: The system should recommend budget-friendly restaurants with fast service and simple, satisfying recipes.
#
# <b> Test Case 4: A family with dietary restrictions</b>
# - User who needs kid-friendly options, has a family member with nut allergies, and prefers casual dining.
# - Expected behavior: The system should flag nut-containing items, recommend family-friendly restaurants, and suggest simple, accessible recipes.
#
#
# ## Evaluation criteria
# When testing your system, evaluate it on:
#
# 1. **Relevance**
# Do the recommendations match the user's stated preferences and history?
#
# 2. **Diversity**
# Are the recommendations varied, or does the system repeat similar suggestions?
#
# 3. **Coherence**
# Do the explanations make sense? Does the Recommendation Expert effectively synthesize insights from all agents?
#
# 4. **Dietary compliance**
# Does the system respect dietary restrictions and flag potential allergens?
#
# 5. **Timeliness**
# Are trend-based recommendations actually aligned with current food trends?
#
#
#
# ## Key considerations
# As you implement your multi-agent system, keep these principles in mind:
#
# - State consistency: Ensure that each agent updates the state in a predictable format
# - Error handling: Implement try-catch blocks to handle agent failures gracefully
# - Logging: Add print statements or logging to track workflow execution
# - Modularity: Keep node functions focused on single responsibilities
# - Testability: Design the system so you can test individual nodes in isolation
# - Performance: Monitor execution time and identify bottlenecks

# %% [markdown]
# ## Learning Objectives
# After completing this lab, you'll be able to:
#
# - Design and implement a hybrid workflow for coordinating multiple agents
# - Use LangGraph to build stateful multi-agent systems
# - Create node functions that update shared state
# - Build workflow graphs with sequential and parallel execution patterns
# - Test multi-agent systems with diverse user inputs
# - Evaluate recommendation quality and agent coordination

# %% [markdown]
# ## Table of contents
#
# <font size = 3>
#
# 1. [Install the required libraries](#Install-the-required-libraries)
# 2. [Import required libraries](#Import-required-libraries)
# 3. [Import agent configurations](#Import-agent-configurations)
# 4. [Define the shared state structure](#Define-the-shared-state-structure)
# 5. [Question 1: How many fields are in the AgentState structure?](#Question-1:-How-many-fields-are-in-the-AgentState-structure?)
# 6. [Create the node functions](#Create-the-node-functions)
# 7. [Helper function: Call agent](#Helper-function:-Call-agent)
# 8. [Node 1: Generate the user profile](#Node-1:-Generate-the-user-profile)
# 9. [Node 2: Retrieve the candidates](#Node-2:-Retrieve-the-candidates)
# 10. [Node 3: Analyze trends](#Node-3:-Analyze-trends)
# 11. [Node 4: Analyze food styles](#Node-4:-Analyze-food-styles)
#      1. [Task 1: Complete the node_analyze_styles function](#Task-1:-Complete-the-node_analyze_styles-function)
# 12. [Node 5: Evaluate nutrition](#Node-5:-Evaluate-nutrition)
# 13. [Node 6: Generate recommendations](#Node-6:-Generate-recommendations)
# 14. [Question 2: Which three nodes execute in parallel during Phase 3?](#Question-2:-Which-three-nodes-execute-in-parallel-during-Phase-3?)
# 15. [Build the workflow graph](#Build-the-workflow-graph)
# 16. [Test the multi-agent system](#Test-the-multi-agent-system)
#      1. [Test Case 1: The health-conscious user](#Test-Case-1:-The-health-conscious-user)
#      2. [Test Case 2: The adventurous foodie](#Test-Case-2:-The-adventurous-foodie)
# 17. [Question 3: Based on the workflow design, which phase takes the longest time to execute and why?](#Question-3:-Based-on-the-workflow-design,-which-phase-takes-the-longest-time-to-execute-and-why?)
# 18. [Evaluate the recommendations](#Evaluate-the-recommendations)
# 19. [Question 4: What is the purpose of the workflow_step field in the AgentState?](#Question-4:-What-is-the-purpose-of-the-workflow_step-field-in-the-AgentState?)
#
# </font>
# </div>

# %% [markdown]
# ## **Screenshot requirement for this lab**
#
# You will be prompted to take a screenshot and save it on your own device. You will need this screenshot either to answer graded quiz questions or to upload as your submission for the Final Project at the end of this course. You can use various free screen-grabbing tools or your operating system's shortcut keys to do this (for example, `Alt+PrintScreen` on Windows and `Command+shift+4` on Mac).
# **Note**: The screenshot can be saved with either the **.jpg** or **.png** extension.

# %% [markdown]
# ----

# %% [markdown]
# ### Install the required libraries
#
#
# All the required libraries are __not__ pre-installed in the Skills Network Labs environment. __You need to run the following cell__ to install them, and this might take a few minutes.

# %%
# %%capture
# %pip install openai==1.99.9 | tail -n 1
# %pip install langchain==0.3.0
# %pip install langchain-openai==0.2.0
# %pip install langchain-community==0.3.0
# %pip install langgraph==0.2.0

# %% [markdown]
# ### Import required libraries
#
# Let's import the libraries needed for building the multi-agent workflow.

# %%
import os
import json
from typing import TypedDict, List, Dict, Any
from concurrent.futures import ThreadPoolExecutor, as_completed
from langchain_ollama import ChatOllama

# %%
# Configure OpenAI API
# os.environ["OPENAI_API_KEY"] = "your-api-key-here"

# client = OpenAI()
# MODEL = "gpt-5"
model_id = "llama3.2:3b"

    # Define the model
client = ChatOllama(
        model=model_id,
        temperature=0
    )

# %% [markdown]
# ### Import agent configurations
#
# Let's bring in the agent configurations you've worked on earlier.

# %%
# Agent configurations from Lesson 1
agent_configs = {
    "user_profile_generator": {
        "role": "User Profile Generator",
        "goal": "Analyze user restaurant visit history and social media posts to create a comprehensive profile.",
        "backstory": """You are an expert user behavior analyst with 10 years of experience in the food industry. 
        You excel at identifying patterns in dining behavior and building rich user profiles."""
    },
    "rag_retriever": {
        "role": "RAG Retriever",
        "goal": "Query multimodal vector databases to retrieve relevant restaurants and recipes.",
        "backstory": """You are a data retrieval specialist with expertise in vector databases and semantic search."""
    },
    "food_trend_analyst": {
        "role": "Food Trend Analyst",
        "goal": "Identify current food trends and emerging dining concepts.",
        "backstory": """You are a culinary journalist who has spent 15 years covering food culture across global markets."""
    },
    "food_style_expert": {
        "role": "Food Style Expert",
        "goal": "Analyze cuisine types and flavor profiles to match user preferences.",
        "backstory": """You are a trained chef and culinary anthropologist with expertise in global cuisines."""
    },
    "nutrition_expert": {
        "role": "Nutrition Expert",
        "goal": "Evaluate nutritional content and ensure dietary compliance.",
        "backstory": """You are a registered dietitian with 8 years of clinical experience."""
    },
    "recommendation_expert": {
        "role": "Recommendation Expert",
        "goal": "Synthesize insights from all agents into final recommendations.",
        "backstory": """You are a recommendation systems architect with experience in personalization engines."""
    }
}

print("Agent configurations loaded successfully!")
# Out:
# Agent configurations loaded successfully!

# %% [markdown]
# ## Define the shared state structure
#
# The shared state flows through the entire workflow. Each agent reads from it and updates it with their outputs.
#
# You'll use a TypedDict to define the state structure.

# %%
# Define the shared state structure as a dictionary.
# Every node reads from and writes to this state.
INITIAL_STATE = {
    # Input
    "user_input": "",
    
    # Phase 1: User Analysis
    "user_profile": {},
    
    # Phase 2: Data Retrieval
    "retrieved_restaurants": [],
    "retrieved_recipes": [],
    
    # Phase 3: Analysis (Parallel)
    "trend_analysis": {},
    "style_analysis": {},
    "nutrition_analysis": {},
    
    # Phase 4: Synthesis
    "final_recommendations": {},
    
    # Metadata
    "workflow_step": "start"
}

print(f"State structure defined with {len(INITIAL_STATE)} fields:")
for key in INITIAL_STATE:
    print(f"  - {key}")
# Out:
# State structure defined with 9 fields:
#   - user_input
#   - user_profile
#   - retrieved_restaurants
#   - retrieved_recipes
#   - trend_analysis
#   - style_analysis
#   - nutrition_analysis
#   - final_recommendations
#   - workflow_step

# %% [markdown]
# ### **Question 1**: How many fields are in the AgentState structure?

# %% [markdown]
# #### **Answer**: 9

# %% [markdown]
# ## Create the node functions
#
# Each node represents an agent's task. A node function:
# 1. Receives the current state
# 2. Performs the agent's task
# 3. Returns an updated state
#
# Let's create node functions for all six agents.

# %% [markdown]
# ### Helper function: Call agent

# %%
def call_agent(agent_key: str, user_message: str) -> str:
    """Call an agent with a specific message and return its response."""
    config = agent_configs[agent_key]
    
    system_prompt = f"""You are a {config['role']}.
    
        Your goal: {config['goal']}

        Your background: {config['backstory']}

        Respond with structured, actionable output."""
    
    messages = [
        ("system", system_prompt),
        ("user", user_message)
    ]

    # Get response

    response = client.invoke(messages)

    # Extract text
    output_text = response.content

  
    return output_text

# %%
import re
import json

def extract_json(text: str) -> dict:
    """Robust JSON extractor that handles multiple objects, markdown, and noise."""
    if not text or not text.strip():
        raise ValueError("Empty response from model")

    # Remove markdown fences
    cleaned = re.sub(r"```(?:json)?\s*", "", text, flags=re.IGNORECASE)
    cleaned = re.sub(r"```", "", cleaned)

    # Try to find all JSON objects
    objects = []
    # More aggressive pattern that can handle nested structures better
    for match in re.finditer(r"\{(?:[^{}]|(?:\{[^{}]*\}))*\}", cleaned, re.DOTALL):
        candidate = match.group(0)
        try:
            obj = json.loads(candidate)
            if isinstance(obj, dict):
                objects.append(obj)
        except json.JSONDecodeError:
            continue

    if objects:
        # Merge all found objects
        merged = {}
        for obj in objects:
            merged.update(obj)
        return merged

    # Last resort: try the whole cleaned string
    try:
        return json.loads(cleaned.strip())
    except json.JSONDecodeError as e:
        raise ValueError(f"No valid JSON found. Original error: {e}\nCleaned text starts with: {cleaned[:200]!r}")

# %% [markdown]
# ### Node 1: Generate the user profile

# %%
def node_generate_profile(state: dict) -> dict:
    """Generate user profile from input data."""
    print("\n[Phase 1] Generating user profile...")
    
    user_message = f"""Analyze this user data and create a comprehensive profile:

{state['user_input']}

Return ONLY valid JSON.
Do not use markdown.
Do not use ```json.
Do not add explanations before or after the JSON.

The JSON must contain exactly these keys:
- favorite_cuisines (list)
- dietary_restrictions (list)
- dining_occasions (list)
- price_range (string)
- adventurousness_score (1-10)
- flavor_preferences (list)
- summary (string)
"""
    
    try:
        response = call_agent("user_profile_generator", user_message)
        user_profile = extract_json(response)
        print(f"✓ User profile generated: {user_profile.get('summary', 'No summary')}")
    except Exception as e:
        print(f"⚠ Error generating profile: {e}")
        user_profile = {"error": str(e)}
    
    state["user_profile"] = user_profile
    state["workflow_step"] = "profile_generated"
    return state

# %% [markdown]
# ### Test node_generate_profile

# %%
test_user_1 = """
Restaurant Visit History:
- Visited "Green Bowl" (Vegan, $$) 8 times
- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times
- Visited "Juice Lab" (Smoothies, $) 3 times

Social Media Posts:
- "Loving my plant-based journey! 🌱"
- "This gluten-free Mediterranean bowl is amazing!"
- "Fresh juice is the best way to start the day."

Dietary Restrictions: Vegan, Gluten-Free
"""
state = {
        "user_input": test_user_1,
        "user_profile": {},
        "retrieved_restaurants": [],
        "retrieved_recipes": [],
        "trend_analysis": {},
        "style_analysis": {},
        "nutrition_analysis": {},
        "final_recommendations": {},
        "workflow_step": "start"
    }
state=node_generate_profile(state)
state
# Out:
# [Phase 1] Generating user profile...
# ✓ User profile generated: A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.
# {'user_input': '\nRestaurant Visit History:\n- Visited "Green Bowl" (Vegan, $$) 8 times\n- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times\n- Visited "Juice Lab" (Smoothies, $) 3 times\n\nSocial Media Posts:\n- "Loving my plant-based journey! 🌱"\n- "This gluten-free Mediterranean bowl is amazing!"\n- "Fresh juice is the best way to start the day."\n\nDietary Restrictions: Vegan, Gluten-Free\n',
#  'user_profile': {'favorite_cuisines': ['Vegan', 'Mediterranean'],
#   'dietary_restrictions': ['Vegan', 'Gluten-Free'],
#   'dining_occasions': ['Health-Conscious', 'Special Occasions'],
#   'price_range': '$$$',
#   'adventurousness_score': 8,
#   'flavor_preferences': ['Plant-based', 'Gluten-free'],
#   'summary': 'A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.'},
#  'retrieved_restaurants': [],
#  'retrieved_recipes': [],
#  'trend_analysis': {},
#  'style_analysis': {},
#  'nutrition_analysis': {},
#  'final_recommendations': {},
#  'workflow_step': 'profile_generated'}

# %% [markdown]
# ### Node 2: Retrieve the candidates

# %%
def node_retrieve_candidates(state: dict) -> dict:
    """Retrieve restaurant and recipe candidates from vector database."""
    print("\n[Phase 2] Retrieving candidates from vector database...")
    
    profile = state["user_profile"]
    
    user_message = f"""Based on this user profile:
{json.dumps(profile, indent=2)}

Simulate retrieving top 20 restaurants and top 20 recipes from a vector database.

Return JSON with two arrays:
- restaurants: [{{"name": str, "cuisine": str, "price": str, "rating": float, "description": str}}]
- recipes: [{{"name": str, "cuisine": str, "difficulty": str, "prep_time": str, "description": str}}]

Make the results realistic and diverse.
"""
    
    try:
        response = call_agent("rag_retriever", user_message)
        retrieved_data = extract_json(response)
        restaurants = retrieved_data.get("restaurants", [])
        recipes = retrieved_data.get("recipes", [])
        print(f"✓ Retrieved {len(restaurants)} restaurants and {len(recipes)} recipes")
    except Exception as e:
        print(f"⚠ Error retrieving candidates: {e}")
        restaurants, recipes = [], []
    
    state["retrieved_restaurants"] = restaurants
    state["retrieved_recipes"] = recipes
    state["workflow_step"] = "candidates_retrieved"
    return state

# %%
state = node_retrieve_candidates(state)
state
# Out:
# [Phase 2] Retrieving candidates from vector database...
# ✓ Retrieved 19 restaurants and 19 recipes
# {'user_input': '\nRestaurant Visit History:\n- Visited "Green Bowl" (Vegan, $$) 8 times\n- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times\n- Visited "Juice Lab" (Smoothies, $) 3 times\n\nSocial Media Posts:\n- "Loving my plant-based journey! 🌱"\n- "This gluten-free Mediterranean bowl is amazing!"\n- "Fresh juice is the best way to start the day."\n\nDietary Restrictions: Vegan, Gluten-Free\n',
#  'user_profile': {'favorite_cuisines': ['Vegan', 'Mediterranean'],
#   'dietary_restrictions': ['Vegan', 'Gluten-Free'],
#   'dining_occasions': ['Health-Conscious', 'Special Occasions'],
#   'price_range': '$$$',
#   'adventurousness_score': 8,
#   'flavor_preferences': ['Plant-based', 'Gluten-free'],
#   'summary': 'A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.'},
#  'retrieved_restaurants': [{'name': 'The Greenhouse',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.8,
#    'description': 'A plant-based restaurant with a focus on seasonal, locally-sourced ingredients.'},
#   {'name': 'Mediterranean Oasis',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A cozy restaurant serving traditional Mediterranean dishes with a modern twist.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'Vegan Vibes',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A vibrant restaurant serving creative, plant-based dishes in a lively setting.'},
#   {'name': 'The Mediterranean Table',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'},
#   {'name': 'Plant-Based Paradise',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A health-conscious restaurant offering a variety of plant-based options in a serene atmosphere.'},
#   {'name': 'Gluten-Free Delights',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A bakery and café serving a range of gluten-free treats and light meals.'},
#   {'name': 'The Health Club',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.7,
#    'description': 'A fitness-focused restaurant serving healthy, plant-based options in a modern setting.'},
#   {'name': 'Special Occasion Bistro',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A luxurious restaurant offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Cafe',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A cozy café serving a variety of plant-based options in a relaxed atmosphere.'},
#   {'name': 'Gluten-Free Fusion',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A restaurant offering a fusion of gluten-free and international cuisine.'},
#   {'name': 'The Mediterranean Market',
#    'cuisine': 'Mediterranean',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A market and deli serving traditional Mediterranean dishes and ingredients.'},
#   {'name': 'Vegan Fusion',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.4,
#    'description': 'A restaurant offering a fusion of vegan and international cuisine.'},
#   {'name': 'Gluten-Free Deli',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A deli serving a variety of gluten-free options in a casual setting.'},
#   {'name': 'The Health Food Store',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A health food store and café serving healthy, plant-based options.'},
#   {'name': 'Special Occasion Catering',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A catering service offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Restaurant',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A restaurant offering a variety of plant-based options in a modern setting.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'The Mediterranean Restaurant',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'}],
#  'retrieved_recipes': [{'name': 'Roasted Vegetable Bowl',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A hearty bowl filled with roasted vegetables, quinoa, and a tangy tahini sauce.'},
#   {'name': 'Grilled Halloumi with Honey and Figs',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A classic Cypriot dish featuring grilled halloumi cheese, honey, and fresh figs.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Soup',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting soup made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Chicken Shawarma',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled chicken, served in a warm pita with tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Apple Crisp',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A warm and comforting dessert made with gluten-free oats, apples, and a crunchy streusel topping.'},
#   {'name': 'Vegan Black Bean Tacos',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and nutritious dish featuring black beans, roasted vegetables, and a tangy slaw made with red cabbage and lime juice.'},
#   {'name': 'Stuffed Zucchini Boats',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A healthy and delicious dish featuring zucchinis stuffed with a mix of rice, herbs, and feta cheese, baked to perfection.'},
#   {'name': 'Gluten-Free Pumpkin Spice Muffins',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious and comforting muffin made with gluten-free flours, pumpkin puree, and a hint of cinnamon.'},
#   {'name': 'Vegan Chickpea Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with chickpeas, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Lamb Koftas',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled lamb koftas, served with a side of tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Curry',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting curry made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'}],
#  'trend_analysis': {},
#  'style_analysis': {},
#  'nutrition_analysis': {},
#  'final_recommendations': {},
#  'workflow_step': 'candidates_retrieved'}

# %% [markdown]
# ### Node 3: Analyze trends

# %%
def node_analyze_trends(state: dict) -> dict:
    """Analyze food trends in the retrieved candidates."""
    print("\n[Phase 3a] Analyzing food trends...")
    
    restaurants = state["retrieved_restaurants"]
    recipes = state["retrieved_recipes"]
    
    user_message = f"""Analyze current food trends in these options:

Restaurants: {json.dumps(restaurants[:5], indent=2)}
Recipes: {json.dumps(recipes[:5], indent=2)}

Identify 3-5 relevant trends and explain how they align with modern dining culture.
Return JSON: {{"trends": [{{"name": str, "description": str, "relevance": str}}]}}
"""
    
    try:
        response = call_agent("food_trend_analyst", user_message)
        trend_analysis = extract_json(response)
        print(f"✓ Identified {len(trend_analysis.get('trends', []))} trends")
    except Exception as e:
        print(f"⚠ Error analyzing trends: {e}")
        trend_analysis = {"error": str(e)}
    
    state["trend_analysis"] = trend_analysis
    return state

# %%
state=node_analyze_trends(state)
state
# Out:
# [Phase 3a] Analyzing food trends...
# ✓ Identified 5 trends
# {'user_input': '\nRestaurant Visit History:\n- Visited "Green Bowl" (Vegan, $$) 8 times\n- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times\n- Visited "Juice Lab" (Smoothies, $) 3 times\n\nSocial Media Posts:\n- "Loving my plant-based journey! 🌱"\n- "This gluten-free Mediterranean bowl is amazing!"\n- "Fresh juice is the best way to start the day."\n\nDietary Restrictions: Vegan, Gluten-Free\n',
#  'user_profile': {'favorite_cuisines': ['Vegan', 'Mediterranean'],
#   'dietary_restrictions': ['Vegan', 'Gluten-Free'],
#   'dining_occasions': ['Health-Conscious', 'Special Occasions'],
#   'price_range': '$$$',
#   'adventurousness_score': 8,
#   'flavor_preferences': ['Plant-based', 'Gluten-free'],
#   'summary': 'A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.'},
#  'retrieved_restaurants': [{'name': 'The Greenhouse',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.8,
#    'description': 'A plant-based restaurant with a focus on seasonal, locally-sourced ingredients.'},
#   {'name': 'Mediterranean Oasis',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A cozy restaurant serving traditional Mediterranean dishes with a modern twist.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'Vegan Vibes',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A vibrant restaurant serving creative, plant-based dishes in a lively setting.'},
#   {'name': 'The Mediterranean Table',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'},
#   {'name': 'Plant-Based Paradise',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A health-conscious restaurant offering a variety of plant-based options in a serene atmosphere.'},
#   {'name': 'Gluten-Free Delights',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A bakery and café serving a range of gluten-free treats and light meals.'},
#   {'name': 'The Health Club',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.7,
#    'description': 'A fitness-focused restaurant serving healthy, plant-based options in a modern setting.'},
#   {'name': 'Special Occasion Bistro',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A luxurious restaurant offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Cafe',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A cozy café serving a variety of plant-based options in a relaxed atmosphere.'},
#   {'name': 'Gluten-Free Fusion',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A restaurant offering a fusion of gluten-free and international cuisine.'},
#   {'name': 'The Mediterranean Market',
#    'cuisine': 'Mediterranean',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A market and deli serving traditional Mediterranean dishes and ingredients.'},
#   {'name': 'Vegan Fusion',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.4,
#    'description': 'A restaurant offering a fusion of vegan and international cuisine.'},
#   {'name': 'Gluten-Free Deli',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A deli serving a variety of gluten-free options in a casual setting.'},
#   {'name': 'The Health Food Store',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A health food store and café serving healthy, plant-based options.'},
#   {'name': 'Special Occasion Catering',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A catering service offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Restaurant',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A restaurant offering a variety of plant-based options in a modern setting.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'The Mediterranean Restaurant',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'}],
#  'retrieved_recipes': [{'name': 'Roasted Vegetable Bowl',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A hearty bowl filled with roasted vegetables, quinoa, and a tangy tahini sauce.'},
#   {'name': 'Grilled Halloumi with Honey and Figs',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A classic Cypriot dish featuring grilled halloumi cheese, honey, and fresh figs.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Soup',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting soup made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Chicken Shawarma',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled chicken, served in a warm pita with tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Apple Crisp',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A warm and comforting dessert made with gluten-free oats, apples, and a crunchy streusel topping.'},
#   {'name': 'Vegan Black Bean Tacos',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and nutritious dish featuring black beans, roasted vegetables, and a tangy slaw made with red cabbage and lime juice.'},
#   {'name': 'Stuffed Zucchini Boats',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A healthy and delicious dish featuring zucchinis stuffed with a mix of rice, herbs, and feta cheese, baked to perfection.'},
#   {'name': 'Gluten-Free Pumpkin Spice Muffins',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious and comforting muffin made with gluten-free flours, pumpkin puree, and a hint of cinnamon.'},
#   {'name': 'Vegan Chickpea Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with chickpeas, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Lamb Koftas',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled lamb koftas, served with a side of tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Curry',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting curry made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'}],
#  'trend_analysis': {'trends': [{'name': 'Plant-Based Cuisine',
#     'description': 'The increasing popularity of plant-based diets and the rise of vegan and vegetarian options in restaurants.',
#     'relevance': 'High'},
#    {'name': 'Global Cuisine Revival',
#     'description': 'The resurgence of interest in traditional Mediterranean and Middle Eastern cuisine, with a focus on fresh ingredients and bold flavors.',
#     'relevance': 'High'},
#    {'name': 'Gluten-Free and Special Diets',
#     'description': 'The growing demand for gluten-free and other special diets, with restaurants adapting to cater to these needs and offering innovative solutions.',
#     'relevance': 'Medium'},
#    {'name': 'Sustainable and Locally Sourced',
#     'description': 'The emphasis on sustainability and locally sourced ingredients, with restaurants prioritizing environmentally friendly practices and supporting local farmers.',
#     'relevance': 'Medium'},
#    {'name': 'Easy and Accessible Recipes',
#     'description': 'The increasing popularity of easy and accessible recipes, with a focus on quick and convenient meal options that cater to busy lifestyles.',
#     'relevance': 'Low'}]},
#  'style_analysis': {},
#  'nutrition_analysis': {},
#  'final_recommendations': {},
#  'workflow_step': 'candidates_retrieved'}

# %% [markdown]
# ### Node 4: Analyze food styles

# %% [markdown]
# ### **Task 1**: Complete the `node_analyze_styles` function
#
# Fill in the `user_message` to instruct the Food Style Expert to analyze cuisine types and flavor profiles.

# %%
def node_analyze_styles(state: dict) -> dict:
    """Analyze food styles and flavor profiles."""
    print("\n[Phase 3b] Analyzing food styles...")

    restaurants = state["retrieved_restaurants"]
    recipes = state["retrieved_recipes"]
    profile = state["user_profile"]

    user_message = f"""
Analyze the food styles and flavor profiles in these restaurant and recipe options.

USER PROFILE:
{json.dumps(profile, indent=2)}

RESTAURANTS:
{json.dumps(restaurants[:5], indent=2)}

RECIPES:
{json.dumps(recipes[:5], indent=2)}

Analyze the options from the perspective of:
1. Cuisine styles
2. Flavor profiles
3. Main ingredients
4. Cooking techniques
5. Overall dining style
6. How well each style matches the user's preferences

Identify the most relevant food styles and flavor profiles.

Return JSON in exactly this format:
{{
    "styles": [
        {{
            "name": "string",
            "description": "string",
            "flavor_profile": "string",
            "key_ingredients": ["string"],
            "cooking_techniques": ["string"],
            "user_fit": "string"
        }}
    ]
}}
"""

    try:
        response = call_agent("food_style_expert", user_message)
        style_analysis = extract_json(response)
        print("✓ Style analysis completed")

    except Exception as e:
        print(f"⚠ Error analyzing styles: {e}")
        style_analysis = {"error": str(e)}

    state["style_analysis"] = style_analysis

    return state

# %%
state=node_analyze_styles(state)
state
# Out:
# [Phase 3b] Analyzing food styles...
# ✓ Style analysis completed
# {'user_input': '\nRestaurant Visit History:\n- Visited "Green Bowl" (Vegan, $$) 8 times\n- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times\n- Visited "Juice Lab" (Smoothies, $) 3 times\n\nSocial Media Posts:\n- "Loving my plant-based journey! 🌱"\n- "This gluten-free Mediterranean bowl is amazing!"\n- "Fresh juice is the best way to start the day."\n\nDietary Restrictions: Vegan, Gluten-Free\n',
#  'user_profile': {'favorite_cuisines': ['Vegan', 'Mediterranean'],
#   'dietary_restrictions': ['Vegan', 'Gluten-Free'],
#   'dining_occasions': ['Health-Conscious', 'Special Occasions'],
#   'price_range': '$$$',
#   'adventurousness_score': 8,
#   'flavor_preferences': ['Plant-based', 'Gluten-free'],
#   'summary': 'A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.'},
#  'retrieved_restaurants': [{'name': 'The Greenhouse',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.8,
#    'description': 'A plant-based restaurant with a focus on seasonal, locally-sourced ingredients.'},
#   {'name': 'Mediterranean Oasis',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A cozy restaurant serving traditional Mediterranean dishes with a modern twist.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'Vegan Vibes',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A vibrant restaurant serving creative, plant-based dishes in a lively setting.'},
#   {'name': 'The Mediterranean Table',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'},
#   {'name': 'Plant-Based Paradise',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A health-conscious restaurant offering a variety of plant-based options in a serene atmosphere.'},
#   {'name': 'Gluten-Free Delights',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A bakery and café serving a range of gluten-free treats and light meals.'},
#   {'name': 'The Health Club',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.7,
#    'description': 'A fitness-focused restaurant serving healthy, plant-based options in a modern setting.'},
#   {'name': 'Special Occasion Bistro',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A luxurious restaurant offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Cafe',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A cozy café serving a variety of plant-based options in a relaxed atmosphere.'},
#   {'name': 'Gluten-Free Fusion',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A restaurant offering a fusion of gluten-free and international cuisine.'},
#   {'name': 'The Mediterranean Market',
#    'cuisine': 'Mediterranean',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A market and deli serving traditional Mediterranean dishes and ingredients.'},
#   {'name': 'Vegan Fusion',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.4,
#    'description': 'A restaurant offering a fusion of vegan and international cuisine.'},
#   {'name': 'Gluten-Free Deli',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A deli serving a variety of gluten-free options in a casual setting.'},
#   {'name': 'The Health Food Store',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A health food store and café serving healthy, plant-based options.'},
#   {'name': 'Special Occasion Catering',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A catering service offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Restaurant',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A restaurant offering a variety of plant-based options in a modern setting.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'The Mediterranean Restaurant',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'}],
#  'retrieved_recipes': [{'name': 'Roasted Vegetable Bowl',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A hearty bowl filled with roasted vegetables, quinoa, and a tangy tahini sauce.'},
#   {'name': 'Grilled Halloumi with Honey and Figs',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A classic Cypriot dish featuring grilled halloumi cheese, honey, and fresh figs.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Soup',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting soup made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Chicken Shawarma',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled chicken, served in a warm pita with tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Apple Crisp',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A warm and comforting dessert made with gluten-free oats, apples, and a crunchy streusel topping.'},
#   {'name': 'Vegan Black Bean Tacos',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and nutritious dish featuring black beans, roasted vegetables, and a tangy slaw made with red cabbage and lime juice.'},
#   {'name': 'Stuffed Zucchini Boats',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A healthy and delicious dish featuring zucchinis stuffed with a mix of rice, herbs, and feta cheese, baked to perfection.'},
#   {'name': 'Gluten-Free Pumpkin Spice Muffins',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious and comforting muffin made with gluten-free flours, pumpkin puree, and a hint of cinnamon.'},
#   {'name': 'Vegan Chickpea Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with chickpeas, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Lamb Koftas',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled lamb koftas, served with a side of tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Curry',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting curry made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'}],
#  'trend_analysis': {'trends': [{'name': 'Plant-Based Cuisine',
#     'description': 'The increasing popularity of plant-based diets and the rise of vegan and vegetarian options in restaurants.',
#     'relevance': 'High'},
#    {'name': 'Global Cuisine Revival',
#     'description': 'The resurgence of interest in traditional Mediterranean and Middle Eastern cuisine, with a focus on fresh ingredients and bold flavors.',
#     'relevance': 'High'},
#    {'name': 'Gluten-Free and Special Diets',
#     'description': 'The growing demand for gluten-free and other special diets, with restaurants adapting to cater to these needs and offering innovative solutions.',
#     'relevance': 'Medium'},
#    {'name': 'Sustainable and Locally Sourced',
#     'description': 'The emphasis on sustainability and locally sourced ingredients, with restaurants prioritizing environmentally friendly practices and supporting local farmers.',
#     'relevance': 'Medium'},
#    {'name': 'Easy and Accessible Recipes',
#     'description': 'The increasing popularity of easy and accessible recipes, with a focus on quick and convenient meal options that cater to busy lifestyles.',
#     'relevance': 'Low'}]},
#  'style_analysis': {'styles': [{'name': 'Vegan',
#     'description': 'A plant-based cuisine that excludes animal products',
#     'flavor_profile': 'Plant-based',
#     'key_ingredients': ['Legumes', 'Vegetables'],
#     'cooking_techniques': ['Roasting', 'Stewing'],
#     'user_fit': 'Highly relevant'},
#    {'name': 'Mediterranean',
#     'description': 'A cuisine that originated in the Mediterranean region',
#     'flavor_profile': 'Herby, citrusy, and olive oil-based',
#     'key_ingredients': ['Grains', 'Vegetables', 'Legumes'],
#     'cooking_techniques': ['Grilling', 'Roasting'],
#     'user_fit': 'Highly relevant'},
#    {'name': 'Gluten-free',
#     'description': 'A cuisine that excludes gluten-containing grains',
#     'flavor_profile': 'Light, airy, and often featuring gluten-free flours',
#     'key_ingredients': ['Gluten-free flours', 'Vegetables'],
#     'cooking_techniques': ['Baking', 'Steaming'],
#     'user_fit': 'Moderately relevant'}]},
#  'nutrition_analysis': {},
#  'final_recommendations': {},
#  'workflow_step': 'candidates_retrieved'}

# %% [markdown]
# Take a screenshot of the Python code, clearly showing your implementation from Task 1. Name the screenshot ```M3L2_node_analyze_styles.jpg```.

# %% [markdown]
# ### Node 5: Evaluate nutrition

# %%
def node_evaluate_nutrition(state: dict) -> dict:
    """Evaluate nutritional aspects and dietary compliance."""
    print("\n[Phase 3c] Evaluating nutrition...")
    
    restaurants = state["retrieved_restaurants"]
    recipes = state["retrieved_recipes"]
    profile = state["user_profile"]
    
    user_message = f"""Evaluate the nutritional fit of these options:

User Profile: {json.dumps(profile, indent=2)}
Restaurants: {json.dumps(restaurants[:5], indent=2)}
Recipes: {json.dumps(recipes[:5], indent=2)}

Check dietary restrictions, allergens, and nutritional balance.
Return JSON: {{"compliant_items": [], "flagged_items": [], "nutritional_highlights": []}}
"""
    
    try:
        response = call_agent("nutrition_expert", user_message)
        nutrition_analysis = extract_json(response)
        print(f"✓ Nutrition evaluation completed")
    except Exception as e:
        print(f"⚠ Error evaluating nutrition: {e}")
        nutrition_analysis = {"error": str(e)}
    
    state["nutrition_analysis"] = nutrition_analysis
    return state

# %%
state = node_evaluate_nutrition(state)
state
# Out:
# [Phase 3c] Evaluating nutrition...
# ✓ Nutrition evaluation completed
# {'user_input': '\nRestaurant Visit History:\n- Visited "Green Bowl" (Vegan, $$) 8 times\n- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times\n- Visited "Juice Lab" (Smoothies, $) 3 times\n\nSocial Media Posts:\n- "Loving my plant-based journey! 🌱"\n- "This gluten-free Mediterranean bowl is amazing!"\n- "Fresh juice is the best way to start the day."\n\nDietary Restrictions: Vegan, Gluten-Free\n',
#  'user_profile': {'favorite_cuisines': ['Vegan', 'Mediterranean'],
#   'dietary_restrictions': ['Vegan', 'Gluten-Free'],
#   'dining_occasions': ['Health-Conscious', 'Special Occasions'],
#   'price_range': '$$$',
#   'adventurousness_score': 8,
#   'flavor_preferences': ['Plant-based', 'Gluten-free'],
#   'summary': 'A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.'},
#  'retrieved_restaurants': [{'name': 'The Greenhouse',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.8,
#    'description': 'A plant-based restaurant with a focus on seasonal, locally-sourced ingredients.'},
#   {'name': 'Mediterranean Oasis',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A cozy restaurant serving traditional Mediterranean dishes with a modern twist.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'Vegan Vibes',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A vibrant restaurant serving creative, plant-based dishes in a lively setting.'},
#   {'name': 'The Mediterranean Table',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'},
#   {'name': 'Plant-Based Paradise',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A health-conscious restaurant offering a variety of plant-based options in a serene atmosphere.'},
#   {'name': 'Gluten-Free Delights',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A bakery and café serving a range of gluten-free treats and light meals.'},
#   {'name': 'The Health Club',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.7,
#    'description': 'A fitness-focused restaurant serving healthy, plant-based options in a modern setting.'},
#   {'name': 'Special Occasion Bistro',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A luxurious restaurant offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Cafe',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A cozy café serving a variety of plant-based options in a relaxed atmosphere.'},
#   {'name': 'Gluten-Free Fusion',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A restaurant offering a fusion of gluten-free and international cuisine.'},
#   {'name': 'The Mediterranean Market',
#    'cuisine': 'Mediterranean',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A market and deli serving traditional Mediterranean dishes and ingredients.'},
#   {'name': 'Vegan Fusion',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.4,
#    'description': 'A restaurant offering a fusion of vegan and international cuisine.'},
#   {'name': 'Gluten-Free Deli',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A deli serving a variety of gluten-free options in a casual setting.'},
#   {'name': 'The Health Food Store',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A health food store and café serving healthy, plant-based options.'},
#   {'name': 'Special Occasion Catering',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A catering service offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Restaurant',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A restaurant offering a variety of plant-based options in a modern setting.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'The Mediterranean Restaurant',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'}],
#  'retrieved_recipes': [{'name': 'Roasted Vegetable Bowl',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A hearty bowl filled with roasted vegetables, quinoa, and a tangy tahini sauce.'},
#   {'name': 'Grilled Halloumi with Honey and Figs',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A classic Cypriot dish featuring grilled halloumi cheese, honey, and fresh figs.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Soup',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting soup made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Chicken Shawarma',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled chicken, served in a warm pita with tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Apple Crisp',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A warm and comforting dessert made with gluten-free oats, apples, and a crunchy streusel topping.'},
#   {'name': 'Vegan Black Bean Tacos',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and nutritious dish featuring black beans, roasted vegetables, and a tangy slaw made with red cabbage and lime juice.'},
#   {'name': 'Stuffed Zucchini Boats',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A healthy and delicious dish featuring zucchinis stuffed with a mix of rice, herbs, and feta cheese, baked to perfection.'},
#   {'name': 'Gluten-Free Pumpkin Spice Muffins',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious and comforting muffin made with gluten-free flours, pumpkin puree, and a hint of cinnamon.'},
#   {'name': 'Vegan Chickpea Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with chickpeas, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Lamb Koftas',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled lamb koftas, served with a side of tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Curry',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting curry made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'}],
#  'trend_analysis': {'trends': [{'name': 'Plant-Based Cuisine',
#     'description': 'The increasing popularity of plant-based diets and the rise of vegan and vegetarian options in restaurants.',
#     'relevance': 'High'},
#    {'name': 'Global Cuisine Revival',
#     'description': 'The resurgence of interest in traditional Mediterranean and Middle Eastern cuisine, with a focus on fresh ingredients and bold flavors.',
#     'relevance': 'High'},
#    {'name': 'Gluten-Free and Special Diets',
#     'description': 'The growing demand for gluten-free and other special diets, with restaurants adapting to cater to these needs and offering innovative solutions.',
#     'relevance': 'Medium'},
#    {'name': 'Sustainable and Locally Sourced',
#     'description': 'The emphasis on sustainability and locally sourced ingredients, with restaurants prioritizing environmentally friendly practices and supporting local farmers.',
#     'relevance': 'Medium'},
#    {'name': 'Easy and Accessible Recipes',
#     'description': 'The increasing popularity of easy and accessible recipes, with a focus on quick and convenient meal options that cater to busy lifestyles.',
#     'relevance': 'Low'}]},
#  'style_analysis': {'styles': [{'name': 'Vegan',
#     'description': 'A plant-based cuisine that excludes animal products',
#     'flavor_profile': 'Plant-based',
#     'key_ingredients': ['Legumes', 'Vegetables'],
#     'cooking_techniques': ['Roasting', 'Stewing'],
#     'user_fit': 'Highly relevant'},
#    {'name': 'Mediterranean',
#     'description': 'A cuisine that originated in the Mediterranean region',
#     'flavor_profile': 'Herby, citrusy, and olive oil-based',
#     'key_ingredients': ['Grains', 'Vegetables', 'Legumes'],
#     'cooking_techniques': ['Grilling', 'Roasting'],
#     'user_fit': 'Highly relevant'},
#    {'name': 'Gluten-free',
#     'description': 'A cuisine that excludes gluten-containing grains',
#     'flavor_profile': 'Light, airy, and often featuring gluten-free flours',
#     'key_ingredients': ['Gluten-free flours', 'Vegetables'],
#     'cooking_techniques': ['Baking', 'Steaming'],
#     'user_fit': 'Moderately relevant'}]},
#  'nutrition_analysis': {'compliant_items': [],
#   'flagged_items': [{'name': 'Gluten-Free Bistro',
#     'reason': 'Gluten-free chocolate chip cookies not suitable for vegan dietary needs'},
#    {'name': 'The Mediterranean Table',
#     'reason': 'Stuffed bell peppers recipe contains feta cheese, not suitable for vegan dietary needs'}],
#   'nutritional_highlights': [{'name': 'The Greenhouse',
#     'description': 'High in fiber and protein'},
#    {'name': 'Vegan Vibes', 'description': 'High in protein and fiber'},
#    {'name': 'Mediterranean Oasis',
#     'description': 'High in protein and calcium'}]},
#  'final_recommendations': {},
#  'workflow_step': 'candidates_retrieved'}

# %% [markdown]
# ### Node 6: Generate recommendations

# %%
def node_generate_recommendations(state: dict) -> dict:
    """Synthesize all analyses into final recommendations."""
    print("\n[Phase 4] Generating final recommendations...")
    
    user_message = f"""Synthesize these insights into top 5 restaurant and top 5 recipe recommendations:

User Profile: {json.dumps(state['user_profile'], indent=2)}
Restaurants: {json.dumps(state['retrieved_restaurants'][:10], indent=2)}
Recipes: {json.dumps(state['retrieved_recipes'][:10], indent=2)}
Trends: {json.dumps(state['trend_analysis'], indent=2)}
Styles: {json.dumps(state['style_analysis'], indent=2)}
Nutrition: {json.dumps(state['nutrition_analysis'], indent=2)}

Return EXACTLY this JSON structure and nothing else:
{{
  "restaurants": [{{"name": str, "reasoning": str}}],
  "recipes": [{{"name": str, "reasoning": str}}]
}}

Each reasoning should be 2-3 sentences explaining why it's a great match.
"""
    
    try:
        response = call_agent("recommendation_expert", user_message)
        recommendations = extract_json(response)
        print(f"✓ Generated {len(recommendations.get('restaurants', []))} restaurant recommendations")
        print(f"✓ Generated {len(recommendations.get('recipes', []))} recipe recommendations")
    except Exception as e:
        print(f"⚠ Error generating recommendations: {e}")
        recommendations = {"error": str(e)}
    
    state["final_recommendations"] = recommendations
    state["workflow_step"] = "complete"
    return state

# %%
state=node_generate_recommendations(state)
state
# Out:
# [Phase 4] Generating final recommendations...
# ✓ Generated 5 restaurant recommendations
# ✓ Generated 5 recipe recommendations
# {'user_input': '\nRestaurant Visit History:\n- Visited "Green Bowl" (Vegan, $$) 8 times\n- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times\n- Visited "Juice Lab" (Smoothies, $) 3 times\n\nSocial Media Posts:\n- "Loving my plant-based journey! 🌱"\n- "This gluten-free Mediterranean bowl is amazing!"\n- "Fresh juice is the best way to start the day."\n\nDietary Restrictions: Vegan, Gluten-Free\n',
#  'user_profile': {'favorite_cuisines': ['Vegan', 'Mediterranean'],
#   'dietary_restrictions': ['Vegan', 'Gluten-Free'],
#   'dining_occasions': ['Health-Conscious', 'Special Occasions'],
#   'price_range': '$$$',
#   'adventurousness_score': 8,
#   'flavor_preferences': ['Plant-based', 'Gluten-free'],
#   'summary': 'A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.'},
#  'retrieved_restaurants': [{'name': 'The Greenhouse',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.8,
#    'description': 'A plant-based restaurant with a focus on seasonal, locally-sourced ingredients.'},
#   {'name': 'Mediterranean Oasis',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A cozy restaurant serving traditional Mediterranean dishes with a modern twist.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'Vegan Vibes',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A vibrant restaurant serving creative, plant-based dishes in a lively setting.'},
#   {'name': 'The Mediterranean Table',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'},
#   {'name': 'Plant-Based Paradise',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A health-conscious restaurant offering a variety of plant-based options in a serene atmosphere.'},
#   {'name': 'Gluten-Free Delights',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A bakery and café serving a range of gluten-free treats and light meals.'},
#   {'name': 'The Health Club',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.7,
#    'description': 'A fitness-focused restaurant serving healthy, plant-based options in a modern setting.'},
#   {'name': 'Special Occasion Bistro',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A luxurious restaurant offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Cafe',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.2,
#    'description': 'A cozy café serving a variety of plant-based options in a relaxed atmosphere.'},
#   {'name': 'Gluten-Free Fusion',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A restaurant offering a fusion of gluten-free and international cuisine.'},
#   {'name': 'The Mediterranean Market',
#    'cuisine': 'Mediterranean',
#    'price': '$$',
#    'rating': 4.3,
#    'description': 'A market and deli serving traditional Mediterranean dishes and ingredients.'},
#   {'name': 'Vegan Fusion',
#    'cuisine': 'Vegan',
#    'price': '$$',
#    'rating': 4.4,
#    'description': 'A restaurant offering a fusion of vegan and international cuisine.'},
#   {'name': 'Gluten-Free Deli',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.0,
#    'description': 'A deli serving a variety of gluten-free options in a casual setting.'},
#   {'name': 'The Health Food Store',
#    'cuisine': 'Health-Conscious',
#    'price': '$$$',
#    'rating': 4.6,
#    'description': 'A health food store and café serving healthy, plant-based options.'},
#   {'name': 'Special Occasion Catering',
#    'cuisine': 'Special Occasions',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A catering service offering fine dining experiences for special occasions.'},
#   {'name': 'The Plant-Based Restaurant',
#    'cuisine': 'Vegan',
#    'price': '$$$',
#    'rating': 4.5,
#    'description': 'A restaurant offering a variety of plant-based options in a modern setting.'},
#   {'name': 'Gluten-Free Bistro',
#    'cuisine': 'Gluten-Free',
#    'price': '$$',
#    'rating': 4.1,
#    'description': 'A casual eatery offering a variety of gluten-free options in a relaxed atmosphere.'},
#   {'name': 'The Mediterranean Restaurant',
#    'cuisine': 'Mediterranean',
#    'price': '$$$',
#    'rating': 4.4,
#    'description': 'A family-owned restaurant serving traditional Mediterranean cuisine with a focus on quality ingredients.'}],
#  'retrieved_recipes': [{'name': 'Roasted Vegetable Bowl',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A hearty bowl filled with roasted vegetables, quinoa, and a tangy tahini sauce.'},
#   {'name': 'Grilled Halloumi with Honey and Figs',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A classic Cypriot dish featuring grilled halloumi cheese, honey, and fresh figs.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Soup',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting soup made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Chicken Shawarma',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled chicken, served in a warm pita with tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Apple Crisp',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A warm and comforting dessert made with gluten-free oats, apples, and a crunchy streusel topping.'},
#   {'name': 'Vegan Black Bean Tacos',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and nutritious dish featuring black beans, roasted vegetables, and a tangy slaw made with red cabbage and lime juice.'},
#   {'name': 'Stuffed Zucchini Boats',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A healthy and delicious dish featuring zucchinis stuffed with a mix of rice, herbs, and feta cheese, baked to perfection.'},
#   {'name': 'Gluten-Free Pumpkin Spice Muffins',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious and comforting muffin made with gluten-free flours, pumpkin puree, and a hint of cinnamon.'},
#   {'name': 'Vegan Chickpea Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with chickpeas, roasted vegetables, and a tangy lemon-tahini dressing.'},
#   {'name': 'Grilled Lamb Koftas',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A classic Middle Eastern dish featuring grilled lamb koftas, served with a side of tzatziki sauce and pickled vegetables.'},
#   {'name': 'Gluten-Free Chocolate Chip Cookies',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A delicious batch of gluten-free chocolate chip cookies perfect for a sweet treat.'},
#   {'name': 'Spicy Lentil Curry',
#    'cuisine': 'Vegan',
#    'difficulty': 'Moderate',
#    'prep_time': '40 minutes',
#    'description': 'A flavorful and comforting curry made with red lentils, onions, garlic, and a hint of cumin.'},
#   {'name': 'Stuffed Bell Peppers',
#    'cuisine': 'Mediterranean',
#    'difficulty': 'Moderate',
#    'prep_time': '45 minutes',
#    'description': 'A colorful and nutritious dish featuring bell peppers stuffed with a mix of rice, herbs, and feta cheese.'},
#   {'name': 'Gluten-Free Banana Bread',
#    'cuisine': 'Gluten-Free',
#    'difficulty': 'Easy',
#    'prep_time': '30 minutes',
#    'description': 'A moist and delicious banana bread made with gluten-free flours and topped with a crunchy streusel topping.'},
#   {'name': 'Vegan Quinoa Salad',
#    'cuisine': 'Vegan',
#    'difficulty': 'Easy',
#    'prep_time': '20 minutes',
#    'description': 'A refreshing salad made with cooked quinoa, roasted vegetables, and a tangy lemon-tahini dressing.'}],
#  'trend_analysis': {'trends': [{'name': 'Plant-Based Cuisine',
#     'description': 'The increasing popularity of plant-based diets and the rise of vegan and vegetarian options in restaurants.',
#     'relevance': 'High'},
#    {'name': 'Global Cuisine Revival',
#     'description': 'The resurgence of interest in traditional Mediterranean and Middle Eastern cuisine, with a focus on fresh ingredients and bold flavors.',
#     'relevance': 'High'},
#    {'name': 'Gluten-Free and Special Diets',
#     'description': 'The growing demand for gluten-free and other special diets, with restaurants adapting to cater to these needs and offering innovative solutions.',
#     'relevance': 'Medium'},
#    {'name': 'Sustainable and Locally Sourced',
#     'description': 'The emphasis on sustainability and locally sourced ingredients, with restaurants prioritizing environmentally friendly practices and supporting local farmers.',
#     'relevance': 'Medium'},
#    {'name': 'Easy and Accessible Recipes',
#     'description': 'The increasing popularity of easy and accessible recipes, with a focus on quick and convenient meal options that cater to busy lifestyles.',
#     'relevance': 'Low'}]},
#  'style_analysis': {'styles': [{'name': 'Vegan',
#     'description': 'A plant-based cuisine that excludes animal products',
#     'flavor_profile': 'Plant-based',
#     'key_ingredients': ['Legumes', 'Vegetables'],
#     'cooking_techniques': ['Roasting', 'Stewing'],
#     'user_fit': 'Highly relevant'},
#    {'name': 'Mediterranean',
#     'description': 'A cuisine that originated in the Mediterranean region',
#     'flavor_profile': 'Herby, citrusy, and olive oil-based',
#     'key_ingredients': ['Grains', 'Vegetables', 'Legumes'],
#     'cooking_techniques': ['Grilling', 'Roasting'],
#     'user_fit': 'Highly relevant'},
#    {'name': 'Gluten-free',
#     'description': 'A cuisine that excludes gluten-containing grains',
#     'flavor_profile': 'Light, airy, and often featuring gluten-free flours',
#     'key_ingredients': ['Gluten-free flours', 'Vegetables'],
#     'cooking_techniques': ['Baking', 'Steaming'],
#     'user_fit': 'Moderately relevant'}]},
#  'nutrition_analysis': {'compliant_items': [],
#   'flagged_items': [{'name': 'Gluten-Free Bistro',
#     'reason': 'Gluten-free chocolate chip cookies not suitable for vegan dietary needs'},
#    {'name': 'The Mediterranean Table',
#     'reason': 'Stuffed bell peppers recipe contains feta cheese, not suitable for vegan dietary needs'}],
#   'nutritional_highlights': [{'name': 'The Greenhouse',
#     'description': 'High in fiber and protein'},
#    {'name': 'Vegan Vibes', 'description': 'High in protein and fiber'},
#    {'name': 'Mediterranean Oasis',
#     'description': 'High in protein and calcium'}]},
#  'final_recommendations': {'restaurants': [{'name': 'The Greenhouse',
#     'reasoning': "This restaurant is a great match due to its focus on seasonal, locally-sourced ingredients and plant-based cuisine, aligning with the user's dietary needs and preferences. The restaurant's high rating and price range also make it an attractive option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."},
#    {'name': 'Mediterranean Oasis',
#     'reasoning': "This restaurant is a great match due to its traditional Mediterranean cuisine and modern twist, which aligns with the user's flavor preferences. The restaurant's cozy atmosphere and high rating also make it an appealing option. Furthermore, its focus on fresh ingredients and bold flavors resonates with the user's adventurousness score."},
#    {'name': 'The Mediterranean Table',
#     'reasoning': "This restaurant is a great match due to its traditional Mediterranean cuisine and focus on quality ingredients, which aligns with the user's dietary needs and preferences. The restaurant's family-owned atmosphere and high rating also make it an attractive option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."},
#    {'name': 'Vegan Vibes',
#     'reasoning': "This restaurant is a great match due to its creative, plant-based dishes and lively atmosphere, which aligns with the user's flavor preferences and adventurousness score. The restaurant's high rating and price range also make it an appealing option. Furthermore, its focus on sustainability and locally sourced ingredients resonates with the user's values."},
#    {'name': 'Plant-Based Paradise',
#     'reasoning': "This restaurant is a great match due to its health-conscious approach and plant-based cuisine, which aligns with the user's dietary needs and preferences. The restaurant's serene atmosphere and high rating also make it an attractive option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."}],
#   'recipes': [{'name': 'Roasted Vegetable Bowl',
#     'reasoning': "This recipe is a great match due to its plant-based ingredients and focus on seasonal, locally-sourced ingredients, aligning with the user's dietary needs and preferences. The recipe's ease of preparation and high nutritional value also make it an appealing option. Furthermore, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."},
#    {'name': 'Spicy Lentil Soup',
#     'reasoning': "This recipe is a great match due to its plant-based ingredients and focus on bold flavors, aligning with the user's flavor preferences and adventurousness score. The recipe's ease of preparation and high nutritional value also make it an appealing option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."},
#    {'name': 'Gluten-Free Banana Bread',
#     'reasoning': "This recipe is a great match due to its gluten-free ingredients and focus on easy preparation, aligning with the user's dietary needs and preferences. The recipe's high nutritional value and emphasis on sustainability also make it an appealing option. Furthermore, its focus on locally sourced ingredients resonates with the user's values."},
#    {'name': 'Vegan Quinoa Salad',
#     'reasoning': "This recipe is a great match due to its plant-based ingredients and focus on easy preparation, aligning with the user's dietary needs and preferences. The recipe's high nutritional value and emphasis on sustainability also make it an appealing option. Additionally, its focus on locally sourced ingredients resonates with the user's values."},
#    {'name': 'Gluten-Free Apple Crisp',
#     'reasoning': "This recipe is a great match due to its gluten-free ingredients and focus on easy preparation, aligning with the user's dietary needs and preferences. The recipe's high nutritional value and emphasis on sustainability also make it an appealing option. Furthermore, its focus on locally sourced ingredients resonates with the user's values."}]},
#  'workflow_step': 'complete'}

# %% [markdown]
# ### **Question 2**: Which three nodes execute in parallel during Phase 3?

# %% [markdown]
# #### **Answer**: You can use this cell to enter your answer.

# %% [markdown]
# ## Build the workflow graph
#
# Now you'll build the workflow that connects all nodes. You'll use Python's `ThreadPoolExecutor` to run the Phase 3 analysis agents in parallel, mirroring what a framework like LangGraph would do under the hood.

# %%
def run_workflow(user_input: str) -> dict:
    """Run the full multi-agent workflow.
    
    Phases:
      1. User Analysis      (sequential)
      2. Data Retrieval      (sequential)
      3. Analysis            (parallel – trends, styles, nutrition)
      4. Synthesis           (sequential)
    """
    
    # Initialize shared state
    state = {
        "user_input": user_input,
        "user_profile": {},
        "retrieved_restaurants": [],
        "retrieved_recipes": [],
        "trend_analysis": {},
        "style_analysis": {},
        "nutrition_analysis": {},
        "final_recommendations": {},
        "workflow_step": "start"
    }
    
    # Phase 1 – Sequential
    state = node_generate_profile(state)
    
    # Phase 2 – Sequential
    state = node_retrieve_candidates(state)
    
    # Phase 3 – Parallel using ThreadPoolExecutor
    print("\n[Phase 3] Running analysis agents in parallel...")
    
    # Each function needs its own copy of state to read from,
    # and we merge their outputs back afterwards.
    with ThreadPoolExecutor(max_workers=3) as executor:
        future_trends   = executor.submit(node_analyze_trends, dict(state))
        future_styles   = executor.submit(node_analyze_styles, dict(state))
        future_nutrition = executor.submit(node_evaluate_nutrition, dict(state))
        
        result_trends   = future_trends.result()
        result_styles   = future_styles.result()
        result_nutrition = future_nutrition.result()
        
    # Merge parallel results back into state
    state["trend_analysis"]    = result_trends["trend_analysis"]
    state["style_analysis"]    = result_styles["style_analysis"]
    state["nutrition_analysis"] = result_nutrition["nutrition_analysis"]
    
    # Phase 4 – Sequential
    state = node_generate_recommendations(state)
    
    return state

print("✓ Workflow function built successfully!")
# Out:
# ✓ Workflow function built successfully!

# %% [markdown]
# ## Test the multi-agent system
#
# Next, test the system with different user personas.
#
# ### Test Case 1: The health-conscious user

# %%
test_user_1 = """
Restaurant Visit History:
- Visited "Green Bowl" (Vegan, $$) 8 times
- Visited "Mediterranean Grill" (Mediterranean, $$) 5 times
- Visited "Juice Lab" (Smoothies, $) 3 times

Social Media Posts:
- "Loving my plant-based journey! 🌱"
- "This gluten-free Mediterranean bowl is amazing!"
- "Fresh juice is the best way to start the day."

Dietary Restrictions: Vegan, Gluten-Free
"""

print("="*80)
print("TEST CASE 1: Health-Conscious User")
print("="*80)

try:
    result_1 = run_workflow(test_user_1)
    print("\n" + "="*80)
    print("FINAL RECOMMENDATIONS")
    print("="*80)
    print(json.dumps(result_1["final_recommendations"], indent=2))
except Exception as e:
    print(f"\nTest requires valid OpenAI API key. Error: {e}")
# Out:
# ================================================================================
# TEST CASE 1: Health-Conscious User
# ================================================================================
#
# [Phase 1] Generating user profile...
# ✓ User profile generated: A health-conscious individual with a love for plant-based and Mediterranean cuisine, seeking out new dining experiences that cater to their dietary needs.
#
# [Phase 2] Retrieving candidates from vector database...
# ✓ Retrieved 19 restaurants and 19 recipes
#
# [Phase 3] Running analysis agents in parallel...
#
# [Phase 3a] Analyzing food trends...
#
# [Phase 3b] Analyzing food styles...
#
# [Phase 3c] Evaluating nutrition...
# ✓ Identified 5 trends
# ✓ Nutrition evaluation completed
# ✓ Style analysis completed
#
# [Phase 4] Generating final recommendations...
# ✓ Generated 5 restaurant recommendations
# ✓ Generated 4 recipe recommendations
#
# ================================================================================
# FINAL RECOMMENDATIONS
# ================================================================================
# {
#   "restaurants": [
#     {
#       "name": "The Greenhouse",
#       "reasoning": "This restaurant is a great match due to its focus on seasonal, locally-sourced ingredients and plant-based cuisine, aligning with the user's dietary needs and preferences. The restaurant's high rating and price range also make it an attractive option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."
#     },
#     {
#       "name": "Mediterranean Oasis",
#       "reasoning": "This restaurant is a great match due to its traditional Mediterranean cuisine and modern twist, which aligns with the user's flavor preferences. The restaurant's cozy atmosphere and high rating also make it an appealing option. Furthermore, its focus on fresh ingredients and bold flavors resonates with the user's adventurousness score."
#     },
#     {
#       "name": "The Mediterranean Table",
#       "reasoning": "This restaurant is a great match due to its traditional Mediterranean cuisine and focus on quality ingredients, which aligns with the user's dietary needs and preferences. The restaurant's family-owned atmosphere and high rating also make it an attractive option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."
#     },
#     {
#       "name": "Vegan Vibes",
#       "reasoning": "This restaurant is a great match due to its creative, plant-based dishes and lively atmosphere, which aligns with the user's flavor preferences and adventurousness score. The restaurant's high rating and price range also make it an appealing option. Furthermore, its focus on sustainability and locally sourced ingredients resonates with the user's values."
#     },
#     {
#       "name": "Plant-Based Paradise",
#       "reasoning": "This restaurant is a great match due to its health-conscious approach and plant-based cuisine, which aligns with the user's dietary needs and preferences. The restaurant's serene atmosphere and high rating also make it an attractive option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."
#     }
#   ],
#   "recipes": [
#     {
#       "name": "Roasted Vegetable Bowl",
#       "reasoning": "This recipe is a great match due to its plant-based ingredients and focus on seasonal, locally-sourced ingredients, aligning with the user's dietary needs and preferences. The recipe's ease of preparation and high nutritional value also make it an appealing option. Furthermore, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."
#     },
#     {
#       "name": "Spicy Lentil Soup",
#       "reasoning": "This recipe is a great match due to its plant-based ingredients and focus on bold flavors, aligning with the user's flavor preferences and adventurousness score. The recipe's ease of preparation and high nutritional value also make it an appealing option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values."
#     },
#     {
#       "name": "Gluten-Free Banana Bread",
#       "reasoning": "This recipe is a great match due to its gluten-free ingredients and focus on easy preparation, aligning with the user's dietary needs and preferences. The recipe's high nutritional value and emphasis on sustainability also make it an appealing option. Furthermore, its focus on locally sourced ingredients resonates with the user's values."
#     },
#     {
#       "name": "Vegan Quinoa Salad",
#       "reasoning": "This recipe is a great match due to its plant-based ingredients and focus on easy preparation, aligning with the user's dietary needs and preferences. The recipe's high nutritional value and emphasis on sustainability also make it an appealing option. Additionally, its focus on locally sourced ingredients resonates with the user's values."
#     }
#   ]
# }

# %% [markdown]
# ### Test Case 2: The adventurous foodie

# %%
test_user_2 = """
Restaurant Visit History:
- Visited "Omakase Sushi" (Japanese Fine Dining, $$$$) 4 times
- Visited "Street Food Market" (International Fusion, $$) 6 times
- Visited "Molecular Gastronomy Lab" (Experimental, $$$$) 2 times

Social Media Posts:
- "Mind-blown by the 12-course tasting menu! 🤯"
- "Trying crickets for the first time. Surprisingly good!"
- "This molecular take on traditional ramen is art."

Dietary Restrictions: None
"""

print("="*80)
print("TEST CASE 2: Adventurous Foodie")
print("="*80)

try:
    result_2 = run_workflow(test_user_2)
    print("\n" + "="*80)
    print("FINAL RECOMMENDATIONS")
    print("="*80)
    print(json.dumps(result_2["final_recommendations"], indent=2))
except Exception as e:
    print(f"\nTest requires valid OpenAI API key. Error: {e}")
# Out:
# ================================================================================
# TEST CASE 2: Adventurous Foodie
# ================================================================================
#
# [Phase 1] Generating user profile...
# ✓ User profile generated: A foodie with a taste for adventure, always on the lookout for unique dining experiences and bold flavors.
#
# [Phase 2] Retrieving candidates from vector database...
# ✓ Retrieved 19 restaurants and 19 recipes
#
# [Phase 3] Running analysis agents in parallel...
#
# [Phase 3a] Analyzing food trends...
#
# [Phase 3b] Analyzing food styles...
#
# [Phase 3c] Evaluating nutrition...
# ✓ Identified 5 trends
# ✓ Nutrition evaluation completed
# ✓ Style analysis completed
#
# [Phase 4] Generating final recommendations...
# ✓ Generated 5 restaurant recommendations
# ✓ Generated 5 recipe recommendations
#
# ================================================================================
# FINAL RECOMMENDATIONS
# ================================================================================
# {
#   "restaurants": [
#     {
#       "name": "SushiSamba",
#       "reasoning": "SushiSamba is a great match for this user due to its modern take on traditional Japanese cuisine, which aligns with their favorite cuisine. The restaurant's international flair also appeals to their adventurousness score. Additionally, its rating and price range make it a suitable choice for a special occasion or date night."
#     },
#     {
#       "name": "Fusion Station",
#       "reasoning": "Fusion Station is a great match for this user because it serves innovative fusion dishes that combine different international cuisines. This aligns with their love for international fusion cuisine and adventurousness score. The restaurant's trendy atmosphere also makes it a great choice for a date night or special occasion."
#     },
#     {
#       "name": "Kokoro",
#       "reasoning": "Kokoro is a great match for this user because it offers a traditional Japanese dining experience with a focus on seasonal ingredients. This aligns with their love for Japanese cuisine and umami flavor preferences. The restaurant's cozy atmosphere also makes it a great choice for a special occasion or date night."
#     },
#     {
#       "name": "Taste Quest",
#       "reasoning": "Taste Quest is a great match for this user because it offers a culinary journey through international flavors and cuisines. This aligns with their love for international fusion cuisine and adventurousness score. The restaurant's modern take on traditional dishes also appeals to their umami flavor preferences."
#     },
#     {
#       "name": "Bistro Bliss",
#       "reasoning": "Bistro Bliss is a great match for this user because it offers a charming French dining experience with a twist. This aligns with their love for umami flavor preferences and adventurousness score. The restaurant's cozy atmosphere also makes it a great choice for a special occasion or date night."
#     }
#   ],
#   "recipes": [
#     {
#       "name": "Spicy Miso Ramen",
#       "reasoning": "Spicy Miso Ramen is a great match for this user because it offers a rich, savory broth with a spicy kick. This aligns with their umami flavor preferences and adventurousness score. The recipe's ease of preparation also makes it a great choice for a beginner cook."
#     },
#     {
#       "name": "Korean BBQ Beef Tacos",
#       "reasoning": "Korean BBQ Beef Tacos is a great match for this user because it offers a unique fusion of Korean BBQ flavors with Mexican tacos. This aligns with their love for international fusion cuisine and adventurousness score. The recipe's medium level of difficulty also makes it a great choice for an intermediate cook."
#     },
#     {
#       "name": "Umami Mushroom Risotto",
#       "reasoning": "Umami Mushroom Risotto is a great match for this user because it offers a rich, umami flavor profile with a creamy risotto. This aligns with their umami flavor preferences and adventurousness score. The recipe's medium level of difficulty also makes it a great choice for an intermediate cook."
#     },
#     {
#       "name": "Spicy Sushi Rolls",
#       "reasoning": "Spicy Sushi Rolls is a great match for this user because it offers a simple recipe for spicy sushi rolls with a kick of heat. This aligns with their love for umami flavor preferences and adventurousness score. The recipe's ease of preparation also makes it a great choice for a beginner cook."
#     },
#     {
#       "name": "Indian Butter Chicken",
#       "reasoning": "Indian Butter Chicken is a great match for this user because it offers a rich and creamy Indian butter chicken recipe with a blend of spices. This aligns with their love for umami flavor preferences and adventurousness score. The recipe's medium level of difficulty also makes it a great choice for an intermediate cook."
#     }
#   ]
# }

# %% [markdown]
# ### **Question 3**: Based on the workflow design, which phase takes the longest time to execute and why?

# %% [markdown]
# #### **Answer**: You can use this cell to enter your answer.

# %% [markdown]
# ## Evaluate the recommendations

# %% [markdown]
# Create a simple evaluation function to assess recommendation quality.

# %%
def evaluate_recommendations(result: Dict[str, Any]):
    """Evaluate the quality of recommendations."""
    print("\n" + "="*80)
    print("RECOMMENDATION EVALUATION")
    print("="*80)
    
    profile = result.get("user_profile", {})
    recommendations = result.get("final_recommendations", {})
    
    # Check if recommendations exist
    restaurants = recommendations.get("restaurants", [])
    recipes = recommendations.get("recipes", [])
    
    print(f"\n✓ Number of restaurant recommendations: {len(restaurants)}")
    print(f"✓ Number of recipe recommendations: {len(recipes)}")
    
    # Check dietary compliance
    dietary_restrictions = profile.get("dietary_restrictions", [])
    if dietary_restrictions:
        print(f"\n✓ Dietary restrictions identified: {', '.join(dietary_restrictions)}")
        print("  → Check if recommendations respect these restrictions")
    
    # Check diversity
    favorite_cuisines = profile.get("favorite_cuisines", [])
    if favorite_cuisines:
        print(f"\n✓ Favorite cuisines: {', '.join(favorite_cuisines)}")
        print("  → Check if recommendations include these cuisines")
    
    # Evaluate reasoning quality
    if restaurants:
        print(f"\n✓ First restaurant recommendation:")
        print(f"  Name: {restaurants[0].get('name', 'N/A')}")
        print(f"  Reasoning: {restaurants[0].get('reasoning', 'N/A')}")
    
    if recipes:
        print(f"\n✓ First recipe recommendation:")
        print(f"  Name: {recipes[0].get('name', 'N/A')}")
        print(f"  Reasoning: {recipes[0].get('reasoning', 'N/A')}")
    
    print("\n" + "="*80)

# %%
# Evaluate Test Case 1 if available
try:
    if 'result_1' in locals():
        evaluate_recommendations(result_1)
except Exception as e:
    print(f"Evaluation requires completed test run: {e}")
# Out:
# ================================================================================
# RECOMMENDATION EVALUATION
# ================================================================================
#
# ✓ Number of restaurant recommendations: 5
# ✓ Number of recipe recommendations: 4
#
# ✓ Dietary restrictions identified: Vegan, Gluten-Free
#   → Check if recommendations respect these restrictions
#
# ✓ Favorite cuisines: Vegan, Mediterranean
#   → Check if recommendations include these cuisines
#
# ✓ First restaurant recommendation:
#   Name: The Greenhouse
#   Reasoning: This restaurant is a great match due to its focus on seasonal, locally-sourced ingredients and plant-based cuisine, aligning with the user's dietary needs and preferences. The restaurant's high rating and price range also make it an attractive option. Additionally, its emphasis on sustainability and locally sourced ingredients resonates with the user's values.
#
# ✓ First recipe recommendation:
#   Name: Roasted Vegetable Bowl
#   Reasoning: This recipe is a great match due to its plant-based ingredients and focus on seasonal, locally-sourced ingredients, aligning with the user's dietary needs and preferences. The recipe's ease of preparation and high nutritional value also make it an appealing option. Furthermore, its emphasis on sustainability and locally sourced ingredients resonates with the user's values.
#
# ================================================================================

# %% [markdown]
# ### **Question 4**: What is the purpose of the `workflow_step` field in the AgentState?

# %% [markdown]
# #### **Answer**: You can use this cell to enter your answer.

# %% [markdown]
# ### Congratulations!
# You have successfully completed this lab.

# %% [markdown]
# ### Summary
#
# In this lab, you implemented a multi-agent recommendation system with a hybrid workflow:
# 1. **Phase 1 (Sequential)**: User Profile Generator analyzes user data
# 2. **Phase 2 (Sequential)**: RAG Retriever queries the vector database
# 3. **Phase 3 (Parallel)**: Food Trend Analyst, Food Style Expert, and Nutrition Expert analyze candidates simultaneously
# 4. **Phase 4 (Sequential)**: Recommendation Expert synthesizes all insights into final recommendations
#
# You used LangGraph to build a stateful workflow with shared state, node functions, and edges. You tested the system with multiple user personas and evaluated recommendation quality. In the next lesson, you will build a chatbot interface using Gradio to make the system interactive and user-friendly.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Tenzin Migmar](https://author.skills.network/instructors/tenzin_migmar)

# %% [markdown]
# ©IBM Corporation. All rights reserved.

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2026-02-03|1|Tenzin Migmar|Create lab|
# |2026-02-10|2|Jojy John|ID Reviewed|-->
